# %%
import pandas as pd
import re

# %%
csv = pd.read_csv("kdrama.csv")

# %%
csv.URL = csv.URL.str.split(">")

# %%
csv.URL = csv['URL'].str[0]

# %%
csv.URL = csv.URL.str.split("=")

# %%
csv.URL = csv['URL'].str[1]

# %%
csv.URL = csv.URL.str.replace('"', '')

# %%
csv.to_csv("kdramaclean.csv")

# %%
clean = pd.read_csv("kdramaclean.csv")

# %%
clean
# Out:
#       Unnamed: 0                        Title  \
# 0              0                       Goblin
# 1              1    Strong Woman Do Bong Soon
# 2              2       Descendants of the Sun
# 3              3                            W
# 4              4  You Who Came from the Stars
# ...          ...                          ...
# 1185        1185        The Reason I Hate You
# 1186        1186            You I Didn't Know
# 1187        1187          Love Playlist Pilot
# 1188        1188               Life of Namjoo
# 1189        1189           Case Cell Division
#
#                                   Info  Ratings  \
# 0     Korean Drama - 2016, 16 episodes      8.9
# 1     Korean Drama - 2017, 16 episodes      8.7
# 2     Korean Drama - 2016, 16 episodes      8.7
# 3     Korean Drama - 2016, 16 episodes      8.5
# 4     Korean Drama - 2013, 21 episodes      8.6
# ...                                ...      ...
# 1185   Korean Drama - 2020, 3 episodes      6.9
# ...

# %%
lk = pd.read_csv('kdramaclean.csv')
half = lk['URL'].values
links = ['https://mydramalist.com' + i for i in half]

# %%
links
# Out:
# ['https://mydramalist.com/18452-goblin',
#  'https://mydramalist.com/18894-strong-woman-do-bong-soon',
#  'https://mydramalist.com/10904-descendants-of-the-sun',
#  'https://mydramalist.com/16589-w',
#  'https://mydramalist.com/7398-you-who-came-from-the-stars',
#  'https://mydramalist.com/19262-weightlifting-fairy-kim-bok-joo',
#  'https://mydramalist.com/6640-the-heirs',
#  'https://mydramalist.com/11074-pinocchio',
#  'https://mydramalist.com/10814-healer',
#  'https://mydramalist.com/27885-why-secretary-kim',
#  'https://mydramalist.com/21576-while-you-were-sleeping',
#  'https://mydramalist.com/15999-moon-lovers-scarlet-heart-ryeo',
#  'https://mydramalist.com/8-secret-garden-2010',
#  'https://mydramalist.com/10873-kill-me-heal-me',
#  'https://mydramalist.com/18816-the-legend-of-the-blue-sea',
#  'https://mydramalist.com/35729-emergency-lands-of-love',
#  'https://mydramalist.com/1702-city-hunter-2011',
#  'https://mydramalist.com/6993-i-hear-your-voice',
# ...

# %%
list1 = []

for i in range(0,1190):
    list1.insert(i, clean.URL[i])

# %%
list1
# Out:
# ['/18452-goblin',
#  '/18894-strong-woman-do-bong-soon',
#  '/10904-descendants-of-the-sun',
#  '/16589-w',
#  '/7398-you-who-came-from-the-stars',
#  '/19262-weightlifting-fairy-kim-bok-joo',
#  '/6640-the-heirs',
#  '/11074-pinocchio',
#  '/10814-healer',
#  '/27885-why-secretary-kim',
#  '/21576-while-you-were-sleeping',
#  '/15999-moon-lovers-scarlet-heart-ryeo',
#  '/8-secret-garden-2010',
#  '/10873-kill-me-heal-me',
#  '/18816-the-legend-of-the-blue-sea',
#  '/35729-emergency-lands-of-love',
#  '/1702-city-hunter-2011',
#  '/6993-i-hear-your-voice',
#  '/15055-she-was-pretty',
#  '/24351-im-not-a-robot',
#  '/14457-cheese-in-the-trap',
#  '/22472-fight-for-my-way',
#  '/32925-hotel-del-luna',
#  '/6756-the-masters-sun',
#  '/49865-psycho-but-it-s-okay',
#  '/22602-suspicious-partner',
#  '/9289-its-okay-thats-love',
#  '/14213-oh-my-ghostess',
#  '/20-playful-kiss',
#  '/79-dream-high',
#  '/16119-cinderella-and-the-four-knights',
#  '/15062-oh-my-venus',
# ...

# %%
reviews = pd.read_csv("reviews.csv").dropna()
reviews
# Out:
#                           Title  Ratings                    Ranked  \
# 0     Strong Woman Do Bong Soon      8.7                       #84
# 1                     The Heirs      7.5                     #2787
# 2                     Pinocchio      8.4                      #265
# 3                        Goblin      8.9                       #33
# 4                             W      8.5                      #196
# ...                         ...      ...                       ...
# 1183        Love Playlist Pilot      7.5   15+ - Teens 15 or older
# 1184              Love Teenager      6.9             Not Yet Rated
# 1185    My Wonderful Roommate 2      7.0                    #99999
# 1188             Life of Namjoo      7.3                    #34194
# 1189         Case Cell Division     10.0                    #99999
#
#           Popularity        Actor 1                        URL 1  \
# 0                 #2  Park Bo Young   /people/1498-park-bo-young
# ...

# %%
reviews['URL 1'] = 'https://www.mydramalist.com' + reviews['URL 1'].astype(str)

# %%
reviews['URL 2'] = 'https://www.mydramalist.com' + reviews['URL 2'].astype(str)

# %%
reviews
# Out:
#                           Title  Ratings                    Ranked  \
# 0     Strong Woman Do Bong Soon      8.7                       #84
# 1                     The Heirs      7.5                     #2787
# 2                     Pinocchio      8.4                      #265
# 3                        Goblin      8.9                       #33
# 4                             W      8.5                      #196
# ...                         ...      ...                       ...
# 1183        Love Playlist Pilot      7.5   15+ - Teens 15 or older
# 1184              Love Teenager      6.9             Not Yet Rated
# 1185    My Wonderful Roommate 2      7.0                    #99999
# 1188             Life of Namjoo      7.3                    #34194
# 1189         Case Cell Division     10.0                    #99999
#
#           Popularity        Actor 1  \
# 0                 #2  Park Bo Young
# 1                 #8     Lee Min Ho
# 2                 #9   Lee Jong Suk
# ...

# %%
reviews.reset_index(inplace = True)

# %%
reviews
# Out:
#       index                      Title  Ratings                    Ranked  \
# 0         0  Strong Woman Do Bong Soon      8.7                       #84
# 1         1                  The Heirs      7.5                     #2787
# 2         2                  Pinocchio      8.4                      #265
# 3         3                     Goblin      8.9                       #33
# 4         4                          W      8.5                      #196
# ...     ...                        ...      ...                       ...
# 1145   1183        Love Playlist Pilot      7.5   15+ - Teens 15 or older
# 1146   1184              Love Teenager      6.9             Not Yet Rated
# 1147   1185    My Wonderful Roommate 2      7.0                    #99999
# 1148   1188             Life of Namjoo      7.3                    #34194
# 1149   1189         Case Cell Division     10.0                    #99999
#
#           Popularity        Actor 1  \
# 0                 #2  Park Bo Young
# ...

# %%
reviews = reviews.drop("index", 1)
reviews
# Out:
#                           Title  Ratings                    Ranked  \
# 0     Strong Woman Do Bong Soon      8.7                       #84
# 1                     The Heirs      7.5                     #2787
# 2                     Pinocchio      8.4                      #265
# 3                        Goblin      8.9                       #33
# 4                             W      8.5                      #196
# ...                         ...      ...                       ...
# 1145        Love Playlist Pilot      7.5   15+ - Teens 15 or older
# 1146              Love Teenager      6.9             Not Yet Rated
# 1147    My Wonderful Roommate 2      7.0                    #99999
# 1148             Life of Namjoo      7.3                    #34194
# 1149         Case Cell Division     10.0                    #99999
#
#           Popularity        Actor 1  \
# 0                 #2  Park Bo Young
# 1                 #8     Lee Min Ho
# 2                 #9   Lee Jong Suk
# ...

# %%
reviews.to_csv("reviewscleanbfr.csv")

# %%
url1 = []

for i in range(0,1150):
    url1.insert(i, reviews['URL 1'][i])

# %%
len(url1)
# Out:
# 1150

# %%
url2 = []

for i in range(0,1150):
    url2.insert(i, reviews['URL 2'][i])

# %%
len(url2)
url1
# Out:
# ['https://www.mydramalist.com/people/1498-park-bo-young',
#  'https://www.mydramalist.com/people/232-lee-min-ho',
#  'https://www.mydramalist.com/people/900-lee-jong-suk',
#  'https://www.mydramalist.com/people/440-gong-yoo',
#  'https://www.mydramalist.com/people/300-han-hyo-joo',
#  'https://www.mydramalist.com/people/806-ji-chang-wook',
#  'https://www.mydramalist.com/people/424-kim-soo-hyun',
#  'https://www.mydramalist.com/people/422-suzy',
#  'https://www.mydramalist.com/people/7660-lee-sung-kyung',
#  'https://www.mydramalist.com/people/431-song-joong-ki',
#  'https://www.mydramalist.com/people/232-lee-min-ho',
#  'https://www.mydramalist.com/people/183-hyun-bin',
#  'https://www.mydramalist.com/people/430-park-min-young',
#  'https://www.mydramalist.com/people/183-hyun-bin',
#  'https://www.mydramalist.com/people/469-ji-sung',
#  'https://www.mydramalist.com/people/207-lee-joon-gi',
#  'https://www.mydramalist.com/people/900-lee-jong-suk',
# ...

# %%
reviews_clean = pd.read_csv("reviewsclean.csv").drop(["Unnamed: 0", "index"], axis = 1)

# %%
reviews = pd.read_csv('reviewsclean.csv')

url1 = []

for i in range(0,1150):
    url1.insert(i, reviews['URL 1'][i])
    
len(url1)
# Out:
# 1150

# %%
url2 = []

for i in range(0,1150):
    url2.insert(i, reviews_clean['URL 2'][i])
    
len(url2)
# Out:
# 1150

# %%
url2[1149]
# Out:
# 'https://mydramalist.com/people/2686-park-geon-il'

# %%
url1.extend(url2)

# %%
url1[2299]
# Out:
# 'https://mydramalist.com/people/2686-park-geon-il'

# %%
url1 = []

for i in range(0,1150):
    url1.insert(i, reviews_clean['URL 1'][i])

url2 = []

for i in range(0,1150):
    url2.insert(i, reviews_clean['URL 2'][i])

url1.extend(url2)

# %%
len(url1)
# Out:
# 2300

# %%
reviews_clean = reviews_clean.drop(["URL 1", "URL 2"], 1)

# %%
reviews1 = reviews_clean.iloc[:, 0:5]

# %%
reviews2 = reviews_clean.drop('Actor 1', 1)
reviews2['Actor 1'] = reviews2['Actor 2']

# %%
reviews2
# Out:
#                           Title  Ratings                    Ranked  \
# 0     Strong Woman Do Bong Soon      8.7                       #84
# 1                     The Heirs      7.5                     #2787
# 2                     Pinocchio      8.4                      #265
# 3                        Goblin      8.9                       #33
# 4                             W      8.5                      #196
# ...                         ...      ...                       ...
# 1145        Love Playlist Pilot      7.5   15+ - Teens 15 or older
# 1146              Love Teenager      6.9             Not Yet Rated
# 1147    My Wonderful Roommate 2      7.0                    #99999
# 1148             Life of Namjoo      7.3                    #34194
# 1149         Case Cell Division     10.0                    #99999
#
#           Popularity          Actor 1
# 0                 #2  Park Hyung Shik
# 1                 #8    Park Shin Hye
# 2                 #9    Park Shin Hye
# ...

# %%
reviews2 = reviews2.drop('Actor 2', 1)

# %%
reviews3 = pd.concat([reviews1, reviews2])

# %%
reviewsfinal = reviews3.sort_values(by = "Actor 1")

reviewsfinal = reviewsfinal.reset_index().drop("index", 1)

# %%
info = pd.read_csv("info.csv")

# %%
len(info)
# Out:
# 2300

# %%
info = info.sort_values(by = "Name").reset_index().drop("index", 1)

# %%
final = pd.concat([reviewsfinal, info], axis = 1)

# %%
final = final.sort_values(by = "Title").reset_index().drop("index", 1)

# %%
final.to_csv("final.csv")

# %%
review=pd.read_csv("review.csv")

# %%
review.groupby("title").count()
# Out:
#                            review
# title
# 100 Days My Prince              5
# 109 Strange Things              1
# 18 Again                        6
# 20th Century Boy and Girl       1
# 21st Century Family             1
# ...                           ...
# Your Lady                       1
# Your Neighbor's Wife            1
# Youth Syndrome                  0
# beautiology101                  1
# ≥75℃                            1
#
# [1186 rows x 1 columns]

# %%
import pandas as pd
final = pd.read_csv("final.csv")

# %%
final
# Out:
#       Unnamed: 0                 Title  Ratings   Ranked Popularity  \
# 0              0    100 Days My Prince      8.3     #354       #160
# 1              1    100 Days My Prince      8.3     #354       #160
# 2              2    109 Strange Things      6.8    #4530      #2377
# 3              3    109 Strange Things      6.8    #4530      #2377
# 4              4              18 Again      8.8      #44       #287
# ...          ...                   ...      ...      ...        ...
# 2295        2295             Your Lady      7.3   #35426      #8049
# 2296        2296  Your Neighbor's Wife      7.3   #34929      #7790
# 2297        2297  Your Neighbor's Wife      7.3   #34929      #7790
# 2298        2298        beautiology101      7.6    #2588      #2432
# 2299        2299        beautiology101      7.6    #2588      #2432
#
#              Actor 1            Name   Info Info1  \
# 0       Do Kyung Soo    Do Kyung Soo     Do   도경수
# ...

# %%
male = final.loc[final['Info4'] == ' Male']

# %%
female = final.loc[final['Info4'] == " Female"]

# %%
remaining = final.loc[final['Info4'] != " Female"]

# %%
weird = remaining.loc[remaining['Info4'] != " Male"]

# %%
weird
# Out:
#       Unnamed: 0                          Title  Ratings   Ranked  \
# 5              5                       18 Again      8.8      #44
# 14            14  380,000 km Between You and Me      7.9   #28054
# 16            16               4 Kinds of House      7.5    #2775
# 20            20                        49 Days      8.3     #438
# 23            23                 7 First Kisses      6.9    #4427
# ...          ...                            ...      ...      ...
# 2274        2274           You Don't Know Women      7.3   #35432
# 2275        2275           You Don't Know Women      7.3   #35432
# 2276        2276              You Make Me Dance      8.1     #840
# 2281        2281               You Will Love Me      6.8    #6077
# 2285        2285               You're Only Mine      7.2   #36653
#
#           Popularity         Actor 1            Name   Info Info1  \
# 5               #287     Kim Ha Neul     Kim Ha Neul    Kim   김하늘
# ...

# %%
weird["Info4"] = weird["Info3"]
# Out:
# <ipython-input-57-b628bd22b624>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weird["Info4"] = weird["Info3"]

# %%
weird
# Out:
#       Unnamed: 0                          Title  Ratings   Ranked  \
# 5              5                       18 Again      8.8      #44
# 14            14  380,000 km Between You and Me      7.9   #28054
# 16            16               4 Kinds of House      7.5    #2775
# 20            20                        49 Days      8.3     #438
# 23            23                 7 First Kisses      6.9    #4427
# ...          ...                            ...      ...      ...
# 2274        2274           You Don't Know Women      7.3   #35432
# 2275        2275           You Don't Know Women      7.3   #35432
# 2276        2276              You Make Me Dance      8.1     #840
# 2281        2281               You Will Love Me      6.8    #6077
# 2285        2285               You're Only Mine      7.2   #36653
#
#           Popularity         Actor 1            Name   Info Info1  \
# 5               #287     Kim Ha Neul     Kim Ha Neul    Kim   김하늘
# ...

# %%
finalfinal = pd.concat([female, male, weird], axis = 0).drop(["Actor 1", "Info", "Info1", "Info2", "Info3", "Info5", "Info6"], axis = 1)

# %%
finalfinal = finalfinal.sort_values("Title")

# %%
finalfinal = finalfinal.reset_index().drop(['index', 'Unnamed: 0'], axis = 1)

# %%
finalfinal = finalfinal.rename(columns={"Info4": "Gender"})

# %%
finalfinal
# Out:
#                      Title  Ratings   Ranked Popularity            Name  \
# 0       100 Days My Prince      8.3     #354       #160     Nam Ji Hyun
# 1       100 Days My Prince      8.3     #354       #160    Do Kyung Soo
# 2       109 Strange Things      6.8    #4530      #2377  Choi  Tae Joon
# 3       109 Strange Things      6.8    #4530      #2377  Jung Chae Yeon
# 4                 18 Again      8.8      #44       #287     Kim Ha Neul
# ...                    ...      ...      ...        ...             ...
# 2295             Your Lady      7.3   #35426      #8049           Im Ho
# 2296  Your Neighbor's Wife      7.3   #34929      #7790    Yeom Jung Ah
# 2297  Your Neighbor's Wife      7.3   #34929      #7790  Shin Eun Kyung
# 2298        beautiology101      7.6    #2588      #2432   Kim Jae Young
# 2299        beautiology101      7.6    #2588      #2432      Han Ji Eun
#
#        Gender                                   Image
# ...

# %%
finalfinal.to_csv("final.csv")

# %%
finalfinal
# Out:
#                      Title  Ratings   Ranked Popularity            Name  \
# 0       100 Days My Prince      8.3     #354       #160     Nam Ji Hyun
# 1       100 Days My Prince      8.3     #354       #160    Do Kyung Soo
# 2       109 Strange Things      6.8    #4530      #2377  Choi  Tae Joon
# 3       109 Strange Things      6.8    #4530      #2377  Jung Chae Yeon
# 4                 18 Again      8.8      #44       #287     Kim Ha Neul
# ...                    ...      ...      ...        ...             ...
# 2295             Your Lady      7.3   #35426      #8049           Im Ho
# 2296  Your Neighbor's Wife      7.3   #34929      #7790    Yeom Jung Ah
# 2297  Your Neighbor's Wife      7.3   #34929      #7790  Shin Eun Kyung
# 2298        beautiology101      7.6    #2588      #2432   Kim Jae Young
# 2299        beautiology101      7.6    #2588      #2432      Han Ji Eun
#
#        Gender                                   Image
# ...

# %%
title = ['Goblin', 'Strong Woman Do Bong Soon',
 'Descendants of the Sun',
 'W',
 'You Who Came from the Stars',
 'Weightlifting Fairy Kim Bok Joo',
 'The Heirs',
 'Pinocchio',
 'Healer',
 "What's Wrong with Secretary Kim",
 'While You Were Sleeping',
 'Moon Lovers: Scarlet Heart Ryeo',
 'Secret Garden',
 'Kill Me, Heal Me',
 'The Legend of the Blue Sea',
 'Crash Landing on You',
 'City Hunter',
 'I Hear Your Voice',
 'She Was Pretty',
 "I'm Not a Robot",
 'Cheese in the Trap',
 'Fight For My Way',
 'Hotel del Luna',
 "The Master's Sun",
 "It's Okay to Not Be Okay",
 'Suspicious Partner',
 "It's Okay, That's Love",
 'Oh My Ghostess',
 'Playful Kiss',
 'Dream High',
 'Cinderella and the Four Knights',
 'Oh My Venus',
 'Reply 1997',
 'My ID Is Gangnam Beauty',
 'Personal Taste',
 'Because This is My First Life',
 'Itaewon Class',
 'The K2',
 'Hwarang',
 'Who Are You: School 2015',
 'Heartstrings',
 'To The Beautiful You',
 'Her Private Life',
 'My Girlfriend Is a Gumiho',
 'Love in the Moonlight',
 'Reply 1988',
 'Doctor Stranger',
 'A Korean Odyssey',
 'Doctors',
 'Romance is a Bonus Book',
 'Flower Boy Next Door',
 'My Secret Romance',
 'Uncontrollably Fond',
 'Rooftop Prince',
 'The Bride of Habaek',
 'Extraordinary You',
 'The King: Eternal Monarch',
 'Fated to Love You',
 'Bring It On, Ghost',
 'Touch Your Heart',
 'Just Between Lovers',
 'Love Alarm',
 'Are You Human Too?',
 'Moon Embracing the Sun',
 'Age of Youth',
 'Sassy Go Go',
 'He Is Psychometric',
 "Queen In Hyun's Man",
 'Emergency Couple',
 'Memories of the Alhambra',
 'Introverted Boss',
 'The Innocent Man',
 'Marriage, Not Dating',
 'Faith',
 'Shopping King Louie',
 'Thirty But Seventeen',
 'The Beauty Inside',
 'True Beauty',
 "Angel's Last Mission: Love",
 'Another Miss Oh',
 'Prison Playbook',
 'Abyss',
 'Hospital Playlist',
 'Shut Up: Flower Boy Band',
 'Sungkyunkwan Scandal',
 'Blood',
 'Chicago Typewriter',
 'Flower Boy Ramen Shop',
 'Flower of Evil',
 'The Great Seducer',
 'Gu Family Book',
 'School 2017',
 'Eulachacha Waikiki',
 'Something in the Rain',
 'King2Hearts',
 'Mr. Sunshine',
 'Start-Up',
 'Lie to Me',
 'The Girl Who Sees Scents',
 'EXO Next Door',
 '49 Days',
 "You're All Surrounded",
 'Dr. Romantic',
 'Love Rain',
 'Good Doctor',
 'Black',
 'Tale of the Nine-Tailed',
 'Hi! School - Love On',
 'Dream High 2',
 'Reply 1994',
 'The Smile Has Left Your Eyes',
 'Jealousy Incarnate',
 'Moorim School',
 'My First First Love',
 'When the Camellia Blooms',
 'Protect the Boss',
 'Search: WWW',
 'The Tale of Nokdu',
 'Big',
 'Come and Hug Me',
 'Empress Ki',
 'Something About 1 Percent',
 'That Winter, The Wind Blows',
 "A Gentleman's Dignity",
 'Falling for Innocence',
 'Orange Marmalade',
 'Melting Me Softly',
 'The Producers',
 'Secret',
 '100 Days My Prince',
 'Tomorrow With You',
 'Hit the Top',
 'Clean With Passion For Now',
 'The Liar and His Lover',
 'Lawless Lawyer',
 '7 First Kisses',
 'Mary Stayed Out All Night',
 'The Secret Life of My Secretary',
 'Hyde, Jekyll, Me',
 'Radio Romance',
 'The Scholar Who Walks the Night',
 'Missing You',
 'The Greatest Love',
 'Noble, My Love',
 'My Princess',
 'The Bridal Mask',
 'Birth of a Beauty',
 'My Holo Love',
 'Beautiful Gong Shim',
 'Cunning Single Lady',
 'Arang and the Magistrate',
 'When the Weather Is Fine',
 'Go Back Couple',
 'Record of Youth',
 'High Society',
 'Age of Youth 2',
 'Where Your Eyes Linger',
 'My Strange Hero',
 'Remember: War of the Son',
 'Lucky Romance',
 'Bride of the Century',
 'Run On',
 'Encounter',
 'Monstar',
 "Witch's Romance",
 'Please Come Back, Mister',
 'Rookie Historian Goo Hae Ryung',
 'The World of the Married',
 'Dr. Romantic 2',
 'Miss Hammurabi',
 'High School King of Savvy',
 'One Spring Night',
 'Mask',
 'Mr. Queen',
 'Surplus Princess',
 'Man to Man',
 'Madame Antoine',
 'Cruel City',
 'Terius Behind Me',
 'A Beautiful Mind',
 'Backstreet Rookie',
 'Yong Pal',
 'Where Stars Land',
 'The Lover',
 'Long Time No See',
 'My Father is Strange',
 'My Lovely Girl',
 'About Time',
 'Queen of the Ring',
 '18 Again',
 'Hi Bye, Mama!',
 'Bel Ami',
'Arthdal Chronicles Part 1: The Children of Prophecy',
 "The Princess's Man",
 "Go Ho's Starry Night",
 'My First First Love 2',
 'Scent of a Woman',
 'Doctor John',
 'Temperature of Love',
 'Moment at Eighteen',
 'The Hymn of Death',
 'Angel Eyes',
 'Who Are You',
 'Love with Flaws',
 'Prosecutor Princess',
 'High-end Crush',
 'Six Flying Dragons',
 'Missing 9',
 'Do Do Sol Sol La La Sol',
 'King of Baking, Kim Tak Goo',
 'Meow, the Secret Boy',
 'Devilish Joy',
 'Wok of Love',
 'Panda and Hedgehog',
 'K-POP - The Ultimate Audition',
 'The Emperor: Owner of the Mask',
 'Hotel King',
 'D-Day',
 'Twenty Again',
 "Ho Goo's Love",
 'Mirror of the Witch',
 'Dream Knight',
 'Marriage Contract',
 'Strongest Deliveryman',
 'Rich Man',
 'One More Happy Ending',
 'The Time We Were Not in Love',
 'Oh! My Lady',
 'Find Me in Your Memory',
 'A Piece of Your Mind',
 'Revolutionary Love',
 'Prime Minister and I',
 'Warm and Cozy',
 'Can You Hear My Heart',
 "Let's Eat",
 'Be Melodramatic',
 'Color Rush',
 'Live Up to Your Name',
 'The Last Empress',
 'Cheongdamdong Alice',
 'My Only Love Song',
 'I Need Romance 3',
 'Mr. Heart',
 'Full House Take 2',
 'Me too, Flower!',
 'Ma Boy',
 'Lovestruck in the City',
 'Nine: Nine Times Time Travel',
 'My Absolute Boyfriend',
 'The Light in Your Eyes',
 'Queen for Seven Days',
 'Pasta',
 "Cinderella's Sister",
 'Marry Him If You Dare',
 'Live',
 'Chocolate',
 'The Boy Next Door',
 'A Poem a Day',
 "Witch's Love",
 'Familiar Wife',
 'The Crowned Clown',
 'My Country: The New Age',
 "Naeil's Cantabile",
 'Jugglers',
 'Eulachacha Waikiki 2',
 'Heart to Heart',
 'Drinking Solo',
 'Click Your Heart',
 'Rebel: Thief Who Stole the People',
 'You Are The Best!',
 'Dinner Mate',
 'Trot Lovers',
 'A-Teen',
 'My Secret Hotel',
 'I  Do, I Do',
 "Because It's The First Time",
 'Discovery of Romance',
 'Star of the Universe',
 'Modern Farmer',
 'Sweet Revenge',
 'Do You Like Brahms?',
 'One More Time',
 'Warrior Baek Dong Soo',
 'Wild Romance',
 'Catch the Ghost',
 'The Package',
 'Wednesday 3:30 PM',
 'Secret Love Affair',
 'Dating Agency: Cyrano',
 'The Third Charm',
 'Twenty Years Old',
 'Was It Love?',
 'The Undateables',
 'Arthdal Chronicles Part 3: The Prelude To All Legends',
 'Somehow 18',
 'More Than Friends',
 'Forest',
 'Pride and Prejudice',
 'Myung Wol the Spy',
 'The King of Dramas',
 'My Love Eun Dong',
 'Private Lives',
 'Plus Nine Boys',
 'Perfume',
 'Nail Shop Paris',
 'The King in Love',
 '7th Grade Civil Servant',
 'Dong Yi',
 'Wish You: Your Melody From My Heart',
 'To My Star',
 'What Happens to My Family?',
 'Operation Proposal',
 'Hyena',
 'Black Knight: The Man Who Guards Me',
 'I Need Romance',
 'A Love So Beautiful',
 'Padam Padam',
 'Triangle',
 'I Picked Up a Star on the Road',
 "When A Man's in Love",
 'Baby-faced Beauty',
 'Dramaworld',
 'Radiant Office',
 'Time Slip Dr. Jin',
 'Flower Crew: Joseon Marriage Agency',
 'Gunman In Joseon',
 'Your Honor',
 'Money Flower',
 "Let's Eat 2",
 'Stars Falling From the Sky',
 'I Need Romance 2',
 'Born Again',
 'When My Love Blooms',
 'Bad Guy',
 'My Unfortunate Boyfriend',
 'Live On',
 'Into the Ring',
 'Choco Bank',
 'Oh My Baby',
 'Inspiring Generation',
 'Mama Fairy and the Woodcutter',
 'Misty',
 'The Ghost Detective',
 'My Fellow Citizens!',
 'Can We Get Married?',
 'Chuno',
 'XX',
 'Your House Helper',
 "What's Up?",
 'My Beautiful Bride',
 'Jang Ok Jung',
 'My Golden Life',
 'When Time Stopped',
 'Ugly Alert',
 'Five Enough',
 'Coffee House',
 "Girls' Generation 1979",
 'Best Wedding',
 'On The Way To The Airport',
 'Feel Good To Die',
 'Lie After Lie',
 'Kiss Goblin',
 'Best Mistake',
 'Possessed',
 'Once Again',
 'Soul Mechanic',
 'Love Revolution',
 'Twenty-Twenty',
 'Haechi',
 'When I Was the Most Beautiful',
 "Please Don't Date Him",
 'Cheat On Me, If You Can',
 'Queen of Ambition',
 'Wild Chives and Soy Bean Soup: 12 Years Reunion',
 'The Incarnation of Money',
 'All About My Romance',
 'Love Affairs in the Afternoon',
 'Valid Love',
 'Queen: Love And War',
 'Sweet Munchies',
 'New Tales of Gisaeng',
 'Temptation',
'My Heart Twinkle Twinkle']

# %%
len(title)
# Out:
# 383

# %%
title
# Out:
# ['Goblin',
#  'Strong Woman Do Bong Soon',
#  'Descendants of the Sun',
#  'W',
#  'You Who Came from the Stars',
#  'Weightlifting Fairy Kim Bok Joo',
#  'The Heirs',
#  'Pinocchio',
#  'Healer',
#  "What's Wrong with Secretary Kim",
#  'While You Were Sleeping',
#  'Moon Lovers: Scarlet Heart Ryeo',
#  'Secret Garden',
#  'Kill Me, Heal Me',
#  'The Legend of the Blue Sea',
#  'Crash Landing on You',
#  'City Hunter',
#  'I Hear Your Voice',
#  'She Was Pretty',
#  "I'm Not a Robot",
#  'Cheese in the Trap',
#  'Fight For My Way',
#  'Hotel del Luna',
#  "The Master's Sun",
#  "It's Okay to Not Be Okay",
#  'Suspicious Partner',
#  "It's Okay, That's Love",
#  'Oh My Ghostess',
#  'Playful Kiss',
#  'Dream High',
#  'Cinderella and the Four Knights',
#  'Oh My Venus',
#  'Reply 1997',
#  'My ID Is Gangnam Beauty',
#  'Personal Taste',
#  'Because This is My First Life',
#  'Itaewon Class',
#  'The K2',
#  'Hwarang',
#  'Who Are You: School 2015',
#  'Heartstrings',
# ...

# %%
finalfinal = finalfinal[finalfinal.Title.isin(title)].reset_index().drop("index", axis = 1)

# %%
finalfinal[finalfinal.Title == "Once Again"]
# Out:
#           Title  Ratings   Ranked Popularity         Name   Gender  \
# 458  Once Again      7.4   #33773     #99999     Park Jun     Male
# 459  Once Again      8.5     #221      #1107  Chun Ho Jin     Male
# 460  Once Again      8.5     #221      #1107  Cha Hwa Yun   Female
# 461  Once Again      7.4   #33773     #99999   Han Ji Hye   Female
#
#                                       Image
# 458  https://i.mydramalist.com/RgngR_5c.jpg
# 459    https://i.mydramalist.com/pkNw8c.jpg
# 460    https://i.mydramalist.com/43l46c.jpg
# 461  https://i.mydramalist.com/Qlrv4_5c.jpg

# %%
final.shape
# Out:
# (2300, 15)

# %%
final.to_csv("final.csv")

# %%
len(final.Title.unique())
# Out:
# 1147

# %%
final.drop_duplicates(keep = False, inplace = True)

# %%
final = final.drop([353,354,458,461,738,741])

# %%
final = final.reset_index().drop("index", axis = 1)

# %%
final = pd.read_csv("final.csv")

# %%
final
# Out:
#       Unnamed: 0  Unnamed: 0.1                 Title  Ratings   Ranked  \
# 0              0             0    100 Days My Prince      8.3     #354
# 1              1             1    100 Days My Prince      8.3     #354
# 2              2             2    109 Strange Things      6.8    #4530
# 3              3             3    109 Strange Things      6.8    #4530
# 4              4             4              18 Again      8.8      #44
# ...          ...           ...                   ...      ...      ...
# 2295        2295          2295             Your Lady      7.3   #35426
# 2296        2296          2296  Your Neighbor's Wife      7.3   #34929
# 2297        2297          2297  Your Neighbor's Wife      7.3   #34929
# 2298        2298          2298        beautiology101      7.6    #2588
# 2299        2299          2299        beautiology101      7.6    #2588
#
#      Popularity         Actor 1            Name   Info Info1  \
# ...

# %%
f = final[final.Gender == " Female"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-ded15b5268ee> in <module>
# ----> 1 f = final[final.Gender == " Female"]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Gender'

# %%
f

# %%
f = f.drop_duplicates(subset = ['Title'], keep = False)

# %%
f

# %%
m = final[final.Gender == " Male"]

# %%
m

# %%
m = m.drop_duplicates(subset = ['Title'], keep = False)

# %%
m

# %%
final = pd.concat([m,f], axis = 0).sort_values("Title").reset_index().drop("index", axis = 1)

# %%
final.to_csv("final.csv")

# %%
arr = final.Title.values

# %%
list1 = arr.tolist()

# %%
drama = pd.read_csv("kdramaclean.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bec3d2c5104e> in <module>
# ----> 1 drama = pd.read_csv("kdramaclean.csv")
#
# NameError: name 'pd' is not defined

# %%
cd kdrama
# Out:
# /Users/valencialie/Desktop/CZ1016_DS2/kdrama

# %%
list1 = ['100 Days My Prince',
 '100 Days My Prince',
 '18 Again',
 '18 Again',
 '7th Grade Civil Servant',
 '7th Grade Civil Servant',
 'A Beautiful Mind',
 'A Beautiful Mind',
 "A Gentleman's Dignity",
 "A Gentleman's Dignity",
 'A Korean Odyssey',
 'A Korean Odyssey',
 'A Love So Beautiful',
 'A Love So Beautiful',
 'A Piece of Your Mind',
 'A Piece of Your Mind',
 'A Poem a Day',
 'A Poem a Day',
 'About Time',
 'About Time',
 'Abyss',
 'Abyss',
 'All About My Romance',
 'All About My Romance',
 'Angel Eyes',
 'Angel Eyes',
 "Angel's Last Mission: Love",
 "Angel's Last Mission: Love",
 'Another Miss Oh',
 'Another Miss Oh',
 'Arang and the Magistrate',
 'Arang and the Magistrate',
 'Are You Human Too?',
 'Are You Human Too?',
 'Arthdal Chronicles Part 1: The Children of Prophecy',
 'Arthdal Chronicles Part 1: The Children of Prophecy',
 'Arthdal Chronicles Part 3: The Prelude To All Legends',
 'Arthdal Chronicles Part 3: The Prelude To All Legends',
 'Baby-faced Beauty',
 'Baby-faced Beauty',
 'Backstreet Rookie',
 'Backstreet Rookie',
 'Bad Guy',
 'Bad Guy',
 'Beautiful Gong Shim',
 'Beautiful Gong Shim',
 "Because It's The First Time",
 "Because It's The First Time",
 'Because This is My First Life',
 'Because This is My First Life',
 'Bel Ami',
 'Bel Ami',
 'Best Mistake',
 'Best Mistake',
 'Best Wedding',
 'Best Wedding',
 'Big',
 'Big',
 'Birth of a Beauty',
 'Birth of a Beauty',
 'Black',
 'Black',
 'Black Knight: The Man Who Guards Me',
 'Black Knight: The Man Who Guards Me',
 'Blood',
 'Blood',
 'Born Again',
 'Born Again',
 'Bride of the Century',
 'Bride of the Century',
 'Bring It On, Ghost',
 'Bring It On, Ghost',
 'Can We Get Married?',
 'Can We Get Married?',
 'Catch the Ghost',
 'Catch the Ghost',
 'Cheat On Me, If You Can',
 'Cheat On Me, If You Can',
 'Cheese in the Trap',
 'Cheese in the Trap',
 'Cheongdamdong Alice',
 'Cheongdamdong Alice',
 'Chicago Typewriter',
 'Chicago Typewriter',
 'Choco Bank',
 'Choco Bank',
 'Chocolate',
 'Chocolate',
 'Chuno',
 'Chuno',
 'Cinderella and the Four Knights',
 'Cinderella and the Four Knights',
 "Cinderella's Sister",
 "Cinderella's Sister",
 'City Hunter',
 'City Hunter',
 'Clean With Passion For Now',
 'Clean With Passion For Now',
 'Click Your Heart',
 'Click Your Heart',
 'Coffee House',
 'Coffee House',
 'Come and Hug Me',
 'Come and Hug Me',
 'Crash Landing on You',
 'Crash Landing on You',
 'Cruel City',
 'Cruel City',
 'Cunning Single Lady',
 'Cunning Single Lady',
 'D-Day',
 'D-Day',
 'Dating Agency: Cyrano',
 'Dating Agency: Cyrano',
 'Descendants of the Sun',
 'Descendants of the Sun',
 'Devilish Joy',
 'Devilish Joy',
 'Dinner Mate',
 'Dinner Mate',
 'Discovery of Romance',
 'Discovery of Romance',
 'Do Do Sol Sol La La Sol',
 'Do Do Sol Sol La La Sol',
 'Do You Like Brahms?',
 'Do You Like Brahms?',
 'Doctor John',
 'Doctor John',
 'Doctor Stranger',
 'Doctor Stranger',
 'Doctors',
 'Doctors',
 'Dong Yi',
 'Dong Yi',
 'Dramaworld',
 'Dramaworld',
 'Dream High',
 'Dream High',
 'Dream High 2',
 'Dream High 2',
 'Dream Knight',
 'Dream Knight',
 'Drinking Solo',
 'Drinking Solo',
 'EXO Next Door',
 'EXO Next Door',
 'Emergency Couple',
 'Emergency Couple',
 'Empress Ki',
 'Empress Ki',
 'Encounter',
 'Encounter',
 'Extraordinary You',
 'Extraordinary You',
 'Faith',
 'Faith',
 'Falling for Innocence',
 'Falling for Innocence',
 'Familiar Wife',
 'Familiar Wife',
 'Fated to Love You',
 'Fated to Love You',
 'Feel Good To Die',
 'Feel Good To Die',
 'Fight For My Way',
 'Fight For My Way',
 'Find Me in Your Memory',
 'Find Me in Your Memory',
 'Five Enough',
 'Five Enough',
 'Flower Boy Next Door',
 'Flower Boy Next Door',
 'Flower Boy Ramen Shop',
 'Flower Boy Ramen Shop',
 'Flower Crew: Joseon Marriage Agency',
 'Flower Crew: Joseon Marriage Agency',
 'Flower of Evil',
 'Flower of Evil',
 'Forest',
 'Forest',
 'Full House Take 2',
 'Full House Take 2',
 'Go Back Couple',
 'Go Back Couple',
 "Go Ho's Starry Night",
 "Go Ho's Starry Night",
 'Goblin',
 'Goblin',
 'Good Doctor',
 'Good Doctor',
 'Gu Family Book',
 'Gu Family Book',
 'Gunman In Joseon',
'Gunman In Joseon',
 'Haechi',
 'Haechi',
 'He Is Psychometric',
 'He Is Psychometric',
 'Healer',
 'Healer',
 'Heart to Heart',
 'Heart to Heart',
 'Heartstrings',
 'Heartstrings',
 'Her Private Life',
 'Her Private Life',
 'Hi Bye, Mama!',
 'Hi Bye, Mama!',
 'Hi! School - Love On',
 'Hi! School - Love On',
 'High School King of Savvy',
 'High School King of Savvy',
 'High Society',
 'High Society',
 'High-end Crush',
 'High-end Crush',
 'Hit the Top',
 'Hit the Top',
 "Ho Goo's Love",
 "Ho Goo's Love",
 'Hotel King',
 'Hotel King',
 'Hotel del Luna',
 'Hotel del Luna',
 'Hwarang',
 'Hwarang',
 'Hyde, Jekyll, Me',
 'Hyde, Jekyll, Me',
 'Hyena',
 'Hyena',
 'I  Do, I Do',
 'I  Do, I Do',
 'I Hear Your Voice',
 'I Hear Your Voice',
 'I Need Romance',
 'I Need Romance',
 'I Need Romance 2',
 'I Need Romance 2',
 'I Need Romance 3',
 'I Need Romance 3',
 'I Picked Up a Star on the Road',
 'I Picked Up a Star on the Road',
 "I'm Not a Robot",
 "I'm Not a Robot",
 'Inspiring Generation',
 'Inspiring Generation',
 'Into the Ring',
 'Into the Ring',
 'Introverted Boss',
 'Introverted Boss',
 "It's Okay to Not Be Okay",
 "It's Okay to Not Be Okay",
 "It's Okay, That's Love",
 "It's Okay, That's Love",
 'Itaewon Class',
 'Itaewon Class',
 'Jang Ok Jung',
 'Jang Ok Jung',
 'Jealousy Incarnate',
 'Jealousy Incarnate',
 'Jugglers',
 'Jugglers',
 'Just Between Lovers',
 'Just Between Lovers',
 'K-POP - The Ultimate Audition',
 'K-POP - The Ultimate Audition',
 'Kill Me, Heal Me',
 'Kill Me, Heal Me',
 'King2Hearts',
 'King2Hearts',
 'Kiss Goblin',
 'Kiss Goblin',
 'Lawless Lawyer',
 'Lawless Lawyer',
 "Let's Eat",
 "Let's Eat",
 "Let's Eat 2",
 "Let's Eat 2",
 'Lie After Lie',
 'Lie After Lie',
 'Lie to Me',
 'Lie to Me',
 'Live',
 'Live',
 'Live On',
 'Live On',
 'Live Up to Your Name',
 'Live Up to Your Name',
 'Love Affairs in the Afternoon',
 'Love Affairs in the Afternoon',
 'Love Alarm',
 'Love Alarm',
 'Love Rain',
 'Love Rain',
 'Love Revolution',
 'Love Revolution',
 'Love in the Moonlight',
 'Love in the Moonlight',
 'Love with Flaws',
 'Love with Flaws',
 'Lovestruck in the City',
 'Lovestruck in the City',
 'Lucky Romance',
 'Lucky Romance',
 'Ma Boy',
 'Ma Boy',
 'Madame Antoine',
 'Madame Antoine',
 'Man to Man',
 'Man to Man',
 'Marriage Contract',
 'Marriage Contract',
 'Marriage, Not Dating',
 'Marriage, Not Dating',
 'Marry Him If You Dare',
 'Marry Him If You Dare',
 'Mary Stayed Out All Night',
 'Mary Stayed Out All Night',
 'Mask',
 'Mask',
 'Me too, Flower!',
 'Me too, Flower!',
 'Melting Me Softly',
 'Melting Me Softly',
 'Memories of the Alhambra',
 'Memories of the Alhambra',
 'Meow, the Secret Boy',
 'Meow, the Secret Boy',
 'Mirror of the Witch',
 'Mirror of the Witch',
 'Miss Hammurabi',
 'Miss Hammurabi',
 'Missing 9',
 'Missing 9',
 'Missing You',
 'Missing You',
 'Misty',
 'Misty',
 'Modern Farmer',
 'Modern Farmer',
 'Moment at Eighteen',
 'Moment at Eighteen',
 'Money Flower',
 'Money Flower',
 'Monstar',
 'Monstar',
 'Moon Embracing the Sun',
 'Moon Embracing the Sun',
 'Moon Lovers: Scarlet Heart Ryeo',
 'Moon Lovers: Scarlet Heart Ryeo',
 'More Than Friends',
 'More Than Friends',
 'Mr. Queen',
 'Mr. Queen',
 'Mr. Sunshine',
 'Mr. Sunshine',
 'My Absolute Boyfriend',
 'My Absolute Boyfriend',
 'My Beautiful Bride',
 'My Beautiful Bride',
 'My Father is Strange',
 'My Father is Strange',
 'My Fellow Citizens!',
 'My Fellow Citizens!',
 'My First First Love',
 'My First First Love',
 'My First First Love 2',
 'My First First Love 2',
 'My Girlfriend Is a Gumiho',
 'My Girlfriend Is a Gumiho',
 'My Golden Life',
 'My Golden Life',
 'My Heart Twinkle Twinkle',
 'My Heart Twinkle Twinkle',
 'My Holo Love',
 'My Holo Love',
 'My ID Is Gangnam Beauty',
 'My ID Is Gangnam Beauty',
 'My Love Eun Dong',
 'My Love Eun Dong',
 'My Lovely Girl',
 'My Lovely Girl',
 'My Only Love Song',
 'My Only Love Song',
 'My Princess',
 'My Princess',
 'My Secret Hotel',
 'My Secret Hotel',
 'My Secret Romance',
 'My Secret Romance',
 'My Strange Hero',
 'My Strange Hero',
 'My Unfortunate Boyfriend',
'My Unfortunate Boyfriend',
 'Myung Wol the Spy',
 'Myung Wol the Spy',
 "Naeil's Cantabile",
 "Naeil's Cantabile",
 'Nail Shop Paris',
 'Nail Shop Paris',
 'New Tales of Gisaeng',
 'New Tales of Gisaeng',
 'Noble, My Love',
 'Noble, My Love',
 'Oh My Baby',
 'Oh My Baby',
 'Oh My Venus',
 'Oh My Venus',
 'Oh! My Lady',
 'Oh! My Lady',
 'On The Way To The Airport',
 'On The Way To The Airport',
 'Once Again',
 'Once Again',
 'One More Happy Ending',
 'One More Happy Ending',
 'One More Time',
 'One More Time',
 'One Spring Night',
 'One Spring Night',
 'Orange Marmalade',
 'Orange Marmalade',
 'Padam Padam',
 'Padam Padam',
 'Pasta',
 'Pasta',
 'Perfume',
 'Perfume',
 'Personal Taste',
 'Personal Taste',
 'Pinocchio',
 'Pinocchio',
 'Playful Kiss',
 'Playful Kiss',
 'Please Come Back, Mister',
 'Please Come Back, Mister',
 "Please Don't Date Him",
 "Please Don't Date Him",
 'Possessed',
 'Possessed',
 'Pride and Prejudice',
 'Pride and Prejudice',
 'Prime Minister and I',
 'Prime Minister and I',
 'Private Lives',
 'Private Lives',
 'Prosecutor Princess',
 'Prosecutor Princess',
 'Protect the Boss',
 'Protect the Boss',
 "Queen In Hyun's Man",
 "Queen In Hyun's Man",
 'Queen for Seven Days',
 'Queen for Seven Days',
 'Queen of Ambition',
 'Queen of Ambition',
 'Queen of the Ring',
 'Queen of the Ring',
 'Queen: Love And War',
 'Queen: Love And War',
 'Radiant Office',
 'Radiant Office',
 'Radio Romance',
 'Radio Romance',
 'Rebel: Thief Who Stole the People',
 'Rebel: Thief Who Stole the People',
 'Record of Youth',
 'Record of Youth',
 'Reply 1988',
 'Reply 1988',
 'Reply 1994',
 'Reply 1994',
 'Reply 1997',
 'Reply 1997',
 'Revolutionary Love',
 'Revolutionary Love',
 'Rich Man',
 'Rich Man',
 'Romance is a Bonus Book',
 'Romance is a Bonus Book',
 'Rooftop Prince',
 'Rooftop Prince',
 'Rookie Historian Goo Hae Ryung',
 'Rookie Historian Goo Hae Ryung',
 'Run On',
 'Run On',
 'Sassy Go Go',
 'Sassy Go Go',
 'Scent of a Woman',
 'Scent of a Woman',
 'School 2017',
 'School 2017',
 'Secret',
 'Secret',
 'Secret Garden',
 'Secret Garden',
 'Secret Love Affair',
 'Secret Love Affair',
 'She Was Pretty',
 'She Was Pretty',
 'Shopping King Louie',
 'Shopping King Louie',
 'Shut Up: Flower Boy Band',
 'Shut Up: Flower Boy Band',
 'Somehow 18',
 'Somehow 18',
 'Something About 1 Percent',
 'Something About 1 Percent',
 'Something in the Rain',
 'Something in the Rain',
 'Soul Mechanic',
 'Soul Mechanic',
 'Star of the Universe',
 'Star of the Universe',
 'Stars Falling From the Sky',
 'Stars Falling From the Sky',
 'Start-Up',
 'Start-Up',
 'Strong Woman Do Bong Soon',
 'Strong Woman Do Bong Soon',
 'Strongest Deliveryman',
 'Strongest Deliveryman',
 'Sungkyunkwan Scandal',
 'Sungkyunkwan Scandal',
 'Surplus Princess',
 'Surplus Princess',
 'Suspicious Partner',
 'Suspicious Partner',
 'Sweet Munchies',
 'Sweet Munchies',
 'Sweet Revenge',
 'Sweet Revenge',
 'Tale of the Nine-Tailed',
 'Tale of the Nine-Tailed',
 'Temperature of Love',
 'Temperature of Love',
 'Temptation',
 'Temptation',
 'Terius Behind Me',
 'Terius Behind Me',
 'That Winter, The Wind Blows',
 'That Winter, The Wind Blows',
 'The Beauty Inside',
 'The Beauty Inside',
 'The Bridal Mask',
 'The Bridal Mask',
 'The Bride of Habaek',
 'The Bride of Habaek',
 'The Crowned Clown',
 'The Crowned Clown',
 'The Emperor: Owner of the Mask',
 'The Emperor: Owner of the Mask',
 'The Ghost Detective',
 'The Ghost Detective',
 'The Girl Who Sees Scents',
 'The Girl Who Sees Scents',
 'The Great Seducer',
 'The Great Seducer',
 'The Greatest Love',
 'The Greatest Love',
 'The Heirs',
 'The Heirs',
 'The Hymn of Death',
 'The Hymn of Death',
 'The Incarnation of Money',
 'The Incarnation of Money',
 'The Innocent Man',
 'The Innocent Man',
 'The K2',
 'The K2',
 'The King in Love',
 'The King in Love',
 'The King of Dramas',
 'The King of Dramas',
 'The King: Eternal Monarch',
 'The King: Eternal Monarch',
 'The Last Empress',
 'The Last Empress',
 'The Legend of the Blue Sea',
 'The Legend of the Blue Sea',
 'The Liar and His Lover',
 'The Liar and His Lover',
'The Lover',
 'The Lover',
 "The Master's Sun",
 "The Master's Sun",
 'The Package',
 'The Package',
 "The Princess's Man",
 "The Princess's Man",
 'The Producers',
 'The Producers',
 'The Scholar Who Walks the Night',
 'The Scholar Who Walks the Night',
 'The Secret Life of My Secretary',
 'The Secret Life of My Secretary',
 'The Smile Has Left Your Eyes',
 'The Smile Has Left Your Eyes',
 'The Tale of Nokdu',
 'The Tale of Nokdu',
 'The Third Charm',
 'The Third Charm',
 'The Time We Were Not in Love',
 'The Time We Were Not in Love',
 'The Undateables',
 'The Undateables',
 'The World of the Married',
 'The World of the Married',
 'Thirty But Seventeen',
 'Thirty But Seventeen',
 'Time Slip Dr. Jin',
 'Time Slip Dr. Jin',
 'To The Beautiful You',
 'To The Beautiful You',
 'Tomorrow With You',
 'Tomorrow With You',
 'Touch Your Heart',
 'Touch Your Heart',
 'Trot Lovers',
 'Trot Lovers',
 'True Beauty',
 'True Beauty',
 'Twenty Again',
 'Twenty Again',
 'Twenty Years Old',
 'Twenty Years Old',
 'Twenty-Twenty',
 'Twenty-Twenty',
 'Ugly Alert',
 'Ugly Alert',
 'Uncontrollably Fond',
 'Uncontrollably Fond',
 'Valid Love',
 'Valid Love',
 'W',
 'W',
 'Warm and Cozy',
 'Warm and Cozy',
 'Was It Love?',
 'Was It Love?',
 'Wednesday 3:30 PM',
 'Wednesday 3:30 PM',
 'Weightlifting Fairy Kim Bok Joo',
 'Weightlifting Fairy Kim Bok Joo',
 'What Happens to My Family?',
 'What Happens to My Family?',
 "What's Wrong with Secretary Kim",
 "What's Wrong with Secretary Kim",
 "When A Man's in Love",
 "When A Man's in Love",
 'When I Was the Most Beautiful',
 'When I Was the Most Beautiful',
 'When My Love Blooms',
 'When My Love Blooms',
 'When Time Stopped',
 'When Time Stopped',
 'When the Camellia Blooms',
 'When the Camellia Blooms',
 'When the Weather Is Fine',
 'When the Weather Is Fine',
 'Where Stars Land',
 'Where Stars Land',
 'While You Were Sleeping',
 'While You Were Sleeping',
 'Who Are You',
 'Who Are You',
 'Who Are You: School 2015',
 'Who Are You: School 2015',
 'Wild Chives and Soy Bean Soup: 12 Years Reunion',
 'Wild Chives and Soy Bean Soup: 12 Years Reunion',
 'Wild Romance',
 'Wild Romance',
 "Witch's Love",
 "Witch's Love",
 "Witch's Romance",
 "Witch's Romance",
 'Yong Pal',
 'Yong Pal',
 'You Are The Best!',
 'You Are The Best!',
 'You Who Came from the Stars',
 'You Who Came from the Stars',
 "You're All Surrounded",
 "You're All Surrounded",
 'Your Honor',
 'Your Honor',
 'Your House Helper',
 'Your House Helper']

# %%
drama = pd.read_csv("kdramaclean.csv")

# %%
drama
# Out:
#       Unnamed: 0                        Title  \
# 0              0                       Goblin
# 1              1    Strong Woman Do Bong Soon
# 2              2       Descendants of the Sun
# 3              3                            W
# 4              4  You Who Came from the Stars
# ...          ...                          ...
# 1185        1185        The Reason I Hate You
# 1186        1186            You I Didn't Know
# 1187        1187          Love Playlist Pilot
# 1188        1188               Life of Namjoo
# 1189        1189           Case Cell Division
#
#                                   Info  Ratings  \
# 0     Korean Drama - 2016, 16 episodes      8.9
# 1     Korean Drama - 2017, 16 episodes      8.7
# 2     Korean Drama - 2016, 16 episodes      8.7
# 3     Korean Drama - 2016, 16 episodes      8.5
# 4     Korean Drama - 2013, 21 episodes      8.6
# ...                                ...      ...
# 1185   Korean Drama - 2020, 3 episodes      6.9
# ...

# %%
drama = drama[drama.Title.isin(list1)]

# %%
drama = drama.drop([820,767,1182])

# %%
drama = drama.reset_index().drop("index", axis = 1)

# %%
drama
# Out:
#      Unnamed: 0                        Title  \
# 0             0                       Goblin
# 1             1    Strong Woman Do Bong Soon
# 2             2       Descendants of the Sun
# 3             3                            W
# 4             4  You Who Came from the Stars
# ..          ...                          ...
# 339         487          Queen: Love And War
# 340         517               Sweet Munchies
# 341         535         New Tales of Gisaeng
# 342         553                   Temptation
# 343         657     My Heart Twinkle Twinkle
#
#                                  Info  Ratings  \
# 0    Korean Drama - 2016, 16 episodes      8.9
# 1    Korean Drama - 2017, 16 episodes      8.7
# 2    Korean Drama - 2016, 16 episodes      8.7
# 3    Korean Drama - 2016, 16 episodes      8.5
# 4    Korean Drama - 2013, 21 episodes      8.6
# ..                                ...      ...
# 339  Korean Drama - 2019, 16 episodes      7.8
# ...

# %%
drama.to_csv("drama.csv")

# %%
list1 = []

for i in range(0,344):
    list1.insert(i, drama.URL[i])

# %%
half = drama['URL'].values
links = ['https://www.mydramalist.com' + i for i in half]

# %%
links
# Out:
# ['https://www.mydramalist.com/18452-goblin',
#  'https://www.mydramalist.com/18894-strong-woman-do-bong-soon',
#  'https://www.mydramalist.com/10904-descendants-of-the-sun',
#  'https://www.mydramalist.com/16589-w',
#  'https://www.mydramalist.com/7398-you-who-came-from-the-stars',
#  'https://www.mydramalist.com/19262-weightlifting-fairy-kim-bok-joo',
#  'https://www.mydramalist.com/6640-the-heirs',
#  'https://www.mydramalist.com/11074-pinocchio',
#  'https://www.mydramalist.com/10814-healer',
#  'https://www.mydramalist.com/27885-why-secretary-kim',
#  'https://www.mydramalist.com/21576-while-you-were-sleeping',
#  'https://www.mydramalist.com/15999-moon-lovers-scarlet-heart-ryeo',
#  'https://www.mydramalist.com/8-secret-garden-2010',
#  'https://www.mydramalist.com/10873-kill-me-heal-me',
#  'https://www.mydramalist.com/18816-the-legend-of-the-blue-sea',
#  'https://www.mydramalist.com/35729-emergency-lands-of-love',
#  'https://www.mydramalist.com/1702-city-hunter-2011',
# ...

# %%
reviews = pd.read_csv("reviews 2.csv")

# %%
reviews
# Out:
#                                Title     Character1     Character2  \
# 0                                  W    Oh Yeon Joo      Kang Chul
# 1    What's Wrong with Secretary Kim      Kim Mi So            NaN
# 2        You Who Came from the Stars    Do Min Joon  Cheon Song Yi
# 3                             Goblin            NaN     Ji Eun Tak
# 4    Weightlifting Fairy Kim Bok Joo            NaN            NaN
# ..                               ...            ...            ...
# 339         My Heart Twinkle Twinkle            NaN            NaN
# 340                       Temptation            NaN            NaN
# 341                   Sweet Munchies  Park Jin Sung            NaN
# 342                       Valid Love            NaN            NaN
# 343              Queen: Love And War            NaN      Lee Gyung
#
#                     Character3       Character4
# 0                          NaN              NaN
# 1                          NaN   Lee Young Joon
# ...

# %%
a1 = reviews[(reviews.Character1.isna() == True) & (reviews.Character2.isna() == True)]

# %%
a1.Character1 = a1.Character3
a1.Character2 = a1.Character4
# Out:
# /Users/valencialie/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
a1
# Out:
#                                Title                               Character1  \
# 4    Weightlifting Fairy Kim Bok Joo                              Kim Bok Joo
# 6                          Pinocchio                Choi Dal Po / Ki Ha Myung
# 8          Strong Woman Do Bong Soon                             Do Bong Soon
# 9               Crash Landing on You                             Ri Jung Hyuk
# 11                            Healer  Seo Jung Hoo / Park Bong Soo / "Healer"
# ..                               ...                                      ...
# 334         The Incarnation of Money              Lee Cha Don / Lee Kang Seok
# 337             New Tales of Gisaeng                               Dan Sa Ran
# 339         My Heart Twinkle Twinkle                             Lee Soon Jin
# 340                       Temptation                             Yoo Se Young
# 342                       Valid Love                             Jang Hee Tae
#
# ...

# %%
b1 = reviews[(reviews.Character1.isna() == True) & (reviews.Character2.isna() == False)]

# %%
b1.Character1 = b1.Character3
# Out:
# /Users/valencialie/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
b1
# Out:
#                               Title  \
# 3                            Goblin
# 24                     Playful Kiss
# 40             To The Beautiful You
# 54                My Secret Romance
# 60                Fated to Love You
# 69                            Faith
# 72             Thirty But Seventeen
# 77                 The Innocent Man
# 78                            Abyss
# 118           Falling for Innocence
# 126                Hyde, Jekyll, Me
# 131                     Missing You
# 141                    My Holo Love
# 159                            Mask
# 160                      Man to Man
# 164                      Cruel City
# 171                        Yong Pal
# 186                 Love with Flaws
# 191             Prosecutor Princess
# 196  The Emperor: Owner of the Mask
# 199                    Dream Knight
# 208            A Piece of Your Mind
# 209                        Rich Man
# 219                 Me too, Flower!
# 222                The Last Empress
# ...

# %%
c1 = reviews[(reviews.Character1.isna() == False) & (reviews.Character2.isna() == True)]

# %%
c1.Character2 = c1.Character4
# Out:
# /Users/valencialie/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
d1 = reviews[(reviews.Character1.isna() == False) & (reviews.Character2.isna() == False)]

# %%
d1
# Out:
#                                                  Title  \
# 0                                                    W
# 2                          You Who Came from the Stars
# 5                               Descendants of the Sun
# 7                                            The Heirs
# 10                                       Secret Garden
# 15                          The Legend of the Blue Sea
# 25                                  Cheese in the Trap
# 27                                          Dream High
# 29                                          Reply 1997
# 49                                Flower Boy Next Door
# 59                                  He Is Psychometric
# 73                                         True Beauty
# 84                                      Flower of Evil
# 94                               Something in the Rain
# 95                                           Love Rain
# 108                                My First First Love
# ...

# %%
len(a1) +len(b1) + len(c1) + len(d1)
# Out:
# 344

# %%
fin = pd.concat([a1, b1,c1,d1]).drop(["Character3", "Character4"], axis = 1).sort_values("Title")

# %%
cd Desktop
# Out:
# /Users/valencialie/Desktop

# %%
final = pd.read_csv("final.csv")

# %%
fin
# Out:
#                            Title                           Character1  \
# 119           100 Days My Prince  Crown Prince Lee Yool / Na Won Deuk
# 168                     18 Again                         Jung Da Jung
# 274      7th Grade Civil Servant            Han Gil Ro / Han Pil Hoon
# 166             A Beautiful Mind                         Lee Young Oh
# 113        A Gentleman's Dignity                           Kim Do Jin
# ..                           ...                                  ...
# 241            You Are The Best!                        Lee Soon Shin
# 2    You Who Came from the Stars                          Do Min Joon
# 96         You're All Surrounded             Eun Dae Gu / Kim Ji Yong
# 293                   Your Honor             Han Kang Ho / Han Soo Ho
# 314            Your House Helper                          Kim Ji Woon
#
#                         Character2
# 119        Hong Shim / Yoon Yi Seo
# 168  Hong Dae Young [37 years old]
# ...

# %%
fin1 = fin.drop("Character1", 1)
fin2 = fin.drop("Character2", 1).sort_values("Title")

fin1 = fin1.rename(columns={"Character2": "Character1"})

# %%
fin1 = fin1.sort_values("Title")

# %%
finfin = pd.concat([fin2,fin1], 0)

# %%
finfin = finfin.sort_values("Title")

# %%
finfin = finfin.drop("Title", 1)

# %%
finfin = finfin.reset_index().drop("index", 1)

# %%
final = final.join(finfin).drop(["Unnamed: 0", "Unnamed: 0.1"],1)

# %%
final.to_csv("final.csv")
