# %%
# scrapy changes to make review format better

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import re

# %%
import nltk
# nltk.download('stopwords')
# nltk.download('vader_lexicon')
# nltk.download('punkt')
# nltk.download('maxent_ne_chunker')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('words')
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [raw]
# import spacy
# from spacy.matcher import PhraseMatcher
# nlp = spacy.load("en_core_web_lg")
# matcher = PhraseMatcher(nlp.vocab)
# casts = ['Gong Yoo','Kim Shin','Kim Go Eun','Ji Eun Tak']
# # Only run nlp.make_doc to speed things up
# patterns = [nlp.make_doc(cast) for cast in casts]
# matcher.add("CastList", patterns)
# doc = nlp('Every scene Gong Yoo was in was a treat. Every emotion that Gong Yoo had was palpable, and Gong Yoo smiles could light up the sky.And Kim Go Eun as Ji Eun Tak was super cute.')
# matches = matcher(doc)
# while len(matches)!= 0:
#     start = matches[0][1]
#     end = matches[0][2]
#     with doc.retokenize() as retokenizer:
#         retokenizer.merge(doc[start:end])
#     matches = matcher(doc)
# # EMAXPLE:
# # for token in doc:
# #     print(token.text, token.ent_type_)

# %% [raw]
# def name_comb(casts): # pass in the casts list
#     cast = []
#     for i in range(len(casts)):
#         names = []
#         char = casts[i].split()
#         comb = [(c,c.lower()) for c in char]
#         if len(char) == 2:
#             for char1 in comb[0]:
#                 for char2 in comb[1]:
#                     names.append(char1+char2)
#                     names.append(char1+' '+char2)
#                     names.append(char1+'-'+char2)
#             names.append(char[0][0]+char[1][0])
#         elif len(char) == 3:
#             for char1 in comb[0]:
#                 for char2 in comb[1]:
#                     for char3 in comb[2]:
#                         names.append(char2+char3)
#                         names.append(char2+' '+char3)
#                         names.append(char2+'-'+char3)
#                         names.append(char1+' '+char2+char3)
#                         names.append(char1+' '+char2+' '+char3)
#                         names.append(char1+' '+char2+'-'+char3)
#             names.append(char[0][0]+char[1][0]+char[2][0])
#         names.sort(key=len,reverse=True) # why we need this: if replace Kim Go-eun, replace Go-eun with Kim Go Eun then it will become Kim Kim Go Eun
#         cast.append(names)
#     return cast

# %% [raw]
# def name_comb(casts): # pass in the casts list
#     cast = []
#     for i in range(len(casts)):
#         names = []
#         comb = [char.lower() for char in casts[i].split()]
# #         char = casts[i].split()
# #         comb = [c.lower() for c in char]
#         if len(comb) == 2:
#             char1 = comb[0]
#             char2 = comb[1]
#             names.append(char1+char2)
#             names.append(char1+' '+char2)
#             names.append(char1+'-'+char2)
#             names.append(char1[0]+char2[0])
#         elif len(comb) == 3:
#             char1 = comb[0]
#             char2 = comb[1]
#             char3 = comb[2]
#             names.append(char2+char3)
#             names.append(char2+' '+char3)
#             names.append(char2+'-'+char3)
#             names.append(char1+' '+char2+char3)
#             names.append(char1+' '+char2+' '+char3)
#             names.append(char1+' '+char2+'-'+char3)
#             names.append(char1[0]+char2[0]+char3[0])
#         cast.append(names)
#     return cast

# %%
# before chem, just match male lead and female lead and group, add ent
# after filter based on chemistry keyword
# based on token.ent_type_ == 'PERSON', retokenize

# OR we have a list for all main role
# the rest is grouped when processing

# %%
temp = pd.read_csv('temp.csv').drop(columns='Unnamed: 0')
temp
# Out:
#       title                                             review
# 0    Goblin  If you are hesitating to watch this at all, pl...
# 1    Goblin  I feel compelled to write a review for Goblin ...
# 2    Goblin  It must be said that Goblin is very much a som...
# 3    Goblin  Every moment of it indeed shined! Goblin is a ...
# 4    Goblin  Somewhere inside Goblin, buried under a mound ...
# ..      ...                                                ...
# 286  Goblin  I honestly say that Goblin is one of my favori...
# 287  Goblin  well I love everything about this drama also t...
# 288  Goblin  Best korean drama of the year!! Already re-wat...
# 289  Goblin  Interesting drama about the folklore of Dokkae...
# 290  Goblin  There is a compelling story, interesting chara...
#
# [291 rows x 2 columns]

# %%
mystr = 'I like this girl called kim-Go-Eun'
# doc = nlp('and kim go Eun as Eun-Tak are super cute')

casts = ['Gong Yoo', 'Kim Shin', 'Kim Go Eun', 'Ji Eun Tak', 'Lee Dong Wook', 'Yoo In Na', 'Yook Sung Jae', 'Yoo Duk Hwa']
# 'Grim Reaper', 'Sunny'
import spacy
from spacy.matcher import Matcher
from spacy.lang.en import English
nlp = spacy.load('en_core_web_lg')
@English.component("replace_cast")
def replace_cast(doc):
    name_matcher = Matcher(nlp.vocab)
    for cast in casts:
        cast_pattern = []
        name = cast.split()
        if len(name)==2:
            char1 = name[0].lower()
            char2 = name[1].lower()
            pt1 = [{'LOWER': char1+char2}]
#             pt2 = [{'LOWER': char1[0]+char2[0]}]
            pt3 = [{'LOWER': char1}, {'TEXT': '-', 'OP': '?'}, {'LOWER': char2}] 
            cast_pattern.append(pt1)
            cast_pattern.append(pt2)
            cast_pattern.append(pt3)
            name_matcher.add(cast, cast_pattern)
        elif len(name)==3:
            char1 = name[0].lower()
            char2 = name[1].lower()
            char3 = name[2].lower()
            pt1 = [{'LOWER': char1, 'OP': '?'}, {'LOWER': char2+char3}] 
            pt2 = [{'TEXT': char1[0].upper()+char2[0].upper()+char3[0].upper()}]
            pt3 = [{'LOWER': char1, 'OP': '?'}, {'TEXT': '-', 'OP': '?'}, {'LOWER': char2}, {'TEXT': '-', 'OP': '?'}, {'LOWER': char3}]
            cast_pattern.append(pt1)
            cast_pattern.append(pt2)
            cast_pattern.append(pt3)
            name_matcher.add(cast, cast_pattern)
    count = 1
    name_matches = name_matcher(doc)
    while count <= len(name_matches):
        match_id, start, end = name_matches[count-1]
        rep = nlp.vocab.strings[match_id]
        newDoc = doc[:start].text+' '+rep+' '+doc[end:].text 
        doc = nlp.make_doc(newDoc.strip()) # f" {replacement}"
        name_matches = name_matcher(doc)
        if len(rep.split())==2: # if name is two chars, +1
            count += 1
        else:
            count += 2
    return doc
nlp.add_pipe('replace_cast', first=True)
# 我们先replace第一个match，再match的时候前两个一定是刚刚修改过的match。第三个
# 是新的match。再修改它，再match的时候前四个是刚才修改的match。看第五个，没有第五个match了，不需要再修改了
# Out:
# <function __main__.replace_cast(doc)>

# %%
nlp.pipe_names
nlp(txt)
spacy.load('en_core_web_lg')
# Out:
# ['replace_cast',
#  'tok2vec',
#  'tagger',
#  'parser',
#  'ner',
#  'attribute_ruler',
#  'lemmatizer']

# %%
from spacy.matcher import PhraseMatcher
from spacy.tokens import Span
# from spacy.lang.en import English
# nlp = spacy.load('en_core_web_lg')  # use directly
# matcher = PhraseMatcher(nlp.vocab)
# patterns = [nlp.make_doc(cast) for cast in casts]
# matcher.add("CastList", patterns)
@English.component("group_cast")
def group_cast(doc):
    matcher = PhraseMatcher(nlp.vocab)
    patterns = [nlp.make_doc(cast) for cast in casts] 
    matcher.add("CastList", patterns)
    matches = matcher(doc)
    while len(matches)!= 0:
        match_id, start, end = matches[0]
        span = Span(doc, start, end, "PERSON")
#         if span not in list(doc.ents):
#             doc.ents = list(doc.ents) + [span]
#         else:
#             doc.ents = [span if span==ent else ent for ent in list(doc.ents)]
        with doc.retokenize() as retokenizer:
            retokenizer.merge(span)
        matches = matcher(doc)
        
#         ruler = nlp.add_pipe("entity_ruler", after='ner')
#         ruler.add_patterns(patterns)



    return doc
nlp.add_pipe('group_cast')
# Out:
# <function __main__.group_cast(doc)>

# %%
trylist = ['a', 'b', 'c']
span = ['a']
[span if span==ent else ent for ent in trylist]
# Out:
# ['a', 'b', 'c']

# %%
nlp.pipe_names
# Out:
# ['replace_cast',
#  'tok2vec',
#  'tagger',
#  'parser',
#  'ner',
#  'attribute_ruler',
#  'lemmatizer',
#  'group_cast']

# %%
temp = temp.groupby('title').aggregate({'review':'sum'})
text = temp.review[0]
text
# Out:
# 'If you are hesitating to watch this at all, please, just throw out your reservations and watch this. Goblin has just made my favorites list. Even my husband got sucked in and loves this show. The cinematography was gorgeous, the music was amazing, the actors were perfect (Hello, Gong Yoo!), the story was heartbreakingly beautiful. This is the first time I\'ve watched any of the main actors except Gong Yoo In Na. I have now officially developed a Gong Yoo crush and understand why drama fans are enamored of Gong Yoo. Gong Yoo as Kim Shin/ Goblin was mesmerizing. I could listen to Gong Yoo voice for days. Every scene Gong Yoo was in was a treat. Every emotion that Gong Yoo had was palpable, and Gong Yoo smiles could light up the sky. And Kim Go Eun as Ji Eun Tak was super cute. Ji Eun Tak had a lot of detractors and the writer got a lot of flak for making Ji Eun Tak so young. But the character and Ji Eun Tak age were perfect for this story and how it unfolded. Lee Dong Wook as the Grim Reaper had the perfect deadpan (heh) delivery. And Lee Dong Wook may be the best male "crier" I\'ve seen yet. the story will make you laugh and make you cry. Not only is the love story epic, but so is the bromance between Goblin and Reaper. I\'ve found that I\'m quite fond of this fantasy genre and this has been done so well. I have hardly any criticisms of this show at all because even the flaws faded into nothing noticeable for me. It\'s sweet, funny, romantic, sad, tragic, beautiful, The music was perfect and perfectly lovely. I don\'t always pay much attention to The music, but this show utilized It so well and chose the perfect songs. So many people loved even the intro song that So many people made a special recording of It to make It a full length song (Round and Round, but may also be found under Never Far Away). Beautiful by Crush was the best song in my opinion, and I believe that it was the theme song for our main couple. And Stay With me by Chanyeol and Punch was another favorite. Rewatch value is high if not everything, then there are many, many favorite scenes that I\'ll go back to and relive the feels. :)I feel compelled to write a review for Goblin because I\'m finding all the perfect 10s to be misleading and, if I can be honest, completely confounding. Let me first say the best thing about Goblin is the acting. The cast is fantastic. The worst is the age gap. I know most people talk about the age of the actors; however, the issue to those of us that have a problem with the age isn\'t the actors, it\'s the characters. The lead female character is a 19 year old girl. The lead male (taking out the fantasy of The lead female character living 938 years) is a grown man who appears almost 40, Personally, I find that the Korean\'s have been dancing too close to the line in the young girls with adult men in dramas for at least a year now and I\'m not a fan. They\'re more daddy issue characters. There are many times when the relationship between the 2 leads are most like Father  and  daughter. daughter speaks to The lead female character like a father figure. And The lead female character speaks to daughter as a child. It\'s off putting when it becomes clear that The lead female character has fallen for this high school girl. Part of me believes the part of Kim Shin (the Goblin) was written for a younger man. Considering the life expectancy of the period and a younger man postion, in a younger man late 30s a younger man should have had a wife (and concubines I would guess) and children. I think a younger man should have been at least 10 years younger (again the 900 years undead aside). The romance of the leads just did not work for me on any level. Conversely, the romance between the supports is a completely different story. It was endearing and very moving. I rooted for them. The writing was inconsistent. The writing was great in some parts and just passable in others. Toward the end the end almost turned into melodramatic schlock. Goblin  ...

# %%
lines = re.split(';\s*|:\s*|!\s*|\?\s*|\.\s*', text) # |,\s*
lines = [line for line in lines if not line.isspace()] # get rid of whitespace str
lines = [line for line in lines if line]
lines
# Out:
# ['If you are hesitating to watch this at all, please, just throw out your reservations and watch this',
#  'Goblin has just made my favorites list',
#  'Even my husband got sucked in and loves this show',
#  'The cinematography was gorgeous, the music was amazing, the actors were perfect (Hello, Gong Yoo',
#  '), the story was heartbreakingly beautiful',
#  "This is the first time I've watched any of the main actors except Gong Yoo In Na",
#  'I have now officially developed a Gong Yoo crush and understand why drama fans are enamored of Gong Yoo',
#  'Gong Yoo as Kim Shin/ Goblin was mesmerizing',
#  'I could listen to Gong Yoo voice for days',
#  'Every scene Gong Yoo was in was a treat',
#  'Every emotion that Gong Yoo had was palpable, and Gong Yoo smiles could light up the sky',
#  'And Kim Go Eun as Ji Eun Tak was super cute',
#  'Ji Eun Tak had a lot of detractors and the writer got a lot of flak for making Ji Eun Tak so young',
#  'But the character and Ji Eun Tak age were perfect for this story and how it unfolded',
#  'Lee Dong Wook as the Grim Reaper had the perfect deadpan (heh) delivery',
#  'And Lee Dong Wook may be the best male "crier" I\'ve seen yet',
#  'the story will make you laugh and make you cry',
#  'Not only is the love story epic, but so is the bromance between Goblin and Reaper',
#  "I've found that I'm quite fond of this fantasy genre and this has been done so well",
#  'I have hardly any criticisms of this show at all because even the flaws faded into nothing noticeable for me',
#  "It's sweet, funny, romantic, sad, tragic, beautiful, The music was perfect and perfectly lovely",
#  "I don't always pay much attention to The music, but this show utilized It so well and chose the perfect songs",
#  'So many people loved even the intro song that So many people made a special recording of It to make It a full length song (Round and Round, but may also be found under Never Far Away)',
#  'Beautiful by Crush was the best song in my opinion, and I believe that it was the theme song for our main couple',
#  'And Stay With me by Chanyeol and Punch was another favorite',
#  "Rewatch value is high if not everything, then there are many, many favorite scenes that I'll go back to and relive the feels",
#  ")I feel compelled to write a review for Goblin because I'm finding all the perfect 10s to be misleading and, if I can be honest, completely confounding",
#  'Let me first say the best thing about Goblin is the acting',
#  'The cast is fantastic',
#  'The worst is the age gap',
#  'I know most people talk about the age of the actors',
#  "however, the issue to those of us that have a problem with the age isn't the actors, it's the characters",
#  'The lead female character is a 19 year old girl',
#  "The lead male (taking out the fantasy of The lead female character living 938 years) is a grown man who appears almost 40, Personally, I find that the Korean's have been dancing too close to the line in the young girls with adult men in dramas for at least a year now and I'm not a fan",
#  "They're more daddy issue characters",
#  'There are many times when the relationship between the 2 leads are most like Father  and  daughter',
#  'daughter speaks to The lead female character like a father figure',
#  'And The lead female character speaks to daughter as a child',
#  "It's off putting when it becomes clear that The lead female character has fallen for this high school girl",
#  'Part of me believes the part of Kim Shin (the Goblin) was written for a younger man',
#  'Considering the life expectancy of the period and a younger man postion, in a younger man late 30s a younger man should have had a wife (and concubines I would guess) and children',
#  'I think a younger man should have been at least 10 years younger (again the 900 years undead aside)',
#  'The romance of the leads just did not work for me on any level',
#  'Conversely, the romance between the supports is a completely different story',
#  'It was endearing and very moving',
#  'I rooted for them',
#  'The writing was inconsistent',
#  'The writing was great in some parts and just passable in others',
#  'Toward the end the end almost turned into melodramatic schlock',
#  'Goblin works best as a bromance',
#  'The scenes between Goblin, Reaper(s), and the male humans were precious golden nuggets to hold onto until the next time 2 or 3 of the male humans were in a scene together',
#  'Had the writers held on to that chemistry and nourished that chemistry, Goblin would have been much better',
#  "It must be said that Goblin is very much a somewhat clich rom-com disguising Goblin as something else, but ultimately, what appears to be an interesting premise is cast aside for a romantic plot that I'm going to be honest is a little creepy and at times feels very fatherly to me",
#  'This makes it very hard to love the romance especially when the female lead is a bubble of cutesy energy and also the romance borderline looks twelve',
#  'There were moments I wanted to run into the scene and tell Gong Yoo, you get the hell away from the romance and date someone your own age',
#  'Yes, that, 782 age gap was at times hard to swallow',
#  "What makes Goblin good is Goblin good's featuring",
#  "Goblin good stars longing looks, teary-eyed longing looks, bromance, ignoring that he is 800 years old, trying to pretend you are not watching this because of the bromance and good looking leads and KES's obligatory three good episodes towards the end that makes you think this is so good",
#  'It also stars a very good performance by Lee Dong Wook',
#  "I'd like to say the rest of the cast were just as good, but I'd be lying",
#  'Gong Yoo is someone, I watch because Gong Yoo is in good movies (The Crucible/Silenced, etc) but not because Gong Yoo gives an actual good performance',
#  "Gong Yoo's like a Brad Pitt type in that regard",
#  "I was quite surprised by LDW as I find Gong Yoo heavily attractive and have for a long time but I've admitted Gong Yoo's a terrible actor",
#  'Suddenly Gong Yoo is Matthew McConaughaying me',
#  'The female lead is literally a copy paste of all rom-coms',
#  'Especially from this writer',
#  'The intro of this drama is unique and creates what has the potential to be a very good plot, but ultimately this is a meandering slow stream of a journey that I heavily recommend you skip some episodes',
#  "Yes, skip from ep 5 to 13 and you'll miss very little",
#  'The juicy parts of the plot are thrown aside for a slew of teary-eyed longing looks and clich romantic scenes that at ep 4, I started to wonder when The juicy parts of the plot were actually going to focus on the juicy premise',
#  'Character wise, the bromance sells the plot as personally, the romance between the male and female lead just looks awkward',
#  'I should be gushing at romantic scenes but The juicy parts of the plot look as uncomfortable as I do and when Gong Yoo pats Gong Yoo head, Gong Yoo at times feels like Gong Yoo father',
#  "this drama has a lot of potential but this writer didn't seem to know what to do with this drama and I feel like a traitor who deserves to be hanged for saying this, but as a huge lover of bromance, dare I say it, I actually got bored of the bromance",
#  'I started tuning in to cast longing looks at Lee Dong Wook',
#  "My obsession made me run out into the street and jump in front of a car, but I heavily recommend you don't do that as the Grim Reaper never appeared and now I'm writing this in the afterlife",
#  'this writer also inserts this writer I suckered you into thinking this was good by having this writer obligatory three good episodes that make me think, Oh this has potential',
#  "It's always towards the end too",
#  'Melancholic episodes with good editing that make me wonder where was this for the previous ten episodes',
#  'I feel this drama is a seven at best as in, I would be very generous to give this drama a 7, this drama has this drama good melancholic and humorous scenes but this drama ultimately never quite gets this drama pacing right and never seems to know what to focus on making this really not as good as it could be',
#  'PS',
#  'I also urge you to cast aside any logical questions you might have especially towards the end',
#  'They will not be answered',
#  'Every moment of it indeed shined',
#  'Goblin is a great drama',
#  'I went into it with low expectations, but I was pleasantly surprised, or more accurately, I was blown away',
#  'You can recognize a good drama by the way it makes you feel exactly what the characters in a great drama are feeling',
#  "That's the way Goblin was for me, with each character, I laughed and I cried",
#  "I'll TRY to keep the review sweet and short, so here are the reasons I enjoyed Goblin",
#  'The premise is unique',
#  "The premise's one of a kind",
#  "I haven't seen any other Kdramas with a similar plot-line to Goblin, so that was a plus point",
#  'The actors do a superb job',
#  'I could feel The actors emotions from across the screen',
#  'then again, nothing less to be expected from such a spectacular cast',
#  'a great drama has everything, ranging from bromance, romance to mystery and suspense',
#  'The bromance is spectacular',
#  "One of the most epic bromance I've ever seen in a Kdrama",
#  'The bromance made me laugh a lot, but The bromance also had The bromance heartwarming and heart-wrenching moments',
#  "Goblin and Grim Reaper's relationship is one of the best reasons to pick this up",
#  'The two couples- Goblin  and  Eun Tak and Grim Reaper  and  Sunny',
#  'Both couples had Both couples own story',
#  "The sweet and cute moments of the Goblin couple  and  the sizzling chemistry between Grim Reaper and Sunny was enough to keep the 'romance' meter of a great drama pretty high",
#  "You won't be able to get enough of the cuteness of Goblin  and  Eun Tak",
#  'The mystery of the characters',
#  "From 'the lady in red' to the king and queen, each episode just gave enough glimpse into their lives to keep us engrossed",
#  "It'll drive you crazy in a good way",
#  'Each minute of every episode was enjoyable',
#  "I didn't skip a single moment of any episode",
#  'The unexpectedness of a great drama was really great',
#  "Just when you'd think you had something figured out, some twist would come along and surprise you",
#  'The writer sure did a tremendous job',
#  'BONUS',
#  "Beautiful and addictive OST I personally didn't find anything even remotely bad about it, but that's not to say other people won't, so here's a few things you should keep in mind before venturing into it",
#  'The age difference between Goblin [ (~939) Goblin was 39 when Goblin died and then immortal for 900 years] and Eun Tak (19)',
#  'Comparatively less screen time for Sunny and Grim Reaper couple',
#  "But I suppose that's to be expected specially since the title alone indicates that Kim Shin (Goblin) is the main lead, so it's no wonder they get the most screen time",
#  "Worst product placement you'll ever see in a Kdrama",
#  "You might think I'm kidding but sometimes even the smallest thing can annoy you",
#  'I personally found those scenes amusing though',
#  'So, to sum up- I LOVED a great drama',
#  "Do give this one a chance, you won't be disappointed",
#  "Once you start this one, chances are, you'll end up loving this one",
#  'Happy Watching',
#  'Somewhere inside Goblin, buried under a mound of PPL and tears, is a good show trying to get out',
#  'The first two episodes suggest what might have been, deftly mixing intense action and off-beat humor in a dark world filled with ominous reapers, wounded goblins, ghost-seeing teenagers and cabbage-wielding grannies',
#  'The stage seems set for a life and death clash of epic proportions',
#  'Alas, it soon becomes apparent that the writer forgot to include an antagonist',
#  'The goblin-reaper face-off devolves into a chummy bromance, leaving fate to play the role of spoiler',
#  'Unfortunately, The goblin-reaper face-off s hard to fight disembodied destiny',
#  'Whole episodes are spent weeping in pretty scenery and eating Subway sandwiches',
#  'The talented cast tries to up the urgency, but with nothing tangible to battle, the pacing slows to a crawl',
#  'The extended episode lengths and the director s tendency to linger a little too long on every moment exacerbate the problem',
#  'Even the romance falters on the uncomfortable age gap between the protagonists',
#  'Every so often',
#  'interesting ideas pop up about guilt, redemption, and the role of kindness in a cosmos more random than rewarding',
#  'Alas, the fickle gods that rule this universe stay above the fray',
#  'A drama that actually allowed this universe characters to take its characters on rather than simply lamenting its characters cruelty could have been powerful indeed',
#  'I was going to give it a 7 but there were too many things that bothered me, too many plot holes',
#  'I enjoyed watching this drama more times than not',
#  'It was relaxing to look at, with the great cinematography and breathtaking sceneries',
#  'Music was great and very fitting',
#  'The actors were more or less very fitting in The actors roles and felt natural',
#  'The chemistry between the male cast was flawless',
#  'I guess my main and only issue here is the writing',
#  'There are two types of supernatural dramas',
#  'the one that explores human emotions through the supernatural',
#  'and the ones that use it to tell your usual story',
#  'I think Goblin was somewhere in between',
#  'I still appreciate some points of the writing',
#  'What I dislike is the plot as a whole',
#  'I liked the overall idea but not the execution',
#  'I like the idea of supernatural and powerful beings, like ghosts, goblins, grim reapers and gods, are living normally among humans without being noticed',
#  'I liked the story of the little boy we meet early in this drama to see his fate and effect on the Goblin (and vice versa)',
#  "I loved the heartfelt story of Eun Tak's ghost friend, and enjoyed the company of the group of Ahjuma ghosts",
#  'What I greatly disliked is the way the main story arc was handled',
#  'At first it felt overly dramatic, but later it felt so underwhelming that it removes and intensity felt before',
#  'When it ended the way it did, I felt there was no point to the whole story',
#  'Essentially were back to point zero',
#  'I think the writer has some original ideas, but no guts to go deeper',
#  'As a result interesting topics were touched lightly, but never went beyond, hence felt shallow',
#  'I wish more time was spend in exploring the world, getting more concrete information on how demons are created and how to deal with demons',
#  "Instead you just follow the characters' daily life of not doing much, and supernatural elements were just used as a convenience",
#  "When it comes to romance, I didn't care much about the age difference due to the supernatural part of it, but I just didn't enjoy it, I didn't feel it",
#  "I don't know when it happened",
#  'Also Goblin was beyond childish',
#  'Goblin was too moody and unbearable at times',
#  'While I was more invested into the secondary couple, I still felt the same, as in a missing episode of I was more invested into the secondary couple going out and truly falling in love with each other was missing',
#  "I didn't like the way both couples went",
#  'The non-romance relationships were great',
#  'The bromance, there was more than plenty',
#  'The bromance was perfect',
#  'The focus and the growing relationship felt authentic and real',
#  'I also loved the relationship between Grim Reaper and Eun Tak',
#  "I did enjoy Deok Hwa's presence, but man was man so underused",
#  'Other things that bothered me but not necessarily cause any deduction to the rating is over the top product placement',
#  'At one point it looked like subway was about to save the world, one sandwich at a time',
#  'And the wardrobe of poor little female lead, I just wonder how she manages to fit all those clothes in such little luggages and how she can afford all those clothes',
#  "I love how all those clothes presented Quebec at first, but I got mad that all those clothes didn't try to be accurate as to how Quebec looked at this time of the year",
#  'Worst of all is the episode length',
#  'It was needlessly long',
#  "I don't regret watching this drama",
#  'I still had a great time watching',
#  'Although the last three episodes felt too draggy and less enjoyable, but the last three episodes still had some good moments',
#  'Well all moments with GR for me are great lol',
#  'Enjoy',
#  "And don't hate me too much for the rating ",
#  'PMy reason for watching this show was a) because of all the hype and b) because of Kim Go Eun who I liked in Cheese in the trap',
#  'Unfortunately this show turned out to be a great disappointment',
#  'There is not much depth to the story and to be honest I didn t care much for any of the characters',
#  'For a man who has lived for 900+ years, Kim Shin has about as much maturity as a 16 year old boy',
#  'Moreover, the lead pair is terribly mismatched',
#  'A younger looking actor might ve been better suited',
#  'If this were real life, I would go so far as to think that Ji Eun Tak was a vulnerable girl who loves goblin only because Kim Shin is someone that pays attention to Ji Eun Tak and takes care of Ji Eun Tak',
#  'Not exactly the best reasons to love someone',
#  'That said, not all is bad with this show',
#  'I enjoyed watching the second pair as well as Deok Hwa',
#  'I was never a fan of Yoo In Na in Yoo previous work but I think Yoo did a good job here',
#  'As did Lee Dong Wook and Sung Jae',
#  'Music was pleasant to listen to',
#  'I especially like Stay with Me ',
#  'The best part of this show was the cinematography',
#  'Maybe I have a bit of a soft corner since Quebec is my home province',
#  'But I must say, they did a wonderful job shooting around the Chateau Frontenac and surroundings',
#  'The Goryeo scenes were good too',
#  'Rewatch value is none since the first watch was painful enough',
#  'For such thin plot line, what was the need to have 1,5 hour episodes',
#  'Tighter editing or fewer episodes might have made this show a bit more bearable',
#  'Watch if you re curious like I was, because of the hype',
#  'But I would not recommend I was',
#  'My review will be short and sweet with a link to my very extend review at the bottom if you wish to do some extra curricular reading',
#  'The Good',
#  "1) Reaper and Goblin's Bromance 2) Soni and Reaper's Relationship 3) The theme song 4) The cinematography 5) The locations shot in And that is ALL",
#  'The UGLY',
#  '1) 60% of the episodes are completely plotless',
#  '2) The last 5 or so episodes are completely rushed with about 6 major plot points in each of The last 5 or so episodes 3) The cringey, over-obvious product placement 4) EunDak is the worst character ever',
#  "EunDak's so selfish and so stupid and EunDak gets so lazy once the boys take EunDak in",
#  "5) EunDak and Goblin's relationship should NOT be romantic",
#  "It would've been much better as a Father/Daughter realtionship 6) The editing was rough in a lot of parts 7) Deok Hwa's character was so undeveloped and so underused",
#  "Deok Hwa's character deserved better",
#  "8) The lack of relationship and Deok Hwa's character development for all of them actually 9) The ending is an absolute mess",
#  'Why did the not all die so they could start over again',
#  '10) So many scenes felt half done',
#  'I feel like so much was either not filmed or just simply edited out and I feel like I was missing whole chunks of scenes that were needed',
#  '11) The over the top ridiculousness such as the SnowBoard accident, and the Goblin pushing EunDak and causing massive problems in the car park scene',
#  'many scenes were so stupid',
#  'many scenes were far beyond being able to suspend disbelief',
#  "12) Completely ruining Soni and Reaper's personality and all their charm in their new life in the final episode",
#  '13) Rushing through the final',
#  'Those last 15 or so minutes DESERVED and entire episode',
#  'Not the rush through that it got',
#  'The excessive overhype this show gets',
#  "It's really not that good",
#  'If you really want my Essay-long review of this show, check it out here',
#  'http',
#  '//sambart93,tumblr',
#  'com/post/179925136539/dokkaebi-goblin-its-not-bad-but-its-not-goodI am sorry but I think this drama is overrated',
#  'I know most of people are giving 10, so I thought this drama was importante that I post a more critical review',
#  "Please don't hate me",
#  'Yes the actors are good, the cinematography is great and the music also',
#  'There is clearly a big budget and the special effects are awesome fo a tv drama',
#  'But despite all of that, even if the main plot is interesting, the rythme is extremely slow and all of each episodes are flashback scenes over and over again',
#  'I found myself nearly sleeping while watching this',
#  'And I do not like the main couple (the 2nd one is really touching on the other hand)',
#  'Why',
#  'Well in my opinion the age cap is too much (not the actors but the characters in the way they are written), she is speaking to Gong Yoo like Gong Yoo is she father and she is acting really like a teenager, I found this disturbing',
#  'Conclusion, yes it is a good drama but for myself the lack of action and the slowness of it is not compensated by the rest of the positive points',
#  'the acting was perfect',
#  'the shooting angles were great',
#  'the shooting angles used the music exactly where it should be',
#  'The two love stories in the story were also fascinating',
#  'the characters were handled very well',
#  "There was nothing I didn't like in the story",
#  'those who do not watch this drama will definitely feel missing',
#  "I'm so sorry that this drama is already over",
#  'You should call the goblin as the master of all Asian series',
#  'Without a doubt, the goblin is the best Asian drama ever made',
#  'oh grim reaper',
#  "oh my love At first gong yoo seemed to be the lead role, but it wasn't all",
#  'As I said, the characters were thought through to every fine detail and conveyed to us by the actors in the most accurate way',
#  'comedy and tragedy were very well done',
#  'It was a drama that I both cried and laughed a lot',
#  'absolutely everyone should watch , ',
#  'It is a very good drama, but by faaaaar not one of the best',
#  '(Truthfully speaking, lately folks on MDL just throw around the 10s, it is totally misleading',
#  ') The best about this drama, is by a long shot, the ACTING',
#  'Superb',
#  'The male lead and the second female lead were the outstanding stars for me you could feel The male lead and the second female lead sorrow and mood and The male lead and the second female lead did not overact',
#  "And the male lead had a tough part to act, because, , the freakin' age gap",
#  'It made me cringe sometimes',
#  "I just couldn't overlook It, no matter how hard I tried",
#  'Sure, 19 and around 39 (or',
#  '939) is not a total disaster, but It does come close to being inappropriate, especially since the female lead is written to be extremely teenagery, showing lots of little-girl-aspects',
#  'Although the kissing scenes were really great and believable in the kissing scenes, the issue with the age just made it awkward to watch',
#  'Anyways',
#  'The plot, not to forget, was okay, sometimes even really nice',
#  'The ending is really emotional and I liked it, because I did not expect it',
#  '(it squeezed even two tears out of me, and I am one of those viewers that never cry)',
#  'The issue here is, that there were sometimes weird jumps between very, very serious topics and total slapstick',
#  'It was rather unusual and It made it sometimes difficult to follow the mood',
#  'The other thing was that in each episode there were several times that I was outright bored',
#  'If you look at it from afar, there was not much plot going on besides the two lead couples circling around each other',
#  'Is it a good drama',
#  'Yes',
#  'Is it a great drama',
#  'No',
#  'This drama is extremely overrated',
#  "This drama's boring",
#  'From the premise, it seems original, but it just a generic k-drama romance full of cliches',
#  'The main girl is extremely immature and I find the age gap quite worrying',
#  'I did not find The main girl too annoying as some people have said, The main girl could be the kind of girl found in high school (still though The main girl immaturity is exaggerated)',
#  "It is the relationship between The main girl character and the Goblin I disliked- it just didn't work",
#  'The romance does not feel real or believable',
#  'The romance feels like a father and daughter, but we are supposed to believe a father and daughter are in love',
#  'It seemed like I would especially enjoy it because of the historical/fantasy aspects, which are genres I love, but these are only very small parts of This drama',
#  "Although I did expect these to be only small parts, I didn't enjoy the rest of This drama anyway",
#  'I found myself wanting to skip lots or sometimes felt like I was falling asleep',
#  "The plot skips ahead often and feels a bit all over the place, as if the writers didn't really know what the writers were doing",
#  'I constantly found myself frustrated and bored with the story',
#  'In saying that I loved the parts involving the Grim Reaper, and his relationship with the Goblin and Sunny, and when the fantasy/historical elements did appear I enjoyed the Goblin and Sunny',
#  'The acting was also very good',
#  'However, overall I did not enjoy This drama and would not recommend This drama unless you like watching generic, boring romances with poor writing (or watch This drama and skip all of the main romance- lmao)',
#  'Story',
#  'The idea as a theme of Story is good, unique and different',
#  "But The idea as a theme of the story's actually a spider web to trap me to go inside and watch The idea as a theme of the story",
#  "I personally dislike the relationship between male and female lead after episode 3, It's damn annoying to see this girl",
#  'I have 0 patience with this kind of girl',
#  'Matrealistic, selfish and demanding',
#  "All of characteristics that I don't like",
#  'The bromance is sweet and funny so The bromance has saved the story in general',
#  'Some scenes are still questionable, even the male lead character changed so abruptly from a great war general to a silly childish guy after meeting a teenage girl for a few days',
#  'The beginning of the plot is so slow with so many flashbacks and unnecessary scenes',
#  'Second lead female is redundant (which is a pity) from eps 1-10, like this girl got so little scenes in the drama besides those flashbacks and sitting in the empty shop',
#  'I would say the drama will be very good if the drama only about 6 8 episodes',
#  'There are too many fillers in the drama (which is understandable) probably to get more money from advertisements to cover big budget',
#  'Music ',
#  'Music is good',
#  'I admit it',
#  'I like all the songs in the drama',
#  "It's very catchy and refreshing",
#  'Cinematography It is good',
#  'Editing team is expert in this',
#  'this has cinematography like movie',
#  'The color is solid, the background, houses, shooting venue, fashion style, everything is nice',
#  'I can tell that it has a big production budget',
#  'Acting is okay',
#  'I can relate',
#  "It's not making me feel weird",
#  'Just some characters written by the writer that makes me feel strange',
#  'Overall, i know this is a good drama, i mean most of the aspects are good',
#  'But sadly, i appreciate movie and drama based on the story and character development',
#  'Since the story is not good enough for me, the drama has big flaw in my eyes',
#  'Sorry, i had higher expectation after i watched 1st episode that i became so disappointed with the rest of the episodes',
#  'Especially the middle ones',
#  "But i would recommend the drama for u to watch if u don't mind of the strange romance that feels forceful for me, this is a drama for u",
#  'ohh i need to mention it again, i hate the female lead character, ok',
#  'STORY',
#  "This was probably the most inventive and creative dramas/story plot I've seen in the Korean entertainment industry yet",
#  "I adore fantasy because it strikes the imagination part of the brain in a fun way and I've seen some fantasy-genre Korean dramas but some fantasy-genre Korean dramas don't involve a lot of fantasy elements",
#  'Most dramas I\'ve seen that are labeled as "fantasy" or "supernatural" usually use these elements to support a story',
#  'They were more tools to carry a story along rather than being the main focus',
#  "'Queen In Hyun's Man' was the closest I've seen to making fantasy as the main focus point, but still lacked emphasis on the genre",
#  'This drama really made the "fantasy" element THE main focus and you see a story support the genre rather than the other way around',
#  "I'm so proud and happy for Kim Eun Sook",
#  'Kim Eun Sook did a FANTASTIC job writing This drama',
#  "The world Kim Eun Sook created was so vivid and realistic in the sense that if there were such thing as goblins and grim reapers in The world she created, Kim Eun Sook made the idea fit into our 'real world' construct to make it believable that our 'real world' might actually exist",
#  'I thought it was unique to have the idea that there were many grim reapers, instead of just one, and that they were organized in a governmental way',
#  "The reasons for they amnesia were pretty sound and the search for the goblin's bride was pretty inventive",
#  "Kim Eun Sook could've been lazy with the why of everything and make they the most conventional reasons possible, but Kim Eun Sook definitely took great stride into creating a story that weaved in and out with every action and every decision so that almost everything had a meaning and a real reason behind they",
#  'Kim Eun Sook did a sublime job fleshing out the characters too',
#  "the characters definitely aren't the cookie-cutter type of characters you usually see in almost all romance Korean dramas, and I super appreciate that",
#  'It gets soooooooo unbelievably boring when I see the same type of character over and over again in every typical romance drama',
#  'Especially the male characters',
#  'Especially the male characters always turn out to be super mean and only to the main female character, but has a hard time expressing Especially the male characters feelings from Especially the male characters golden hearts',
#  '__- ',
#  'ACTING/CAST',
#  "This has been the best casting I've seen EVER",
#  "I'm not even joking",
#  "My favorite actress (for the current time) is Kim Go Eun and even though Kim Go Eun's still young in the industry, Kim Go Eun has AMAZING acting talents",
#  'Kim Go Eun pulled off Kim Go Eun character without a hitch',
#  'Same goes for Gong Yoo, who is a veteran in the industry and brings flourishes of experience from his time in the k-drama and k-movie business',
#  'Lee Dong Wook also did surprisingly well in this drama, although I still wish Lee Dong Wook was a bit more expressive',
#  "Maybe I'll get some upset comments about this, but Lee Dong Wook always seems to have this same indifferent look about Lee Dong Wook in every drama I've seen Lee Dong Wook in",
#  'But still, Lee Dong Wook did great in this drama, despite this fact',
#  'I considered Yoo In Na as a bit of a newbie in the entertainment business, but glad Yoo got to be in this drama because I definitely see good potential to grow Yoo acting talents and be a very talented actress',
#  'Also have to give props to Yook Sung Jae and Lee El for Yook Sung Jae and Lee El great portrayals of our Gods',
#  "Lee El has really good potential to be a great actress as well and hope that after being exposed in this drama, Lee El'll have the opportunity to be in many more dramas as well",
#  'Maybe in a lead',
#  "Lee El's always been the side character, haha",
#  'MUSIC',
#  "I don't really pick on MUSIC unless it's extremely good or extremely ill-fitting",
#  "Goblin's soundtrack was ABSOLUTELY PERFECT",
#  "Goblin's soundtrack fit the tone of this drama so perfectly and carried the emotional and lighthearted scenes so PERFECTLY",
#  'This is one of those rare moments where I want to download the whole track list to my phone so that I can listen to it whenever and where ever',
#  "What people don't often notice is that the music of a drama and the story is kind of like two halves of a whole",
#  'people really do have to fit well together or else the overall picture/concept of this drama becomes a little, off',
#  'But these two fit together absolutely perfectly',
#  'OVERALL',
#  'I was going into this drama with big apprehension because the writer was Kim Eun Sook, who also wrote Descendants of the Sun, which I was absolutely bored to tears with',
#  'With the awesome cast in this drama but with Kim Eun Sook being the writer, I was worried that Kim Eun Sook would do the same thing as Kim Eun Sook did with DOTS',
#  'But I was thankfully relieved and pleasantly surprised',
#  'I know I sung praises up and down in this review for this drama, but please keep in mind that I rarely ever do this unless this demands that kind of praise',
#  "There's really only one other drama I gave a 9/10 or above and that was Liar Game (Korean version)",
#  "this drama was well-directed, well-acted, and put together so well and so impressively that I really can't help say nothing but great things about it",
#  "The only reason why I gave this drama 9,5/10 instead of 10/10 is because of 'the contract' reasoning for our goblin (don't think that's a spoiler because you'd have to watch and know what the contract was) But other than that little lazy reasoning, Usually, I leave about a week to review a drama because I don't want the added hype of my own excitement to affect a review, but I'm very confidant that my thoughts and feelings for this drama will not waver for the reasons I wrote in this review, even as time passes",
#  'I would wholeheartedly watch this again and again',
#  "The cast, the story, and the music all blend and mesh together so well that it's painted the most beautiful picture I've seen yet",
#  'NOTE',
#  'This is a somewhat slow-paced drama, so please understand that before watching',
#  "Some people don't like slow-paced because of Some people tendency to want instant gratification (especially with the younger folks, haha) But to be honest, this drama wouldn't have done so well if this drama were more fast-paced",
#  'I think being slow-paced as it is was the perfect speed for the story',
#  "If it were any faster, Some people'd be left with a less desirable ending and very rushed story",
#  "Okay, here's the thing",
#  'Goblin was a drama sooooooo many people loved',
#  'It was said to be such a great drama',
#  'It took me really long to watch It, simply because I am an anti-hype girl',
#  "I never read or watch things while things are being hyped, as I don't want my view to be somehow clouded",
#  "But then at some point, I'll probably watch or read my view nevertheless",
#  "That's how my view was with Goblin",
#  'And I honestly looked forward to my view because my view was supposed to be such a great drama',
#  'Boy, was I wrong',
#  "Here's why",
#  'Story',
#  'Story is basically a great idea',
#  'GoblinGoblin Goblin ',
#  'his bride being a High School girl, that Goblin once saved, who sees ghosts',
#  'Wait, what',
#  'An ancient guy and a High School girl',
#  "Oooooookay, I thought, well, maybe An ancient guy and a High School girl just meet once while Oooooookay's in High School and then An ancient guy and a High School girl meet years later to fall in love",
#  'Well, no',
#  "That's not what happens",
#  'Story is reaaaaaaallllllyyyyyy slow paced and with that at some point Story was just dragging on and on and on and on and I thought "MOVE',
#  'FORWARD',
#  '" But that did not happen until the last two or so episodes',
#  'Meeh ',
#  '- The only thing that made Story better is the story line between the Grim Reaper and Sunny',
#  'I would have loved to have THEM as the main couple and tell THEM story rather than Story',
#  'Acting/Cast',
#  "I haven't watched any drama with Gong Yoo or Lee Dong Wook before, wo I was open to anything that might come along the way",
#  'They both acted fantastically but I was just SO IRRITATED with Gong Yoo role',
#  'Gong Yoo was constantly going on my nerves acting like a spoiled little child',
#  'Some scenes, especially in the beginning were really funny and I got some weird glances from my husband because I burst out in laughter several times',
#  'But after some time Goblin Goblin became really annoying',
#  'The Grim Reaper on the other hand had a lot of depth and The Grim Reaper was a fascinating character through and through',
#  'Now on to the girls, I watched Kim Go Eun in "Cheese in the Trap" and Yoo In Na in "My love from another star" and I liked both of them',
#  'Here both of them also did a pretty alright job',
#  "But due to this slow paced story I couldn't enjoy there acting much",
#  'A huge praise goes to Yook Sung Jae, The Grim Reaper was hilarious and so damn cute',
#  'Also, I would have loved to see more scenes with Kim So Hyun and Kim Min Jae both of them LOOK SO FREAKING GOOD TOGETHER',
#  'Can both of them please get a drama where both of them are the OTP',
#  'Music',
#  "Now that's the amazing part of the drama the music",
#  'Alsways spot on and so so beautiful',
#  'Together with the scenery WOW',
#  'Rewatch Value',
#  'I would give a 0 if I could',
#  'Will never rewatch this',
#  'Overall',
#  'this could have been amazing',
#  "Unfortunately this wasn't",
#  'Not at all',
#  'TLDR',
#  "I'm giving this a 7/10 for the fabulous cinematography and the excellent bromance",
#  'Why I liked this',
#  '1, The cinematography is LOVE LOVE LOVE',
#  'I want to go visit Canada now',
#  '2, The bromance',
#  "3, Grim Reaper's deadpan sense of humor",
#  'So my thing',
#  '4, Gong Yoo has never looked hotter',
#  "(Okay, that's not quite true",
#  "Gong Yoo's ALWAYS hot",
#  ") 5, Goblin's pettiness",
#  "6, Sunny's character",
#  'I like Gong Yoo lots',
#  'What I disliked about it',
#  '1, TOO',
#  'DAMN',
#  'LONG',
#  "Too many scenes linger on unnecessary beats and Too many scenes stretch scenes that aren't at all integral to the plot",
#  "The premise had so much promise but The premise wasn't used to The premise full potential",
#  "2, Kim Go-eun's cutesy act",
#  "I like Gong Yoo as an actress and Gong Yoo's fab in the dramatic scenes but Gong Yoo tends to overdo the aegyo",
#  "It doesn't help that Gong Yoo character is, confusing",
#  "Gong Yoo's supposed to be intelligent and quite mature, and the next Gong Yoo does absolutely imbecilic things",
#  'SMH',
#  "3, I didn't quite buy the romance between the millenia-old dokkaebi and Gong Yoo high schooler bride",
#  '4, That ending',
#  "I'm ambivalent about That ending",
#  'In all the Kdramas that I have watched, Goblin will probably be the one that I will remember the most',
#  'The acting was brilliant, the chemistry was outstanding (best bromance in history of Kdrama between Gong Yoo and LDW), and the music was so good that when you hear the chemistry outside of the show, you will immediately think of Goblin',
#  "A song in particular that is in my head 'till now is I miss you (Grim Reaper and Sunny's theme song)",
#  'Would have gave it a perfect 10, but they failed to properly conclude the show',
#  'the ending can be considered bland and unfinished from all the butterflies, heartbreaks, and laughter the show gave us',
#  "Overall however, I would still recommend this show for everyone to watchSo far, a lot of Korean dramas I've watched follow what I call the 90-10 rule",
#  '90 percent of the plot will be a romantic comedy filled with light and fluffy moments while the other 10 percent will be focused on the theme that gives the drama the drama identity',
#  'Goblin follows the 90-10 rule to a tee where most of the story involves the characters acting funny or cute with each other',
#  'The rest involves dealing with The rest lives as supernatural beings, coupled with occasional flashbacks of a previous life hundreds of years ago',
#  "I'm not sure if I can call this a flaw",
#  "I know a lot of viewers love this sort of thing and there's nothing wrong with preferring the lighthearted and none-too-heavy in terms of plot",
#  'I know it can be a great stress reliever as well',
#  'I prefer my dramas more on the plot heavy side though',
#  "even the most romantic stories I like have about '50 percent of something-else-going-on-other-than-the-romance",
#  "' But for what it's worth, Goblin is extremely successful as a rom-com",
#  'I just happen to be more interested in the supernatural or dramatic parts of it',
#  'For Eun Tak, the most interesting scenes where when Eun Tak had to deal with the ghosts Eun Tak could see, when Grim Reaper had to transport the dead one drama at a time and when a deity or god would pop up in the story to mess with the characters',
#  'Overall, Goblin was an adorable little show but it could have been much bigger',
#  'I loved the world that it introduced me to',
#  'A world where Grim Reapers would meet and convene on their deadly assignments, where Goblins could make gold out of nothing and where special people (like Eun Tak) could help the dead get over special people (like Eun Tak) unfinished business',
#  'I wish there could have been more of that',
#  'Was the Goblin (the main character) the only Goblin in the world',
#  'Were there others like him',
#  "There were moments where I wanted to see more of what made Goblin Goblin special (and how they were able to tie this Korean fantasy creature to a modern day adaptation) and what him could do to make people's lives more magical",
#  'While him telekinetic fight scenes with Grim Reaper were adorable, I kind of wished to see him powers put to better use',
#  "I wanted him 'Goblin persona' to make the story more interesting",
#  'This drama offers a tantalizing glimpse of a supernatural world in the modern age but there is so very little of This drama ',
#  '( Now the chemistry between the OTP was fine',
#  'I felt that they had they best moments in the last two episodes (where This drama really made it worthwhile and where I finally got the Gong Yu hype',
#  ') but the earlier episodes (all 14 to be exact) were somewhat boring for me because the development of they relationship consisted mostly of',
#  'Goblin',
#  "'Oh can she see the sword in my chest",
#  "', 'Will she pull the sword out",
#  "' 'Oh, I need she to get the sword out of me', 'Oh, I don't want she to pull the sword out now",
#  "' Eun Tak",
#  "'Am I the Goblin's Bride",
#  "' 'Oh, I won't pull the sword out for some reason' 'Oh, I want to pull the sword out but he won't let me', 'Oh, now I know what will happen if the sword gets pulled out I'm never going to do it- how could he ask me to",
#  "' That's basically what their relationship dynamic was like for most of the show",
#  "I much preferred Grim Reaper and Sunny's dynamic because it touched on the difficulties of a Reaper/human relationship better",
#  "The Reaper's past was also more intriguing because The Reaper's past explained why The Reaper was doomed to such a fate",
#  "In the Goblin's (aka Kim Shin) case, the immortal life he was given was meant to be a reward but the immortal life he was given played out more like a punishment",
#  'This made no sense to me because in the very first* episode, The Reaper past life as a noble warlord was established',
#  "The Reaper was betrayed, The Reaper committed no crime whatsoever, so every time the gods would make things difficult for The Reaper, every time the story would make The Reaper suffer, these consequences didn't really fit in with the logic of reward-punishment the story was trying to make",
#  'The Reaper was blameless so the suffering The Reaper went through had no basis and felt hollow to me',
#  'Other Things I Took Note Off',
#  "Gong Yu wasn't the best actor but Gong Yu charisma as a leading man was appealing",
#  "I didn't get it until the very last episodes (this is where the romantic angle finally worked out for me and the OTP moments became squee worthy)",
#  'I just wish it happened sooner ',
#  '0 I liked the actress playing Eun Tak',
#  'But the problem I had was that the director told Eun Tak to act too childlike',
#  "I get that the whole 'naive and innocent' candy girl is a staple in these dramas, but Eun Tak version was too exaggerated and went way beyond the trope",
#  "I've watched (and appreciated) plenty of other candy girls before but Eun Tak was a little too much for Eun Tak at times",
#  'Eun Tak was a 19/20 year old woman and Eun Tak played it like Eun Tak was 13, squealing over a bag Eun Tak got as a present, jumping up and down the bed and hugging Eun Tak stuffed toys, crying in the bed while it rained outside, the last time I saw this peculiar behavior was in the Hollywood action movie Taken, where Liam Neeson\'s daughter "Kimmy" acted like a 7 year old kid instead of as a teenager/young woman',
#  'In hindsight, perhaps it was a good thing that the OTP moments came at the later episodes, as it was only then that Eun Tak started acting normally _- Lee Dong Wok may be the best actor here',
#  '_- Lee Dong Wok was definitely the best crier',
#  '_- Lee Dong Wok brought so much depth to the flawed but intriguing Reaper, who easily became my favorite character',
#  'The way _- Lee Dong Wok expressed emotions seemed extremely heartfelt',
#  "Now, I don't have that much familiarity with Yoo In Na",
#  "the only other time I've seen Eun Tak was in My Love From the Stars where Eun Tak played a similar supporting character",
#  'But Eun Tak Sunny is very likable the no-nonsense types female leads usually are',
#  "One thing Goblin excels in is that it had some of the best special effects I've seen in any drama",
#  'Viewers can feast Viewers eyes on some of the most beautiful landscapes abroad and in Korea',
#  'The fight scenes, exploding cars, etc',
#  ', all were great to look at',
#  'The historical parts were done well, too',
#  "The OST is nice to hear but like plenty of other Korean dramas, when you pause to really listen to The historical parts in the lyrics- The OST don't make much sense",
#  '"Never go my way, never quite some day, " what',
#  "XD Overall, Goblin was a good show but it wasn't great",
#  "I think viewers who don't mind extremely light (as in, 'hardly nothing ever happens but we are all so cute anyway",
#  "') plots would appreciate this the most",
#  "I'm glad I watched this",
#  "I feel like I can understand the hype more although I can't participate in this as much as I would like",
#  'I decided to watch Goblin after many of my friends recommended it to me, to say the least i was disappointed',
#  'The story was full of plot holes, and in a conversation I had, no one could explain plot holes, and said I should just enjoy The story for what The story is',
#  'But how am I suppose to enjoy a drama that could have explain everything in 3 episodes but dragged out',
#  'This is a drama that stirs up my intellect more than anything else',
#  'The music for this drama was kind of blah, with all the hype, I thought they would have more than 1 piece I like',
#  "For majority dramas I watch, The music for this drama would be so good that I would replay the parts with the music I like, but for this drama I only like 1 song they had, and this drama wasn't good enough for a replay The main couple were awkward and boring, maybe for people who likes extremely slow dramas",
#  "The chemistry between they is a little and awkward, like a woman falling in love with a stalker because a woman falling in love with a stalker has psychological problems which hasn't been solved, and will love anyone who gives they any kind of attention",
#  'Or like a man who needs a needy woman to feel better about a man who needs a needy woman to feel better about himself',
#  'Within a few episodes in, I could already predict the majority of the story line for The main couple',
#  'Overall, the majority of the story line for the main couple relationship can be summarize by a daughter-father relationship with romance',
#  'The only redeeming thing about this drama is the supporting characters, the majority of the story line for the main couple had a lot more chemistry, and the majority of the story line for the main couple story line is more interesting with unpredictable outcome',
# ...
#  'I just want to say exactly what I felt',
#  "the show is downright one of the most beautiful things you'll ever see",
#  'From the casting, to the cinematography, to the writing, everything is sheer perfection',
#  "It's kind of EPIC",
#  'You can feel the beautiful way the creator sees the world, with the creator particular touch of darkness',
#  "the creator will hurt you, and make you laugh, even in the midst of your pain, like the Grim Reaper in that one scene, you'll not have a choice",
#  'Rating the show the highest possible rating wasn t even up for debate',
#  "The thing about a good story is that you can have a massive budget and top rated actors but if you have a stale, unworthy story and half boiled characters, it just doesn't work",
#  "The value of the show is that every character is so deep, so believable, so REAL, you can't help getting lost in every character is so deep, so believable, so REAL",
#  'Few minor gripes I have was that Duek Hwa and Jung Hae In should have had better storylines',
#  'Second, toward the end the amnesia bit dragged a bit for Duek Hwa and Jung Hae',
#  '(Minor spoiler) Even the whole finding love in past lives instead of present was again a bit typical for a show of this caliber',
#  'What you can do in a next life you can do in this one, for this reason the last two or three episodes in places it got a bit boring for Duek Hwa and Jung Hae',
#  "Still, I'm happy to have seen the show, I've never quite seen anything like the show",
#  'All in all, bravo',
#  'This drama is really something special and after watching This drama I feel kind of lost to find something similar amazing',
#  'The story was kind of clear from the start but the cast made The story very interesting and very very very emotional',
#  "Every character had it's own habits and weirdness but that made the cast even more loveable",
#  "At first I had my trouble with the female lead Kim Go Eun because sometimes it seems as if Kim Go Eun's trying to hard and it made me cringe but maybe that's because we meet Kim Go Eun in different stages of Kim Go Eun life, as a highschool senior and a college student and at Kim Go Eun later work",
#  'So it is kind of understandable that Kim Go Eun goes through some changes in life and in Kim Go Eun personality and that made me really like Kim Go Eun later on',
#  'The relationship between the Goblin and his Bride developed with some ups and downs and even more interesting was the relationship between the Grim Reaper and Sunny SO HEARTBREAKING',
#  'I loved the fact that the Grim Reaper probably went through the biggest and hardest change during the series as the Grim Reaper starts off as an emotionless weirdo',
#  'I loved the music',
#  "I even added it on my playlist and I'm listening to the intro song all the time",
#  'I would rewatch it but this drama made me so emotional',
#  "I think that I was crying all the time through the last 3 episodes, that's almost like 5 hours of crying",
#  'It had kind of an ending I could be happy with but before I could be happy It had to punch me in the face and heart and everything came so suddenly, so I will wait until I have the nerves to watch the nerves again',
#  'Overall I LOVED the nerves',
#  'I give it a begrudging overall 9/10 ',
#  'I just want to start of by saying that Goblin is a really sad drama ',
#  'I just want to put that out there because all the top comments and reviews out there on the World Wide Web rave on in a fan girl manner that you would think it s Boys Over Flowers ',
#  'I was misled and the sadness genuinely caught me off guard',
#  'it s SAD',
#  'Now that s out of the way let me address why I give it a begrudging 9/10, Goblin did not convince me at all that it is a perfect show',
#  'it s age gap and high school lead was really uncomfortable for me to fathom ',
#  'Why did they have to make ',
#  'Why into a high school kid though ',
#  'And though Gong Yoo is hot and all ',
#  'Gong Yoo really looked considerably older than Gong Yoo female lead and that was just uncomfortable',
#  'But that s an internal personal bias and has nothing to do with the plot unraveling ',
#  'Creep factor aside this was a really original story with an interesting and dare I say new premise',
#  'I admired how the writers stayed true to the writers intentions and you could tell the writers never fell off but kept focused ',
#  'It had great quotes too and I loved the deity aspect of the show It gave It a divine elegance',
#  'However This is a tricky review to write because as a romantic drama This ticks all the right boxes ',
#  'Great sweeping love declaration scenes ',
#  'Yes ',
#  'In fact the writers are touching',
#  'Angst ',
#  'Yes sure to cry like a baby ',
#  'Great supporting leads with equally engaging angsty story lines ',
#  'Yes , yes and yes',
#  'Great romantic kissing scenes ',
#  'Yes',
#  'But nooo',
#  'It s not a 10 ',
#  'the plot was not tight enough ',
#  'the plot was repetitive using the same set ups over and over again that the plot actually wasted time in setting up other important relationships such as the supporting leads relationship progression and the reincarnated relationships that were discovered along the line',
#  'Kudos though to the plot twists which were very much appreciated',
#  'Sure to keep a viewer tuning in',
#  'It also had time in It 16 episodes with rich story to insert a villain which I thought was deft',
#  'I also liked the way they handled the past informing the present and the notion of reincarnation and It s supporting motifs',
#  'The romances were also lovely',
#  'Emotional resonance was very strong too',
#  'I cried like a baby in Ep 13 which is one of the best moments in tv history ',
#  'The last episode was so poignantly sad too',
#  'Comedy was also very well done ',
#  'The acting and cast were unblemished ',
#  'Gong Yoo was so funny and melancholy at the same time ',
#  'The Grim Reaper was gorgeous and grim at the same time and the female leads were assertive , spunky yet passionate in the same this show The soundtrack is quite possibly one of the best of the best and does much to bolster the ratings ',
#  'I loved every song and my standouts were Beautiful Life , Hush ( Goblin lullaby, the second leads song I miss You , I Will Go To You Like the First Snow, oh my word I m listing the whole sound track ',
#  'That s how good it is ',
#  'The fashion was off the charts',
#  'Deok Hwa s coats and suits , The Grim Reaper s cozy oversized sweaters and Goblin s coats were amazing',
#  'Sunny s outfits are worthy of a Pinterest board alone',
#  'Rewatch value is quite strong once I get over the creep factor ',
#  'Souls are apparently immortal and ageless right ',
#  'So we will stick with that and suck that up , As for the OVERALL don t waste anymore time and go ahead and watch it ',
#  'If there s anything this show convinced me of other than a sad love of a lonely and great god Is that this show s definitely one of those shows you need to have under your belt for posterity reasons ',
#  'Also ,If you loved My Love From the Star , you will surely find this pleasant too',
#  'If you like some supernatural and super sadness then this one is for you ',
#  "Can't even put in words how much this series has affected me",
#  'this series is a Masterpiece',
#  'The Ost, the editing, the storyline, the chemistry, the acting every single thing is just awesome',
#  'Every character had it own story and the actors did a marvelous job to inact it',
#  'The continuous bashful comments by the Goblin and the Grim reaper are savage',
#  'It never misses an opportunity to make you laugh till the very end and I was laughing my ass off throughout',
#  'Not only comedy, it is full of romance and drama',
#  'The lines are beautiful and everything connects so well ( things said in past connects later to a thing happening in present) Just WOW A moment i felt goosebumps and in another I was crying (literally a lot) and in next i was laughing like anything, its that level',
#  "I recommend this to everyone who loves Kdrama ( even if you don't you'll after watching this ) A Classic of all time Upon re-watching a show, or watching it critically the first time, much can be said about where the director failed, where the author confused, where the actors faltered",
#  'There are works of art, however, that do not lend the actors to such criticism',
#  'Goblin is one such show',
#  "It's not perfect",
#  'The faults I mentioned (and those that have been and will be mentioned by others) are present in Goblin',
#  "Yet Goblin isn't the sort of artwork to reveal The faults I mentioned (and those that have been and will be mentioned by others) to the engaged viewer",
#  'Again, much will be said in the way of critique and analysis, as it should be',
#  'But if you come across one such show and ever find yourself immersed hopefully in the first episode Goblin will refuse to release you until one such show final moment',
#  'one such show does what every artist hopes every artist work will do',
#  'one such show submerges you in the world one such show constructs and, when one such show ends, leaves a part of one such show world with you',
#  'GOBLIN is by far one of most amazing k-series i have ever watched',
#  "The plot is well written, the characters are amazing and although The plot's a fantasy story, the special effects were just in right amount, not one being used randomly or without logic",
#  'Plot twists, romance, humor, drama, it has everything in perfect balance',
#  'I highly recommend it for everyone and anyone willing to witness a great story',
#  'I have watched it because I found the plot interesting, I am not a fan of GY or KGE',
#  'At the first episodes I found her irritating but then I get used to her',
#  "The story is interesting and keeps you wondering about what's gonna happen next",
#  "I will probably watch another drama of GY but I do not think that I'll watch one of KGE dramas",
#  'I have watched Train to Busan and he is very talented',
#  'while watching there is one thing might irritate you that is the great age difference betw Goblin  and  ET',
#  "That love things in the edge of being a pedapholie Goblin is a man who is over 900 yrs old but looks like a man who is in Goblin late 30's early 40's while ET is only 19 yrs old and a high schooler",
#  'her is inlove with a man who is at the age of her dad / can be easily have / had kids at her age',
#  'And if we think of the era he comes from he possibly might have concubines, wives and a couple of kids',
#  'They are good match physically but in this drama, it was over the border',
#  'I do ship They but not on this drama, They can easily be bf / gf as KGE likes elderly guys and GY likes younger girls',
#  'I was more interested in Sunny and Grim Reaper couple',
#  'they were a fantastic couple',
#  'There were a lot of product placements, from stuff toys, to TBS White Musk Perfume, which I end up buying and now using a room spray as the perfume is that much crap, the watches he wore, canon camera which is worth over 2000 this is with only a small lens',
#  "I only find the Canon placement irritating I thought the Canon placement was related with the upcoming scenes as they have openly showed us, like poking someone's eye",
#  'it was that obvious',
#  "I really enjoyed the Canada scenes, and a couple of Korea Seoul scenes but that's it",
#  'I want to see Yoo In Na, LDW, Yook Sung Jae,  and  Lee El in one drama',
#  'I will not go back  and  rewatch one drama',
#  'It was one shot for me, I will forget about It within few months',
#  'If it was not KGE as a leading lady, and if there were less flashbacks, less repetitions it would be an excellent dramaGoblin has a lot to offer',
#  'Goblin handles one of the deepest concepts',
#  'death, life, destiny, choices and regrets',
#  'And Goblin does a great job with Goblin',
#  'Goblin is a very realistic drama, while having fantasy elements(with great special effects) which makes it x100 times better',
#  'it has great life stories',
#  'And what I mean by life is that it has friendship, family, and great love',
#  'it talks about being a human, it talks about learning to love yourself and others',
#  'It is funny, It is sad, it is beautiful and every moment of it shines',
#  'it is just one the best stories I have ever seen and I wish everyone would get to see this',
#  "Okay, I'll start by letting you know that among all the dramas I've watched, even though I had favorites, I never felt the need to post a review",
#  'So this is my first time',
#  'Goblin was just AMAZING, that I felt like I was committing a grave mistake by not reviewing it and letting everyone know how amazing it really is',
#  "Furthermore, this is also my very first time rating a drama a whole 10, Not because they weren't amazing, nor was it because I felt like they didn't deserve it, just purely because I felt like no drama can ever get a whole 10, It felt impossible to me",
#  'However, as you guys can clearly see, I gave Goblin a 10, This speaks volumes of this drama',
#  'Even my drama hating hubby, decided to give this one a shot after glimpsing a scene of this one while I was watching one of the earlier episodes',
#  'Story',
#  'The story line was spectacular, the idea in The story line was original',
#  "I've never watched anything remotely close to Goblin's story line",
#  'The way everything was timed and spaced was perfect, I never felt like there was a moment of boredom',
#  'The plot, the poems, the scenes, the cinematography, my god, the cinematography was pure bliss',
#  'the cinematography really shows the amount of work and thinking that went into this production',
#  "Even the ending, I won't go into detail with that, as not to spoil it for the people who haven't watched it yet this was one of the very few dramas that wrapped up the ending very well",
#  'Even though this was bittersweet, it just felt right and made total sense',
#  "There wasn't anything that was over the top or thrown in together just to satisfy the audience even though it makes no sense whatsoever",
#  'There was Romance, Comedy and Suspense weaved in together perfectly',
#  'Cheers to the writer and producer',
#  'Acting/Cast',
#  "I've read a few comments here and there while the drama was still airing",
#  "Some people found the relationship between the Goblin and Eun Tak disturbing because of the large age gap (939 years), but if you think about it, it wouldn't have made sense for Some people to just meet for the first time when Eun Tak was older",
#  "He's been living for the past 900 years, so He bride was bound to be born sometime throughout He lifetime and Eun Tak is bound to be much younger than He",
#  'Also, the production team limited the relationship between the Goblin and the younger Eun Tak to cutesy and adorable moments',
#  'There was nothing immoral about it',
#  'So if anyone is hesitating to watch the drama because of this issue then fear not',
#  'I felt like the cast did an amazing job',
#  'Each actor and actress portrayed Each actor and actress characters in a way that made me laugh and cry with Each actor and actress',
#  "I felt each person's sorrow and pain",
#  'Even the chemistry between the Goblin and the younger Eun Tak was amazing',
#  'The Bromance between the Goblin and the Grim Reaper was mind blowing',
#  "I feel like if it weren't for this specific cast, the story line wouldn't have been portrayed as seamlessly as the story line had been",
#  'SO, Cheers to the cast as well',
#  'Music',
#  'The OST was superb',
#  "You won't be able to prevent yourself from repeatedly playing the songs on a loop",
#  'Whenever I was waiting for the next episode to air, I would just play The OST The OST and reminisce on the previous scenes',
#  'I miss everything about this drama already',
#  'EVERYTHING',
#  "') this drama now holds a special place in my heart",
#  "this drama may even be my new #1 fav drama, especially since this drama's in the supernatural/fantasy/romance genre, which is my fav",
#  'this drama gave me great feelings, especially from the characters (and I must say that this drama has the BEST freaking bromance ever',
#  ')',
#  ...]

# %%
chem = []
for line in lines:
    if "chemistry" in line:
        chem.append(line)
chem
# Out:
# ['Had the writers held on to that chemistry and nourished that chemistry, Goblin would have been much better',
#  "The sweet and cute moments of the Goblin couple  and  the sizzling chemistry between Grim Reaper and Sunny was enough to keep the 'romance' meter of a great drama pretty high",
#  'The chemistry between the male cast was flawless',
#  'The acting was brilliant, the chemistry was outstanding (best bromance in history of Kdrama between Gong Yoo and LDW), and the music was so good that when you hear the chemistry outside of the show, you will immediately think of Goblin',
#  '( Now the chemistry between the OTP was fine',
#  "The chemistry between they is a little and awkward, like a woman falling in love with a stalker because a woman falling in love with a stalker has psychological problems which hasn't been solved, and will love anyone who gives they any kind of attention",
#  'The only redeeming thing about this drama is the supporting characters, the majority of the story line for the main couple had a lot more chemistry, and the majority of the story line for the main couple story line is more interesting with unpredictable outcome',
#  '(2) Lee El chemistry with Grim Reaper is daebak',
#  'And even when people bash this because of the lack of chemistry ( I admit that there is a lack but not too much) or the confusing facts ( But people explained it at the end well), I personally want to recommend it to other people',
#  'So much chemistry, The story line was amazing, I love The story line from the beginning to the end, I laugh when The cast did',
#  'The performances were great, and the story was really good, with the chemistry between the couple obvious',
#  'I felt as though the cast as a whole had such great chemistry, everyone just seemed to mesh together so well and all seemed so at ease and comfortable in everyone characters',
#  'Not only was the chemistry and witty banter between Gong Yoo and Lee Dong Wook amazing, but the extra comical effect of Yook Sungjae made everything perfection',
#  'It had a great intro and the cinematography was amazing, It has great actors and the chemistry between the male actors was absolutely flawless and also half the reason I bothered finishing this drama',
#  'not mostly for the awesome and unbearably cute bromance between Gong Yoo and Lee Dong Wook had great chemistry together and not mostly for the awesome and unbearably cute bromance between Gong Yoo and Lee Dong Wook dynamic was way more interesting than the actual boy-girl romance, in my opinion',
#  'The Ost, the editing, the storyline, the chemistry, the acting every single thing is just awesome',
#  'Even the chemistry between the Goblin and the younger Eun Tak was amazing',
#  'Lol I loved the beautiful, breathtaking, heartwarming, heartbreaking, sizzling hot chemistry between the couples',
#  'The chemistry was there and The chemistry was just perfect',
#  'I was enjoying The chemistry too much to care',
#  'All of the characters had chemistry and you could tell All of the characters enjoyed what All of the characters were doing',
#  'The actors chemistry for This drama was perfection, The actors gelled so well and the stories intertwining with one another was amazingly well written',
#  "I'm not going to be doing the acting/cast the way i usually do a person in the cast but I'm going to do the chemistry",
#  'the other one is Gong Yoo and Kim Go Eun had great chemistry, and Gong Yoo and Kim Go Eun had great chemistry with Gong Yoo and Kim Go Eun romance was really well done',
#  'Honorable mention to the chemistry',
#  "It wasn't until later did I finally feel the Kim Shin and Eun Tak subtle chemistry, then I fell head in for the Kim Shin and Eun Tak in the second half",
#  'the Kim Shin and Eun Tak history lent the Kim Shin and Eun Tak romance more weight but the Kim Shin and Eun Tak is filled with charged, tense chemistry all on the Kim Shin and Eun Tak own',
#  'SO much chemistry',
#  'The Grim Reaper and Sunny have an incredible chemistry on set',
#  'I just expected a little more at that point as they share great chemistry',
#  'The story is simple but unique, sad but funny, the details, cinematography, ost, especially the acting and chemistry are superb',
#  'The best part is of course the characters, the surprising chemistry and the relationships',
#  'The cast had a really good chemistry and the story was great',
#  'The people who worked behind the drama did a lot of improvisation and I think this shows how good The people who worked behind the drama skills are and how good The people who worked behind the drama chemistry is',
#  'But Euk Tak was way too whiny, had no chemistry with the Goblin, and they dragged everything on for EVER',
#  'There was no chemistry between the two leads',
#  'Sunny and the Grim reaper has the best chemistry of all time, it was such a sad love story but had a very realistic ending',
#  'It s undeniable that Sunny and the Reaper s relationship had a level of comical chemistry between essentially a naive man with lacking social interactions , and a social butterfly each seeking their own comfort within one another s company',
#  "The relationship always felt more familial, and age gap aside, I just didn't feel any chemistry between the main couple",
#  'their chemistry is on point, even much better than the chemistry between goblin and Ji Chang Wook bride',
#  "Sadly, for me, GY and Kim Go Eun didn't have Their chemistry",
#  "It's just that GY and Kim Go Eun don't have Their chemistry",
#  "Lee Dong Wook and Gong Yoo's In Na's chemistry is even better than Lee Dong Wook and Yoo",
#  'However, the chemistry between Gong Yoo and Kim Go Eun was amazing',
#  "I personally adored Kim Shin and Eun Tak's chemistry and story and The love stories",
#  'I was entranced by The love stories story and chemistry',
#  'their story and chemistry was also sweet',
#  'Each character had beautiful chemistry',
#  'especially the chemistry between the Goblin and Ji Euk Tak',
#  'And Lee Dong Wook chemistry with Gong Yoo in na was very nice',
#  'The chemistry between the leads is one of the best i can find in kdrama',
#  'I never really got why the two mains would fall in love, but once the plot moves past that point, the two mains have good chemistry together',
#  "Though Kim Go Eun and Gong Yoo illustrate such chemistry through the series, it has to be said that Gong Yoo and Lee Dong Wook's bromance steal the show",
#  'The chemistry betythe actors was amazing and the story had me hooked from the first episode all the way to the end',
#  'more than one actor have great chemistry, more than one actor bromance was awesome and their bromance sometimes overshadowed the main couple',
#  "Like I said, Kim Go Eun chemistry with Gong Yoo was there but there were times I didn't feel as much for Goblin/Eun Tak couple as I did for Goblin/Grim Reaper",
#  "Gong Yoo and Lee Dong-wook had the best chemistry out of all male actors I've seen so far",
#  "if u r here, then chances r u have already heard of all the hype and the positive stuff about it, time for the other side of the coin review, goblin starts out with a fantasy story that is really damn good, first episodes takes a while so u scroll down to find goblin's episodes r actually 90 minutes long, okay so thats a fancy sneaky way to advertise a 24 episode show being 16 longish episodes, acting is great , nearly every actor/actress feels perfect for the role except for the little important main lead actress Kim Go-Eun, nearly every actor/actress feels so wrong casted on so many levels, something just feels off from first time u see nearly every actor/actress on the screen, 12 years difference between nearly every actor/actress and gong yoo just adds oil to the chemistry on fire already, , every other single relationship between the characters is perfect, the chemistry is just amazing inbetween the rest of the cast execution",
#  "And Sungjae's acting chemistry with Lee Da Hee felt so real",
#  'the main couple, the Goblin and his bride, was kind of strange and unrelatable screen time is so strong and made me quite anxious each and every episode, the main couple, the Goblin and his bride, was kind of strange and unrelatable chemistry is unbelievable, the main couple, the Goblin and his bride, was kind of strange and unrelatable definitely need a separate series',
#  "The chemistry all the actors have with each other is amazing and it's so exciting to see how all the actors change throughout the series",
#  'Loved all the characters and all of about even if it s so popular chemistry',
#  'On the other hand, the chemistry on this set was absolutely incredible',
#  'The chemistry between the actors is always there, between all of the actors and kudos for the main couple, even tho the female lead is younger than her male lead co star and has less experience, her was sooo good at it, i mean her has such potential her can mesmerize you with just one look, her eyes spoke in every scene with such emotion it gave me chills',
#  "If I didn't focus on a high school student and an immortal being who looked like he was in his late 30s supposed romance, I think a high school student and an immortal being who looked like he was in his late 30s chemistry suited a high school student and an immortal being who looked like he was in his late 30s well as a HS student and a 39 year old man",
#  'The chemistry of the two couples is so intense, sweet and tragic that The chemistry of the two couples even made my heart flutter',
#  'And the chemistry among all the cast is also great',
#  'The main leads look strange together due to the large age difference, even though their chemistry makes up for their chemistry',
#  'Gong Yoo still has more chemistry with both Dong Wook and Sung Jae than Go Eun',
#  "I think I enjoyed In Na's and Dong Wook relationship more, because they were more age appropiate and also, because they had more history and chemistry together",
#  "But the cast was so endearing, it's Gong Yoo's first drama back in so long, Gong Yoo's chemistry with Lee Dong Wook was so on point, Shin  and  Grim Reaper were adorkable beta heroes kdramaland don't always get, and I'm a sucker for fantasy about gods so I stuck on",
#  'Once his chemistry with Lee Dong Wook finally got over the first pulling of the sword out of the way, the pacing improved and slowly built up',
#  'The age gap between the two main couple annoyed me at first since both of the two main couple are great actors but both of them are great actors do much better when both of them are great actors have a partner with sizzling chemistry but I chose to ignore it and just enjoy it',
#  'The two main male characters even have more friendly/brotherly chemistry than the main couple',
#  "Also, the chemistry between the cast (sorry, main leads not included I just can't see/feel it) is superb",
#  "I was seriously absorbed into this show, and I didn't even want to skip the parts with the secondary leads (Lee Dong Wook and Gong Yoo In Na) because they were so good too, they had such chemistry",
#  "i love the chemistry between the main leads sooooooo much i hope they make another drama with same cast specially dong wook  and  in na all about the story was amazing the romance parts was brilliant i love the romance parts except the religious part about god  and  angels i felt the romance parts was really disgracing my mind and the END as usual *if the writer was controlling destiny and God's behavior y the writer didn't make the goblin's bride immortal as the writer *y the writer didn't make the writer friend  and  the writer sister remembered the writer *y the writer insists till the end to torture  and  punish the writer for something wasn't the writer fault ommo that's really bothered me alotA lot of drama bite off more than they can chew when tackling plots and after binge watching show after show that couldn't neatly tie they story lines together, Goblin was a happy surprise",
#  'The chemistry between the main male leads was invincible as well as the chemistry between the female leads, This drama truly showed that love was an umbrella to many different types i',
#  'Likewise, the romantic aspect of it was also very well thought, the chemistry between the actors felt so real I almost thought the actors were dating in real life',
#  'And Lee dong wook and yooinna stole my heart by Lee dong wook and yooinna natural chemistry and ofcaz goblin and grimreaper ( brother in law and goblin) bro romance the best part of show , I hate how their natural chemistry and ofcaz goblin and grimreaper ( brother in law and goblin) story developee',
#  'their natural chemistry and ofcaz goblin and grimreaper ( brother in law and goblin) could kill the main violent by grim reapper because he actually killed the king both life , noting lose of goblin story',
#  'And most touchy part was grimreaper sunny true love story and best chemistry was Lee dong wook and yooinna togather are best alwaysI had put off watching Goblin for the longest time because from what I had heard of it I knew it would become my favorite drama out there, and I was right',
#  'I had no choice but to give the cast 10/10 because the chemistry was simply great, be it the lead couple or the second lead',
#  'The kissing scenes are cute but there is no real chemistry, however, things change after Eun Tak comes back to life and Eun Tak is 10 years older and obviously more mature',
#  'As for the secondary couple Sunny and the Grim Reaper, I think the secondary couple Sunny and the Grim Reaper story was a much more relatable and deep love story but for some reason I did not really like Sunny as a character and also felt that there was no real chemistry between the secondary couple Sunny and the Grim Reaper which made the secondary couple Sunny and the Grim Reaper love story kind of a wasted potential',
#  "Moving to the cast, you really can't get better chemistry between a male and female lead than this adding to the fact that the secondary m lead and f lead is also a perfect match",
#  'the characters have such good chemistry that you feel like you are part of the drama',
#  'I have not seen two male actors share such an easy yet fiery chemistry on-screen for a long time',
#  'The chemistry with all of the characters/actors was just one of a kind',
#  'From main lead to second lead, /actors was able to have a chemistry that was sweet and respectful',
#  'The chemistry between Kim Shin (goblin) and Ji Eun-Tak (goblin bride) was the purest thing I have ever seen',
#  'I was really worried I would not like The chemistry between Kim Shin (goblin) and Ji Eun-Tak (goblin bride) together, but please give The chemistry between Kim Shin (goblin) and Ji Eun-Tak (goblin bride) a chance',
#  'A few more scenes you will be in love with The chemistry between Kim Shin (goblin) and Ji Eun-Tak (goblin bride) as I did',
#  'The actors did an amazing job The actors conveyed the characters so well and The actors had so much chemistry in this drama and in the BTS, I think we really have to give The actors an applause for The actors crying scenes cause honestly every time The actors cried I felt it, I remember there was a part that Kim Go Eun cried (Kim Go Eun played Ji Eun Tak) and Kim Go Eun cries sounded to melancholy and so real the way Kim Go Eun gasping for air I myself just couldn t stop crying with Kim Go Eun',
#  'The romance between Sunny and the Grim Reaper have great chemistry and I could totally see why Touch your Heart was made after this show',
#  "I believe the general idea of Eun Tak and Kim Shin's relationship was to portray Eun Tak and Kim Shin's relationship as a married couple/destined lovers (the Goblin and the bride) which I immediately noticed through episode 1, through Gong Yoo and Go Eun's chemistry",
#  "Eun Tak and Kim Shin's relationship delivered that 'married couple' chemistry really well, never once faltering and keeping 'married couple' chemistry consistent through every episode",
#  "Overall, for those who have yet to watch Goblin, I highly recommend watching 'married couple' chemistry",
#  "I finished 'married couple' chemistry a few days ago and 'married couple' chemistry's still in my mind",
#  'I highly disagree with people who think they had no chemistry and instead had a father-daughter relationship',
#  'The romance, the bromance, the comedy, the costumes, the jackets, the magic, the chemistry between the entire cast, the plot, the history, The memorable scenes, the beautiful kisses, And an ending that had me thinking about it for weeks',
#  'What I Disliked I felt absolutely no chemistry between the male leads, personally',
#  'I loved the second couple and I loved the supporting characters chemistry ',
#  "It seemed Great friendship between Gong Yoo and Lee Dong Wook're friends in real life Great chemistry between Lee Dong Wook and Yoo In Na",
#  'Yoo Inna Scenes with Lee Dongwook were so intensive and the chemistry was the best',
#  'The chemistry betweeen them both is gr8, Kim shin looks like lack of emotion and in many scene Kim shin chose to keep quiet and lack of reaction',
#  'The comedic chemistry between the two male actors had me in stitches',
#  'mp3 and I ll be a wreck) Quality storyline Slow and steady pacing Great acting Superb chemistry for our main 2 romantic couples (and bromance couple) I took my time watching this show in order to savour this show beauty',
#  'Loved the bromance, they shared amazing chemistry',
#  'After watching Goblin, I find that the thing I love the most about it is the chemistry between the cast members, and not just the main couple but, for example, between Gong Yoo and Lee Dong Wook',
#  'the story was great, the ending ok, amazing chemistry, would recommendSo much people I know who have reservations in watching this show, but once they watch this show its in they top 5, Just give this show a go',
#  'Lee Dong Wook and Yoo In-Na were a great couple full of chemistry',
#  'The theme of the story is great like applause to the writers, but the actors age gap made a bit uncomfortable but i could understand why the actors age gap chose the writers , the actors age gap chemistry was GREAT, and i was so into the writers i cried oceans i laughed hysterically',
#  'The theme of the story is great like applause to the writers, but the actors age gap made a bit uncomfortable but i could understand why the actors age gap chose the writers , the actors age gap chemistry was GREAT, and i was so into the writers i cried oceans i laughed hysterically',
#  'To me the story dragged, the chemistry was quietly simmering throughout in a beautifully shot drama',
#  'this character is really good and the chemistry between everyone who said is just awe-some',
#  'But despite that, I really felt some great chemistry between they',
#  "I don't think Post-Goblin would have been great had it been for the actors and the chemistry between the actors and the chemistry between them",
#  'Love story and chemistry were amazing',
#  "I love first couple's romance,it was naturally and I felt Love story and chemistry understood each other great",
#  "I didn't quite believe that there will be chemistry between the two leads, but they really impressed me",
#  'Sunny and Grim Reaper also displayed they subtle chemistry that I liked a lot',
#  'The 2 male leads have a genuine bromance going on, loads of chemistry, so much a viewer could feel it',
#  'The 4 leads have good chemistry together']

# %%
# txt = "Lee El's chemistry with Grim Reaper is daebak"
for txt in chem:
# txt = 'Sunny and Grim Reaper has the best chemistry of all time'
    doc = nlp(txt)
    from spacy import displacy
    displacy.render(doc, style='dep')
    print(doc.ents)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a56c1e58da224be288f4e818a5201058-0" class="displacy" width="3200" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">writers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">held</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">chemistry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">nourished</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">chemistry,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Goblin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">would</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">much</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">better</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a56c1e58da224be288f4e818a5201058-0-0" stroke-width="2px" d="M70,527.0 C70,264.5 560.0,264.5 560.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a56c1e58da224be288f4e818a5201058-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,529.0 L62,517.0 78,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a56c1e58da224be288f4e818a5201058-0-1" stroke-width="2px" d="M245,527.0 C245,439.5 375.0,439.5 375.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a56c1e58da224be288f4e818a5201058-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,529.0 L237,517.0 253,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a56c1e58da224be288f4e818a5201058-0-2" stroke-width="2px" d="M420,527.0 C420,439.5 550.0,439.5 550.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a56c1e58da224be288f4e818a5201058-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,529.0 L412,517.0 428,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a56c1e58da224be288f4e818a5201058-0-3" stroke-width="2px" d="M595,527.0 C595,2.0 2675.0,2.0 2675.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a56c1e58da224be288f4e818a5201058-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,529.0 L587,517.0 603,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a56c1e58da224be288f4e818a5201058-0-4" stroke-width="2px" d="M595,527.0 C595,439.5 725.0,439.5 725.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a56c1e58da224be288f4e818a5201058-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M725.0,529.0 L733.0,517.0 717.0,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a56c1e58da224be288f4e818a5201058-0-5" stroke-width="2px" d="M595,527.0 C595,352.0 905.0,352.0 905.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="
# (Goblin,)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="809bdf903a8244f2ba57019cb3e77c61-0" class="displacy" width="5825" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">sweet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">cute</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">moments</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Goblin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">couple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">sizzling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">chemistry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">between</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Grim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Reaper</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Sunny</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">enough</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">keep</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">the '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">romance'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">meter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">great</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">drama</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">NO
# (Grim Reaper and Sunny,)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="23aa2da087b14daea0444164f6c46f93-0" class="displacy" width="1450" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">chemistry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">between</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">male</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">cast</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">flawless</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-23aa2da087b14daea0444164f6c46f93-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-23aa2da087b14daea0444164f6c46f93-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-23aa2da087b14daea0444164f6c46f93-0-1" stroke-width="2px" d="M245,352.0 C245,2.0 1100.0,2.0 1100.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-23aa2da087b14daea0444164f6c46f93-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-23aa2da087b14daea0444164f6c46f93-0-2" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-23aa2da087b14daea0444164f6c46f93-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M385.0,354.0 L393.0,342.0 377.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-23aa2da087b14daea0444164f6c46f93-0-3" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-23aa2da087b14daea0444164f6c46f93-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-23aa2da087b14daea0444164f6c46f93-0-4" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-23aa2da087b14daea0444164f6c46f93-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-23aa2da087b14daea0444164f6c46f93-0-5" stroke-width="2px" d="M420,352.0 C420,89.5 920.0,89.5 920.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-23aa2da087b14daea0444164f6c46f93-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,354.0 L928.0,342.0 912.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-23aa2da087b14daea0444164f6c46f93-0-6" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-23aa2da087b14daea0444164f6c46f93-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1260.0,354.0 L1268.0,342.0 1252.0,342.0" fill="currentColor"/>
# </g>
# </svg></span>
# ()
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8e0516a8460a4da0bb9f68e3da5b27b3-0" class="displacy" width="7050" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">acting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">brilliant,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">chemistry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">outstanding (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">bromance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">history</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Kdrama</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">between</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Gong Yoo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Lee Dong Wook ),</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">music</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">so</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">good</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">when</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">hear</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">chemistry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">outside</tspan>
#     <tspan class="displacy-tag" dy="2em"
# (Kdrama, Gong Yoo, Lee Dong Wook)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="49ddb28eb15a41718010c01efaf55545-0" class="displacy" width="1625" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">(</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">chemistry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">between</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">OTP</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">fine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-49ddb28eb15a41718010c01efaf55545-0-0" stroke-width="2px" d="M70,439.5 C70,2.0 1275.0,2.0 1275.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-49ddb28eb15a41718010c01efaf55545-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-49ddb28eb15a41718010c01efaf55545-0-1" stroke-width="2px" d="M245,439.5 C245,89.5 1270.0,89.5 1270.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-49ddb28eb15a41718010c01efaf55545-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-49ddb28eb15a41718010c01efaf55545-0-2" stroke-width="2px" d="M420,439.5 C420,352.0 555.0,352.0 555.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-49ddb28eb15a41718010c01efaf55545-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-49ddb28eb15a41718010c01efaf55545-0-3" stroke-width="2px" d="M595,439.5 C595,177.0 1265.0,177.0 1265.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-49ddb28eb15a41718010c01efaf55545-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587,429.5 603,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-49ddb28eb15a41718010c01efaf55545-0-4" stroke-width="2px" d="M595,439.5 C595,352.0 730.0,352.0 730.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-49ddb28eb15a41718010c01efaf55545-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M730.0,441.5 L738.0,429.5 722.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-49ddb28eb15a41718010c01efaf55545-0-5" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-49ddb28eb15a41718010c01efaf55545-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,441.5 L937,429.5 953,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-49ddb28eb15a41718010c01efaf55545-0-6" stroke-width="2px" d="M770,439.5 C770,264.5 1085.0,264.5 1085.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-49ddb28eb15a41718010c01efaf55545-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1085.0,441.5 L1093.0,429.5 1077.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-49ddb28eb15a41718010c01efaf55545-0-7" stroke-width="2px" d="M1295,439.5 C1295,352.0 1430.0,352.0 1430.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-49ddb28eb15a41718010c01efaf55545-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1430.0,441.5 L1438.0,429.5 1422.0,429.5" fill="currentColor"/>
# </g>
# </svg></span>
# (OTP,)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8fd4c1e1b7fc450b878b56e6903407ee-0" class="displacy" width="8100" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">chemistry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">between</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">little</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">awkward,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">woman</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">falling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">love</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">stalker</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">because</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">woman</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">falling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">love</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">stalker</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">psychological</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">problems</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">which</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530
# ()
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6942625f6fb74fcc82cb3de4f97a5cc3-0" class="displacy" width="7925" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">only</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">redeeming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">thing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">drama</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">is</tspan>
# ...
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aa56ad128953439b8fc934ba4967be38-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aa56ad128953439b8fc934ba4967be38-0-4" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aa56ad128953439b8fc934ba4967be38-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aa56ad128953439b8fc934ba4967be38-0-5" stroke-width="2px" d="M1120,352.0 C1120,177.0 1440.0,177.0 1440.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aa56ad128953439b8fc934ba4967be38-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aa56ad128953439b8fc934ba4967be38-0-6" stroke-width="2px" d="M1295,352.0 C1295,264.5 1435.0,264.5 1435.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aa56ad128953439b8fc934ba4967be38-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aa56ad128953439b8fc934ba4967be38-0-7" stroke-width="2px" d="M945,
# (Sunny and Grim Reaper,)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5dee85b95e574d44b6a14d80659ebf94-0" class="displacy" width="3550" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">male</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">leads</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">genuine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">bromance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">on,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">loads</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">chemistry,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">so</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">much</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">viewer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">could</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">feel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PRON</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5dee85b95e574d44b6a14d80659ebf94-0-0" stroke-width="2px" d="M70,439.5 C70,177.0 565.0,177.0 565.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5dee85b95e574d44b6a14d80659ebf94-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5dee85b95e574d44b6a14d80659ebf94-0-1" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5dee85b95e574d44b6a14d80659ebf94-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5dee85b95e574d44b6a14d80659ebf94-0-2" stroke-width="2px" d="M420,439.5 C420,352.0 555.0,352.0 555.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5dee85b95e574d44b6a14d80659ebf94-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5dee85b95e574d44b6a14d80659ebf94-0-3" stroke-width="2px" d="M595,439.5 C595,352.0 730.0,352.0 730.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5dee85b95e574d44b6a14d80659ebf94-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587,429.5 603,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5dee85b95e574d44b6a14d80659ebf94-0-4" stroke-width="2px" d="M945,439.5 C945,264.5 1260.0,264.5 1260.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5dee85b95e574d44b6a14d80659ebf94-0-4" class="displacy-label" startOffset="50%" side="lef
# (2,)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1b39089345944122b73ad89e5bd9d8f7-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">4</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">leads</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">good</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">chemistry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">together</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b39089345944122b73ad89e5bd9d8f7-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b39089345944122b73ad89e5bd9d8f7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b39089345944122b73ad89e5bd9d8f7-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b39089345944122b73ad89e5bd9d8f7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b39089345944122b73ad89e5bd9d8f7-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b39089345944122b73ad89e5bd9d8f7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b39089345944122b73ad89e5bd9d8f7-0-3" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b39089345944122b73ad89e5bd9d8f7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b39089345944122b73ad89e5bd9d8f7-0-4" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b39089345944122b73ad89e5bd9d8f7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b39089345944122b73ad89e5bd9d8f7-0-5" stroke-width="2px" d="M595,264.5 C595,2.0 1100.0,2.0 1100.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b39089345944122b73ad89e5bd9d8f7-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,266.5 L1108.0,254.5 1092.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>
# (4,)

# %%
txt = chem[36]
# txt = "Best chemistry was Gong Yoo and Kim Go Eun together"
# txt = "The chemistry the male actors have with each other was amazing"
doc = nlp(txt)
from spacy.matcher import DependencyMatcher
def find_obj(doc):
    matches = matcher(doc)
    print(matches) # [(4851363122962674176, [6, 0, 10, 9])]
    # Each token_id corresponds to one pattern dict
    match_id, token_ids = matches[0]
    print(nlp.vocab.strings[match_id])
    for i in range(len(token_ids)):
        print(doc[token_ids[i]].text)

# find_obj(doc)
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3aa83de47f4e4297a4452befde701010-0" class="displacy" width="4425" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Sunny</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Grim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">reaper</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">chemistry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">time,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">such</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">sad</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">love</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">story</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">realistic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">ending</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3aa83de47f4e4297a4452befde701010-0-0" stroke-width="2px" d="M70,702.0 C70,2.0 2325.0,2.0 2325.0,702.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3aa83de47f4e4297a4452befde701010-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,704.0 L62,692.0 78,692.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3aa83de47f4e4297a4452befde701010-0-1" stroke-width="2px" d="M70,702.0 C70,614.5 190.0,614.5 190.0,702.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3aa83de47f4e4297a4452befde701010-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190.0,704.0 L198.0,692.0 182.0,692.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3aa83de47f4e4297a4452befde701010-0-2" stroke-width="2px" d="M420,702.0 C420,527.0 720.0,527.0 720.0,702.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3aa83de47f4e4297a

# %%
matcher = DependencyMatcher(nlp.vocab)
pattern1 = [
    {
        "RIGHT_ID": "chemistry",
        "RIGHT_ATTRS": {"ORTH": "chemistry"}
    },
    {
        "LEFT_ID": "chemistry",
        "REL_OP": ">", #'.*''
        "RIGHT_ID": "chem_prep",
        "RIGHT_ATTRS": {"DEP": "prep"},
    },
    {
        "LEFT_ID": "chem_prep",
        "REL_OP": ">",
        "RIGHT_ID": "object",
        "RIGHT_ATTRS": {"DEP": "pobj"},
    },
    {
        "LEFT_ID": "object",
        "REL_OP": ">",
        "RIGHT_ID": "conjunct",
        "RIGHT_ATTRS": {"DEP": {"IN": ["conj", "amod", "nummod", "compound"]}}, #conj: between A and B; amod: between the male cast; compound: between Goblin couple
    }
]# chem between A and B
pattern2 = [
    {
        "RIGHT_ID": "chemistry",
        "RIGHT_ATTRS": {"ORTH": "chemistry"}
    },
    {
        "LEFT_ID": "chemistry",
        "REL_OP": ">",
        "RIGHT_ID": "chem_prep",
        "RIGHT_ATTRS": {"DEP": "prep"},
    },
    {
        "LEFT_ID": "chem_prep",
        "REL_OP": ">",
        "RIGHT_ID": "object",
        "RIGHT_ATTRS": {"DEP": "pobj"},
    },
    {
        "LEFT_ID": "object",
        "REL_OP": ">",
        "RIGHT_ID": "det",
        "RIGHT_ATTRS": {"DEP": "det"},
    }
]# chem between the couple
pattern3 = [
    {
        "RIGHT_ID": "chemistry",
        "RIGHT_ATTRS": {"ORTH": "chemistry"}
    },
    {
        "LEFT_ID": "chemistry",
        "REL_OP": ">",
        "RIGHT_ID": "chem_prep",
        "RIGHT_ATTRS": {"DEP": "prep"},
    },
    {
        "LEFT_ID": "chem_prep",
        "REL_OP": ">",
        "RIGHT_ID": "object",
        "RIGHT_ATTRS": {"DEP": "pobj"},
    }
]# chem between couple
# pattern2 = [
#     {
#         "RIGHT_ID": "chemistry",
#         "RIGHT_ATTRS": {"ORTH": "chemistry"}
#     },
#     {
#         "LEFT_ID": "chemistry",
#         "REL_OP": ">", #'.*''
#         "RIGHT_ID": "chem_prep",
#         "RIGHT_ATTRS": {"DEP": "prep"},
#     },
#     {
#         "LEFT_ID": "chem_prep",
#         "REL_OP": ">",
#         "RIGHT_ID": "object",
#         "RIGHT_ATTRS": {"DEP": "pobj"},
#     }
# ] for 'the chemistry between they'
pattern4 = [
    {
        "RIGHT_ID": "chem_root",
        "RIGHT_ATTRS": {"LEMMA": {"IN": ["have", "share", "illustrate"]}}
    },
    {
        "LEFT_ID": "chem_root",
        "REL_OP": ">",
        "RIGHT_ID": "subject",
        "RIGHT_ATTRS": {"DEP": "nsubj"},
    },
    {
        "LEFT_ID": "chem_root",
        "REL_OP": ">", 
        "RIGHT_ID": "chemistry",
        "RIGHT_ATTRS": {"ORTH": "chemistry", "DEP": "dobj"},
    },
    {
        "LEFT_ID": "chemistry",
        "REL_OP": ">", 
        "RIGHT_ID": "chem_prep",
        "RIGHT_ATTRS": {"DEP": "prep"},
    },
    {
        "LEFT_ID": "chem_prep",
        "REL_OP": ">",
        "RIGHT_ID": "object",
        "RIGHT_ATTRS": {"DEP": "pobj"},
    }
]# A have chem with B
pattern5 = [
    {
        "RIGHT_ID": "chem_root",
        "RIGHT_ATTRS": {"LEMMA": {"IN": ["have", "share", "illustrate"]}}
    },
    {
        "LEFT_ID": "chem_root",
        "REL_OP": ">",
        "RIGHT_ID": "chemistry",
        "RIGHT_ATTRS": {"ORTH": "chemistry", "DEP": "dobj"},
    },
    {
        "LEFT_ID": "chem_root",
        "REL_OP": ">",
        "RIGHT_ID": "subject",
        "RIGHT_ATTRS": {"DEP": "nsubj"},
    },
    {
        "LEFT_ID": "subject",
        "REL_OP": ">",
        "RIGHT_ID": "conjunct",
        "RIGHT_ATTRS": {"DEP": {"IN": ["amod", "nummod", "compound", "conj"]}},
    }
]# A and B have good chem
pattern6 = [
    {
        "RIGHT_ID": "chem_root",
        "RIGHT_ATTRS": {"LEMMA": {"IN": ["have", "share"]}}
    },
    {
        "LEFT_ID": "chem_root",
        "REL_OP": ">", 
        "RIGHT_ID": "chemistry",
        "RIGHT_ATTRS": {"ORTH": "chemistry", "DEP": "dobj"},
    },
    {
        "LEFT_ID": "chem_root",
        "REL_OP": ">",
        "RIGHT_ID": "subject",
        "RIGHT_ATTRS": {"DEP": "nsubj"},
    },
    {
        "LEFT_ID": "subject",
        "REL_OP": ">",
        "RIGHT_ID": "conjunct",
        "RIGHT_ATTRS": {"DEP": "det"},
    }
]# the couples have good chem
pattern7 = [
    {
        "RIGHT_ID": "chemistry",
        "RIGHT_ATTRS": {"ORTH": "chemistry"}
    },
    {
        "LEFT_ID": "chemistry",
        "REL_OP": ">", 
        "RIGHT_ID": "chem_poss",
        "RIGHT_ATTRS": {"DEP": "poss"},
    },
    {
        "LEFT_ID": "chemistry",
        "REL_OP": "<", # ";*" this may have some problem, not accurate enough, such as chem[95]
        "RIGHT_ID": "conj",
        "RIGHT_ATTRS": {"POS": "PROPN"}, # why cannot "DEP": "conj"
    }
] # A and B's chem
pattern8 = [
    {
        "RIGHT_ID": "chemistry",
        "RIGHT_ATTRS": {"ORTH": "chemistry"}
    },
    {
        "LEFT_ID": "chemistry",
        "REL_OP": ">", #'.*''
        "RIGHT_ID": "chem_poss",
        "RIGHT_ATTRS": {"DEP": "poss"},
    },
    {
        "LEFT_ID": "chemistry",
        "REL_OP": ">", 
        "RIGHT_ID": "chem_prep",
        "RIGHT_ATTRS": {"DEP": "prep"},
    },
    {
        "LEFT_ID": "chem_prep",
        "REL_OP": ">", 
        "RIGHT_ID": "obj",
        "RIGHT_ATTRS": {"DEP": "pobj"},
    }
] # A's chem with B
pattern9 = [
    {
        "RIGHT_ID": "chemistry",
        "RIGHT_ATTRS": {"LOWER": "chemistry"}
    },
    {
        "LEFT_ID": "chemistry",
        "REL_OP": ">", 
        "RIGHT_ID": "clause",
        "RIGHT_ATTRS": {"DEP": "relcl"},
    },
    {
        "LEFT_ID": "clause",
        "REL_OP": ">",
        "RIGHT_ID": "subject",
        "RIGHT_ATTRS": {"DEP": "nsubj"},
    },
    {
        "LEFT_ID": "subject",
        "REL_OP": ">",
        "RIGHT_ID": "conjunct",
        "RIGHT_ATTRS": {"DEP": {"IN": ["amod", "nummod", "compound", "det"]}}, #conj: between A and B; amod: between the male cast; compound: between Goblin couple
    }
]# the chemistry all the actors have was amazing"
matcher.add("CHEMISTRY1", [pattern1])
matcher.add("CHEMISTRY2", [pattern2])
matcher.add("CHEMISTRY3", [pattern3])
matcher.add("CHEMISTRY4", [pattern4])
matcher.add("CHEMISTRY5", [pattern5])
matcher.add("CHEMISTRY6", [pattern6])
matcher.add("CHEMISTRY7", [pattern7])
matcher.add("CHEMISTRY8", [pattern8])
matcher.add("CHEMISTRY9", [pattern9])

# %% [markdown]
# dep_
# sunny: conj
# sunny: poss
#
#
# about chemistry:
# A and B chemistry is xx
# A and B have chemistry
# The chemistry between A and B is xx

# %% [markdown]
# ### problems:
# - imcompatibilty of neuralcoref with spacy 3.0 (need to run that seperately and convert to new csv, ideally we should add that to pipeline) <br>
# And dependency matcher is only available in spacy 3.0
# - Sunny and Grim Reaper: problem of ner, probably because of their names. Maybe need to overwrite entity
# - txt = "Lee El chemistry with Grim Reaper is daebak" <br>
# neuralcoref will not automatically change it to Lee El's. It affects .dep_ when extracting the subjects
# - others: dealing with acronyms and words like sooo goood, daebak <br>
# - some have different ways of spelling names, i juse use the spelling from the website
#
# ## others
# - some sentences don't match the dependency pattern (is it enough?)
# - if it's ok with chemistry, use the same way, it should work on other keywords (more key words)
# - overwritng ents
# - image

# %%
spacy.explain('relcl')
# Out:
# 'relative clause modifier'
