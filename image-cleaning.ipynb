# %%
import pandas as pd

# %%
cd Desktop/CZ1016_DS2/kdrama
# Out:
# [Errno 2] No such file or directory: 'Desktop/CZ1016_DS2/kdrama'
# /Users/valencialie/Desktop/CZ1016_DS2/kdrama

# %%
image = pd.read_csv("genfin.csv")

# %%
image_unique = image.drop_duplicates("Name")

# %%
image_unique
# Out:
#       Unnamed: 0  Gender                                   Image  \
# 0              0    Male    https://i.mydramalist.com/6Lz0Pc.jpg
# 1              1    Male    https://i.mydramalist.com/EPWJzc.jpg
# 2              2  Female  https://i.mydramalist.com/Xyp0q_5c.jpg
# 3              3  Female  https://i.mydramalist.com/4BNPJ_5c.jpg
# 4              4    Male    https://i.mydramalist.com/oQ4dxc.jpg
# ...          ...     ...                                     ...
# 3903        6385    Male    https://i.mydramalist.com/jrEQvc.jpg
# 3910        6392    Male    https://i.mydramalist.com/2qKdOc.jpg
# 3923        6405  Female    https://i.mydramalist.com/rEmV7c.jpg
# 3941        6423  Female    https://i.mydramalist.com/wA78nc.jpg
# 3944        6426    Male  https://i.mydramalist.com/B1OQ7_5c.jpg
#
#                 Name
# 0     Lee Shin Young
# 1      Jung Woong In
# 2         Lee Da Hee
# 3         Seo Ji Hye
# 4      Yoon Joo Sang
# ...              ...
# 3903  Jang Woo Young
# ...

# %%
images = image_unique.reset_index().drop(['index', 'Unnamed: 0'], axis = 1)

# %%
images
# Out:
#       Gender                                   Image            Name
# 0       Male    https://i.mydramalist.com/6Lz0Pc.jpg  Lee Shin Young
# 1       Male    https://i.mydramalist.com/EPWJzc.jpg   Jung Woong In
# 2     Female  https://i.mydramalist.com/Xyp0q_5c.jpg      Lee Da Hee
# 3     Female  https://i.mydramalist.com/4BNPJ_5c.jpg      Seo Ji Hye
# 4       Male    https://i.mydramalist.com/oQ4dxc.jpg   Yoon Joo Sang
# ...      ...                                     ...             ...
# 1010    Male    https://i.mydramalist.com/jrEQvc.jpg  Jang Woo Young
# 1011    Male    https://i.mydramalist.com/2qKdOc.jpg      Eun Ji Won
# 1012  Female    https://i.mydramalist.com/rEmV7c.jpg       Kim Da Mi
# 1013  Female    https://i.mydramalist.com/wA78nc.jpg      Moon So Ri
# 1014    Male  https://i.mydramalist.com/B1OQ7_5c.jpg    Jo Hyun Chul
#
# [1015 rows x 3 columns]

# %%
images.to_csv("images.csv")

# %%
images
# Out:
#       Gender                                   Image            Name
# 0       Male    https://i.mydramalist.com/6Lz0Pc.jpg  Lee Shin Young
# 1       Male    https://i.mydramalist.com/EPWJzc.jpg   Jung Woong In
# 2     Female  https://i.mydramalist.com/Xyp0q_5c.jpg      Lee Da Hee
# 3     Female  https://i.mydramalist.com/4BNPJ_5c.jpg      Seo Ji Hye
# 4       Male    https://i.mydramalist.com/oQ4dxc.jpg   Yoon Joo Sang
# ...      ...                                     ...             ...
# 1010    Male    https://i.mydramalist.com/jrEQvc.jpg  Jang Woo Young
# 1011    Male    https://i.mydramalist.com/2qKdOc.jpg      Eun Ji Won
# 1012  Female    https://i.mydramalist.com/rEmV7c.jpg       Kim Da Mi
# 1013  Female    https://i.mydramalist.com/wA78nc.jpg      Moon So Ri
# 1014    Male  https://i.mydramalist.com/B1OQ7_5c.jpg    Jo Hyun Chul
#
# [1015 rows x 3 columns]

# %%
images[images.Gender == "Female"]
# Out:
#       Gender                                   Image          Name
# 2     Female  https://i.mydramalist.com/Xyp0q_5c.jpg    Lee Da Hee
# 3     Female  https://i.mydramalist.com/4BNPJ_5c.jpg    Seo Ji Hye
# 9     Female  https://i.mydramalist.com/vgnXX_5c.jpg    Son Ye Jin
# 10    Female  https://i.mydramalist.com/depXW_5c.jpg  Cho Hye Jung
# 11    Female    https://i.mydramalist.com/1LRNyc.jpg  Kim Young Ae
# ...      ...                                     ...           ...
# 999   Female    https://i.mydramalist.com/Rez3xc.jpg  Chun Min Hee
# 1004  Female    https://i.mydramalist.com/KDXz0c.jpg         Sulli
# 1006  Female    https://i.mydramalist.com/qwydDc.jpg   Jun Ji Hyun
# 1012  Female    https://i.mydramalist.com/rEmV7c.jpg     Kim Da Mi
# 1013  Female    https://i.mydramalist.com/wA78nc.jpg    Moon So Ri
#
# [466 rows x 3 columns]

# %%
images = pd.read_csv("images.csv")
images.Name = images.Name.str.replace(' ', '_')
female = images[images.Gender == "Female"]
male = images[images.Gender == "Male"]
halfF = female['Name'].values
namefileF = ['/Users/valencialie/Downloads/Images/Female/' + i for i in halfF +".jpg"]
halfM = male['Name'].values
namefileM = ['/Users/valencialie/Downloads/Images/Male/' + i for i in halfM +".jpg"]

# %%
namefileM
# Out:
# ['/Users/valencialie/Downloads/Images/Male/Lee_Shin_Young.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Jung_Woong_In.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Yoon_Joo_Sang.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Ji_Chang_Wook.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Yang_Kyung_Won.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Kim_Jung_Hyun.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Oh_Min_Suk.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Kim_Chang_Wan.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Yoo_Jae_Myung.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Lee_Seung_Jun.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Lee_Si_Eon.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Jin_Goo.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Shim_Hyung_Tak.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Kang_Ki_Young.jpg',
#  '/Users/valencialie/Downloads/Images/Male/Kim_Woo_Bin.jpg',
# ...

# %%
list1 = list(images.Image)
list2 = list(images.ActorName)

# %%
list2
# Out:
# ['Ahn  Ji Hyun',
#  'Ahn Bo Hyun',
#  'Ahn Hyo Seop',
#  'Ahn Jae Hong',
#  'Ahn Jae Hyun',
#  'Ahn Jae Wook',
#  'Ahn Kil Kang',
#  'Ahn Nae Sang',
#  'Ahn Se Ha',
#  'Ahn Seung Gyun',
#  'Ahn So Hee',
#  'Ahn Suk Hwan',
#  'Alex',
#  'Bae Da Bin',
#  'Bae Hae Seon',
#  'Bae In Hyuk',
#  'Bae Jong Ok',
#  'Bae Min Jung',
#  'Bae Noo Ri',
#  'Bae Soo Bin',
#  'Bae Sung Woo',
#  'Bae Suzy',
#  'Baek Hyun Jin',
#  'Baek Jin Hee',
#  'Baek Sang Hee',
#  'Baek Seung Heon',
#  'Baek Soo Min',
#  'Baek Sung Hyun',
#  'BamBam',
#  'Bang Min Ah',
#  'Baro',
#  'Bona',
#  'Byeon Woo Seok',
#  'Byun Baek Hyun',
#  'Byun Jung Soo',
#  'Byun Woo Min',
#  'Byun Yo Han',
#  'Cha Eun Woo',
#  'Cha Hwa Yun',
#  'Cha In Ha',
#  'Cha Jung Won',
#  'Cha Seung Won',
#  'Cha Tae Hyun',
#  'Cha Ye Ryun',
#  'Chae Gook Hee',
#  'Chae Jung An',
#  'Chae Rim',
#  'Chae So Young',
#  'Chae Soo Bin',
#  'Chae Won Bin',
#  'Chan',
#  'Chani',
#  'Cho Hye Jung',
#  'Cho Yeo Jung',
#  'Choe Chan Yi',
# ...

# %%
list1 = list(female.Image) #URL 
list2 = list(namefileF) #FILE NAME
list3 = list(male.Image) #URL 
list4 = list(namefileM) #FILE NAME

# %%
list2
# Out:
# ['/Users/valencialie/Downloads/Images/Female/Lee_Da_Hee.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Seo_Ji_Hye.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Son_Ye_Jin.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Cho_Hye_Jung.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Kim_Young_Ae.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Kyung_Soo_Jin.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Lee_Joo_Young.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Shim_Hye_Jin.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Kim_Hee_Jung.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Kim_Ji_Won.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Seo_Jung_Yeon.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Song_Hye_Kyo.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Kim_So_Hyun.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Jung_Eun_Chae.jpg',
#  '/Users/valencialie/Downloads/Images/Female/Park_Shin_Hye.jpg',
# ...

# %%
len(images.Name.unique())
# Out:
# 1015

# %%
len(images.Image.unique())
# Out:
# 1015

# %%
images.ActorName = images.ActorName.str.replace(' ', '')

# %%
half = images['ActorName'].values
namefile = ['/Users/valencialie/Downloads/Images/' + i for i in half +".jpg"]

# %%
# Out:
# '/Users/valencialie/Downloads/Images/AhnBoHyun.jpg'

# %%
images.Image
# Out:
# 0         https://i.mydramalist.com/0NwROc.jpg
# 1       https://i.mydramalist.com/EoxeQ_5c.jpg
# 2         https://i.mydramalist.com/qw772c.jpg
# 3         https://i.mydramalist.com/27JKOc.jpg
# 4       https://i.mydramalist.com/dJjDW_5c.jpg
#                          ...
# 1011    https://i.mydramalist.com/BDbjb_5c.jpg
# 1012    https://i.mydramalist.com/BDbjb_5c.jpg
# 1013      https://i.mydramalist.com/kJzXkc.jpg
# 1014    https://i.mydramalist.com/Zm3Bk_5c.jpg
# 1015    https://i.mydramalist.com/XBAoq_5c.jpg
# Name: Image, Length: 1016, dtype: object

# %%
list1
# Out:
# ['https://i.mydramalist.com/0NwROc.jpg',
#  'https://i.mydramalist.com/EoxeQ_5c.jpg',
#  'https://i.mydramalist.com/qw772c.jpg',
#  'https://i.mydramalist.com/27JKOc.jpg',
#  'https://i.mydramalist.com/dJjDW_5c.jpg',
#  'https://i.mydramalist.com/RQNkY_5c.jpg',
#  'https://i.mydramalist.com/WQpx5c.jpg',
#  'https://i.mydramalist.com/1g5nQc.jpg',
#  'https://i.mydramalist.com/XODjZ_5c.jpg',
#  'https://i.mydramalist.com/10xkbc.jpg',
#  'https://i.mydramalist.com/QYwD2_5c.jpg',
#  'https://i.mydramalist.com/RJbqgc.jpg',
#  'https://i.mydramalist.com/KpgODc.jpg',
#  'https://i.mydramalist.com/zElVOc.jpg',
#  'https://i.mydramalist.com/EDX8Qc.jpg',
#  'https://i.mydramalist.com/x2gL3c.jpg',
#  'https://i.mydramalist.com/Qxym5_5c.jpg',
#  'https://i.mydramalist.com/xg1Kyc.jpg',
#  'https://i.mydramalist.com/xg1Kyc.jpg',
#  'https://i.mydramalist.com/X3jAJc.jpg',
#  'https://i.mydramalist.com/pOqyQc.jpg',
#  'https://i.mydramalist.com/pOqyQc.jpg',
# ...

# %%
len(images.Image.unique())
# Out:
# 940

# %%
images.Image
# Out:
# 0         https://i.mydramalist.com/0NwROc.jpg
# 1       https://i.mydramalist.com/EoxeQ_5c.jpg
# 2         https://i.mydramalist.com/qw772c.jpg
# 3         https://i.mydramalist.com/27JKOc.jpg
# 4       https://i.mydramalist.com/dJjDW_5c.jpg
#                          ...
# 1011    https://i.mydramalist.com/BDbjb_5c.jpg
# 1012    https://i.mydramalist.com/BDbjb_5c.jpg
# 1013      https://i.mydramalist.com/M7Dzec.jpg
# 1014    https://i.mydramalist.com/Zm3Bk_5c.jpg
# 1015    https://i.mydramalist.com/XBAoq_5c.jpg
# Name: Image, Length: 1016, dtype: object

# %%
list

# %%
list2= list(namefile)

# %%
list2[2]
# Out:
# '/Users/valencialie/Downloads/Images/AhnHyoSeop.jpg'
