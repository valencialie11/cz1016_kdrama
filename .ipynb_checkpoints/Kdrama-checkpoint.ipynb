# %%
import pandas as pd
import re

# %% [markdown]
# # Cleaning Data
#
# Mainly cleaning the first csv we scraped and cleaning the URL for us to scrape next.

# %%
csv = pd.read_csv("kdrama.csv")

# %%
csv.URL = csv.URL.str.split(">")

# %%
csv.URL = csv['URL'].str[0]

# %%
csv.URL = csv.URL.str.split("=")

# %%
csv.URL = csv['URL'].str[1]

# %%
csv.URL = csv.URL.str.replace('"', '')

# %%
#csv.to_csv("kdramaclean.csv")

# %%
clean = pd.read_csv("kdramaclean.csv")

# %%
clean
# Out:
#       Unnamed: 0                        Title  \
# 0              0                       Goblin
# 1              1    Strong Woman Do Bong Soon
# 2              2       Descendants of the Sun
# 3              3                            W
# 4              4  You Who Came from the Stars
# ...          ...                          ...
# 1185        1185        The Reason I Hate You
# 1186        1186            You I Didn't Know
# 1187        1187          Love Playlist Pilot
# 1188        1188               Life of Namjoo
# 1189        1189           Case Cell Division
#
#                                   Info  Ratings  \
# 0     Korean Drama - 2016, 16 episodes      8.9
# 1     Korean Drama - 2017, 16 episodes      8.7
# 2     Korean Drama - 2016, 16 episodes      8.7
# 3     Korean Drama - 2016, 16 episodes      8.5
# 4     Korean Drama - 2013, 21 episodes      8.6
# ...                                ...      ...
# 1185   Korean Drama - 2020, 3 episodes      6.9
# 1186   Korean Drama - 2020, 3 episodes      7.8
# 1187   Korean Drama - 2017, 2 episodes      7.5
# 1188   Korean Drama - 2020, 6 episodes      7.3
# 1189   Korean Drama - 2021, 3 episodes     10.0
#
#                                     URL
# 0                         /18452-goblin
# 1      /18894-strong-woman-do-bong-soon
# 2         /10904-descendants-of-the-sun
# 3                              /16589-w
# 4     /7398-you-who-came-from-the-stars
# ...                                 ...
# 1185              /683329-weekly-bamboo
# 1186            /683331-weekly-bamboo-2
# 1187        /683585-love-playlist-pilot
# 1188                  /683713-life-boys
# 1189         /688531-case-cell-division
#
# [1190 rows x 5 columns]

# %%
lk = pd.read_csv('kdramaclean.csv')
half = lk['URL'].values
links = ['https://mydramalist.com' + i for i in half]

# %%
list1 = []

for i in range(0,1190):
    list1.insert(i, clean.URL[i])

# %% [markdown]
# Will use the URL that we cleaned previously to scrape another csv here.

# %%
reviews = pd.read_csv("reviews.csv").dropna()
reviews
# Out:
#                           Title  Ratings                    Ranked  \
# 0     Strong Woman Do Bong Soon      8.7                       #84
# 1                     The Heirs      7.5                     #2787
# 2                     Pinocchio      8.4                      #265
# 3                        Goblin      8.9                       #33
# 4                             W      8.5                      #196
# ...                         ...      ...                       ...
# 1183        Love Playlist Pilot      7.5   15+ - Teens 15 or older
# 1184              Love Teenager      6.9             Not Yet Rated
# 1185    My Wonderful Roommate 2      7.0                    #99999
# 1188             Life of Namjoo      7.3                    #34194
# 1189         Case Cell Division     10.0                    #99999
#
#           Popularity        Actor 1                        URL 1  \
# 0                 #2  Park Bo Young   /people/1498-park-bo-young
# 1                 #8     Lee Min Ho       /people/232-lee-min-ho
# 2                 #9   Lee Jong Suk     /people/900-lee-jong-suk
# 3                 #1       Gong Yoo         /people/440-gong-yoo
# 4                 #5    Han Hyo Joo      /people/300-han-hyo-joo
# ...              ...            ...                          ...
# 1183             137  Kim Hyung Suk  /people/15848-kim-hyung-suk
# 1184             236   Nam Dae Jung   /people/57321-nam-dae-jung
# 1185   Not Yet Rated      Son Ye Ji      /people/44333-son-ye-ji
# 1188          #99999   Park Shi Woo   /people/4067-park-so-young
# 1189          #99999   Ham Eun Jung     /people/254-ham-eun-jung
#
#               Actor 2                         URL 2
# 0     Park Hyung Shik  /people/3014-park-hyung-shik
# 1       Park Shin Hye     /people/210-park-shin-hye
# 2       Park Shin Hye     /people/210-park-shin-hye
# 3          Kim Go Eun       /people/2599-kim-go-eun
# 4        Lee Jong Suk      /people/900-lee-jong-suk
# ...               ...                           ...
# 1183      Lee Yoo Jin     /people/19901-lee-yoo-jin
# 1184        Park Road       /people/57313-park-road
# 1185    Choi Joon Han   /people/53553-choi-joon-han
# 1188      Kim Jin Gon     /people/24651-kim-jin-gon
# 1189     Park Geon Il     /people/2686-park-geon-il
#
# [1150 rows x 8 columns]

# %% [markdown]
# Cleaning the URL in this csv as well because we need it to scrape more stuff.

# %%
reviews['URL 1'] = 'https://www.mydramalist.com' + reviews['URL 1'].astype(str)

# %%
reviews['URL 2'] = 'https://www.mydramalist.com' + reviews['URL 2'].astype(str)

# %%
reviews.reset_index(inplace = True)

# %%
reviews_clean = reviews.drop("index", 1)

# %%
reviews_clean
# Out:
#                           Title  Ratings                    Ranked  \
# 0     Strong Woman Do Bong Soon      8.7                       #84
# 1                     The Heirs      7.5                     #2787
# 2                     Pinocchio      8.4                      #265
# 3                        Goblin      8.9                       #33
# 4                             W      8.5                      #196
# ...                         ...      ...                       ...
# 1145        Love Playlist Pilot      7.5   15+ - Teens 15 or older
# 1146              Love Teenager      6.9             Not Yet Rated
# 1147    My Wonderful Roommate 2      7.0                    #99999
# 1148             Life of Namjoo      7.3                    #34194
# 1149         Case Cell Division     10.0                    #99999
#
#           Popularity        Actor 1  \
# 0                 #2  Park Bo Young
# 1                 #8     Lee Min Ho
# 2                 #9   Lee Jong Suk
# 3                 #1       Gong Yoo
# 4                 #5    Han Hyo Joo
# ...              ...            ...
# 1145             137  Kim Hyung Suk
# 1146             236   Nam Dae Jung
# 1147   Not Yet Rated      Son Ye Ji
# 1148          #99999   Park Shi Woo
# 1149          #99999   Ham Eun Jung
#
#                                                   URL 1          Actor 2  \
# 0     https://www.mydramalist.com/people/1498-park-b...  Park Hyung Shik
# 1     https://www.mydramalist.com/people/232-lee-min-ho    Park Shin Hye
# 2     https://www.mydramalist.com/people/900-lee-jon...    Park Shin Hye
# 3       https://www.mydramalist.com/people/440-gong-yoo       Kim Go Eun
# 4     https://www.mydramalist.com/people/300-han-hyo...     Lee Jong Suk
# ...                                                 ...              ...
# 1145  https://www.mydramalist.com/people/15848-kim-h...      Lee Yoo Jin
# 1146  https://www.mydramalist.com/people/57321-nam-d...        Park Road
# 1147  https://www.mydramalist.com/people/44333-son-y...    Choi Joon Han
# 1148  https://www.mydramalist.com/people/4067-park-s...      Kim Jin Gon
# 1149  https://www.mydramalist.com/people/254-ham-eun...     Park Geon Il
#
#                                                   URL 2
# 0     https://www.mydramalist.com/people/3014-park-h...
# 1     https://www.mydramalist.com/people/210-park-sh...
# 2     https://www.mydramalist.com/people/210-park-sh...
# 3     https://www.mydramalist.com/people/2599-kim-go...
# 4     https://www.mydramalist.com/people/900-lee-jon...
# ...                                                 ...
# 1145  https://www.mydramalist.com/people/19901-lee-y...
# 1146  https://www.mydramalist.com/people/57313-park-...
# 1147  https://www.mydramalist.com/people/53553-choi-...
# 1148  https://www.mydramalist.com/people/24651-kim-j...
# 1149  https://www.mydramalist.com/people/2686-park-g...
#
# [1150 rows x 8 columns]

# %% [markdown]
# After Extracting the URL, we can drop the columns. We will ensure that both actors are in 2 different rows, instead of one.

# %%
reviews_clean = reviews_clean.drop(["URL 1", "URL 2"], 1)

# %%
reviews1 = reviews_clean.iloc[:, 0:5]

# %%
reviews2 = reviews_clean.drop('Actor 1', 1)
reviews2['Actor 1'] = reviews2['Actor 2']

# %%
reviews2 = reviews2.drop('Actor 2', 1)

# %%
reviews3 = pd.concat([reviews1, reviews2])

# %%
reviewsfinal = reviews3.sort_values(by = "Actor 1")

reviewsfinal = reviewsfinal.reset_index().drop("index", 1)

# %% [markdown]
# Read the info csv that we scraped that contains the individual info about the actors and actresses.

# %%
info = pd.read_csv("info.csv")

# %%
info = info.sort_values(by = "Name").reset_index().drop("index", 1)

# %%
final = pd.concat([reviewsfinal, info], axis = 1) #concat the info of actors and the info of drama

# %%
final = final.sort_values(by = "Title").reset_index().drop("index", 1)

# %%
#final.to_csv("final.csv")

# %%
final
# Out:
#                      Title  Ratings   Ranked Popularity         Actor 1  \
# 0       100 Days My Prince      8.3     #354       #160    Do Kyung Soo
# 1       100 Days My Prince      8.3     #354       #160     Nam Ji Hyun
# 2       109 Strange Things      6.8    #4530      #2377  Choi  Tae Joon
# 3       109 Strange Things      6.8    #4530      #2377  Jung Chae Yeon
# 4                 18 Again      8.8      #44       #287  Yoon Sang Hyun
# ...                    ...      ...      ...        ...             ...
# 2295             Your Lady      7.3   #35426      #8049           Im Ho
# 2296  Your Neighbor's Wife      7.3   #34929      #7790  Shin Eun Kyung
# 2297  Your Neighbor's Wife      7.3   #34929      #7790    Yeom Jung Ah
# 2298        beautiology101      7.6    #2588      #2432      Han Ji Eun
# 2299        beautiology101      7.6    #2588      #2432   Kim Jae Young
#
#                 Name   Info Info1  \
# 0       Do Kyung Soo     Do   도경수
# 1        Nam Ji Hyun    Nam   남지현
# 2     Choi  Tae Joon   Choi   최태준
# 3     Jung Chae Yeon   Jung   정채연
# 4     Yoon Sang Hyun   Yoon   윤상현
# ...              ...    ...   ...
# 2295           Im Ho     Im    임호
# 2296  Shin Eun Kyung   Shin   신은경
# 2297    Yeom Jung Ah   Yeom   염정아
# 2298      Han Ji Eun    Han   한지은
# 2299   Kim Jae Young    Kim   김재영
#
#                                                   Info2          Info3  \
# 0      도경수;Kyungsoo;Do Kyeong Su;Do Kyeong Soo;Do Ky...   South Korean
# 1               Nam Ji Hyeon;Nam Ji Hyun;Ji Hyun;Jihyun   South Korean
# 2                                  Choi Tae Jun;Tae Jun   South Korean
# 3                Jeong Chae Yeon;Chaeyeon;Jung Chae Yun   South Korean
# 4                                       Yun Sang Hyeon;   South Korean
# ...                                                 ...            ...
# 2295                                             Lim Ho   South Korean
# 2296    Shin Eun Gyeong; Shin Eun Gyung; Sin Eun Kyung;   South Korean
# 2297                          Yeom Jeong Ah;Yum Jung Ah   South Korean
# 2298                                  Han Ji Eun;Ji Eun   South Korean
# 2299                                      Kim Jae Yeong   South Korean
#
#         Info4                Info5 Info6  \
# 0        Male     January 12, 1993    28
# 1      Female   September 17, 1995    25
# 2        Male        July  7, 1991    29
# 3      Female    December  1, 1997    23
# 4        Male   September 21, 1973    47
# ...       ...                  ...   ...
# 2295     Male     January 27, 1970    51
# 2296   Female    February 15, 1973    48
# 2297   Female        July 28, 1972    48
# 2298   Female        June  3, 1990    30
# 2299     Male   September 30, 1988    32
#
#                                        Image
# 0       https://i.mydramalist.com/43e46c.jpg
# 1       https://i.mydramalist.com/wlJ8Yc.jpg
# 2     https://i.mydramalist.com/jbRmJ_5c.jpg
# 3       https://i.mydramalist.com/e3AQec.jpg
# 4     https://i.mydramalist.com/dxN6W_5c.jpg
# ...                                      ...
# 2295    https://i.mydramalist.com/2xv6dc.jpg
# 2296    https://i.mydramalist.com/xg1Yyc.jpg
# 2297  https://i.mydramalist.com/Zdv6j_5c.jpg
# 2298  https://i.mydramalist.com/67VY2_5c.jpg
# 2299    https://i.mydramalist.com/pO6rrc.jpg
#
# [2300 rows x 14 columns]

# %% [markdown]
# Since the gender is not all under one column, we need to further clean it.

# %%
male = final.loc[final['Info4'] == ' Male']

# %%
female = final.loc[final['Info4'] == " Female"]

# %%
remaining = final.loc[final['Info4'] != " Female"]

# %%
weird = remaining.loc[remaining['Info4'] != " Male"]

# %%
weird["Info4"] = weird["Info3"]
# Out:
# <ipython-input-348-b628bd22b624>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weird["Info4"] = weird["Info3"]

# %%
weird
# Out:
#                               Title  Ratings   Ranked      Popularity  \
# 5                          18 Again      8.8      #44            #287
# 14    380,000 km Between You and Me      7.9   #28054          #99999
# 16                 4 Kinds of House      7.5    #2775           #3563
# 20                          49 Days      8.3     #438            #123
# 23                   7 First Kisses      6.9    #4427            #169
# ...                             ...      ...      ...             ...
# 2274           You Don't Know Women      7.3   #35432          #99999
# 2275           You Don't Know Women      7.3   #35432          #99999
# 2276              You Make Me Dance      8.1     #840           #1173
# 2281               You Will Love Me      6.8    #6077   Not Yet Rated
# 2285               You're Only Mine      7.2   #36653           #9670
#
#              Actor 1            Name   Info Info1          Info2    Info3  \
# 5        Kim Ha Neul     Kim Ha Neul    Kim   김하늘   South Korean   Female
# 14     Choi Sang Bae   Choi Sang Bae   Choi   최상배   South Korean     Male
# 16       Lee Jae Jin     Lee Jae Jin    Lee   이재진   South Korean     Male
# 20        Lee Yo Won      Lee Yo Won    Lee   이요원   South Korean   Female
# 23       Lee Cho Hee     Lee Cho Hee    Lee   이초희   South Korean   Female
# ...              ...             ...    ...   ...            ...      ...
# 2274       Kim Ji Ho       Kim Ji Ho    Kim   김지호   South Korean   Female
# 2275    Chae Min Seo    Chae Min Seo     Jo   채민서   South Korean   Female
# 2276  Won Hyung Hoon  Won Hyung Hoon    Won   원형훈   South Korean     Male
# 2281      Lee Tae Im      Lee Tae Im    Lee   이태임   South Korean   Female
# 2285      Han Da Min      Han Da Min   Ham    한다민   South Korean   Female
#
#         Info4 Info5 Info6                                   Image
# 5      Female    43   NaN  https://i.mydramalist.com/Qy7kW_5c.jpg
# 14       Male   NaN   NaN    https://i.mydramalist.com/vO0dZc.jpg
# 16       Male    29   NaN    https://i.mydramalist.com/vyELDc.jpg
# 20     Female    40   NaN  https://i.mydramalist.com/R42VV_5c.jpg
# 23     Female    31   NaN  https://i.mydramalist.com/jYN6d_5c.jpg
# ...       ...   ...   ...                                     ...
# 2274   Female    46   NaN    https://i.mydramalist.com/JBL7pc.jpg
# 2275   Female    39   NaN    https://i.mydramalist.com/M5Xmyc.jpg
# 2276     Male    27   NaN  https://i.mydramalist.com/vEkrX_5c.jpg
# 2281   Female    34   NaN    https://i.mydramalist.com/elRD8c.jpg
# 2285   Female    37   NaN    https://i.mydramalist.com/O840Lc.jpg
#
# [265 rows x 14 columns]

# %%
finalfinal = pd.concat([female, male, weird], axis = 0).drop(["Actor 1", "Info", "Info1", "Info2", "Info3", "Info5", "Info6"], axis = 1)

# %%
finalfinal = finalfinal.sort_values("Title")
finalfinal
# Out:
#                      Title  Ratings   Ranked Popularity            Name  \
# 1       100 Days My Prince      8.3     #354       #160     Nam Ji Hyun
# 0       100 Days My Prince      8.3     #354       #160    Do Kyung Soo
# 2       109 Strange Things      6.8    #4530      #2377  Choi  Tae Joon
# 3       109 Strange Things      6.8    #4530      #2377  Jung Chae Yeon
# 5                 18 Again      8.8      #44       #287     Kim Ha Neul
# ...                    ...      ...      ...        ...             ...
# 2295             Your Lady      7.3   #35426      #8049           Im Ho
# 2297  Your Neighbor's Wife      7.3   #34929      #7790    Yeom Jung Ah
# 2296  Your Neighbor's Wife      7.3   #34929      #7790  Shin Eun Kyung
# 2299        beautiology101      7.6    #2588      #2432   Kim Jae Young
# 2298        beautiology101      7.6    #2588      #2432      Han Ji Eun
#
#         Info4                                   Image
# 1      Female    https://i.mydramalist.com/wlJ8Yc.jpg
# 0        Male    https://i.mydramalist.com/43e46c.jpg
# 2        Male  https://i.mydramalist.com/jbRmJ_5c.jpg
# 3      Female    https://i.mydramalist.com/e3AQec.jpg
# 5      Female  https://i.mydramalist.com/Qy7kW_5c.jpg
# ...       ...                                     ...
# 2295     Male    https://i.mydramalist.com/2xv6dc.jpg
# 2297   Female  https://i.mydramalist.com/Zdv6j_5c.jpg
# 2296   Female    https://i.mydramalist.com/xg1Yyc.jpg
# 2299     Male    https://i.mydramalist.com/pO6rrc.jpg
# 2298   Female  https://i.mydramalist.com/67VY2_5c.jpg
#
# [2300 rows x 7 columns]

# %%
finalfinal = finalfinal.reset_index().drop(['index'], axis = 1)

# %%
finalfinal = finalfinal.rename(columns={"Info4": "Gender"})

# %%
finalfinal
# Out:
#                      Title  Ratings   Ranked Popularity            Name  \
# 0       100 Days My Prince      8.3     #354       #160     Nam Ji Hyun
# 1       100 Days My Prince      8.3     #354       #160    Do Kyung Soo
# 2       109 Strange Things      6.8    #4530      #2377  Choi  Tae Joon
# 3       109 Strange Things      6.8    #4530      #2377  Jung Chae Yeon
# 4                 18 Again      8.8      #44       #287     Kim Ha Neul
# ...                    ...      ...      ...        ...             ...
# 2295             Your Lady      7.3   #35426      #8049           Im Ho
# 2296  Your Neighbor's Wife      7.3   #34929      #7790    Yeom Jung Ah
# 2297  Your Neighbor's Wife      7.3   #34929      #7790  Shin Eun Kyung
# 2298        beautiology101      7.6    #2588      #2432   Kim Jae Young
# 2299        beautiology101      7.6    #2588      #2432      Han Ji Eun
#
#        Gender                                   Image
# 0      Female    https://i.mydramalist.com/wlJ8Yc.jpg
# 1        Male    https://i.mydramalist.com/43e46c.jpg
# 2        Male  https://i.mydramalist.com/jbRmJ_5c.jpg
# 3      Female    https://i.mydramalist.com/e3AQec.jpg
# 4      Female  https://i.mydramalist.com/Qy7kW_5c.jpg
# ...       ...                                     ...
# 2295     Male    https://i.mydramalist.com/2xv6dc.jpg
# 2296   Female  https://i.mydramalist.com/Zdv6j_5c.jpg
# 2297   Female    https://i.mydramalist.com/xg1Yyc.jpg
# 2298     Male    https://i.mydramalist.com/pO6rrc.jpg
# 2299   Female  https://i.mydramalist.com/67VY2_5c.jpg
#
# [2300 rows x 7 columns]

# %% [markdown]
# Extracting the titles of dramas that have more than 2 pages of reviews.

# %%
title = ['Goblin', 'Strong Woman Do Bong Soon',
 'Descendants of the Sun',
 'W',
 'You Who Came from the Stars',
 'Weightlifting Fairy Kim Bok Joo',
 'The Heirs',
 'Pinocchio',
 'Healer',
 "What's Wrong with Secretary Kim",
 'While You Were Sleeping',
 'Moon Lovers: Scarlet Heart Ryeo',
 'Secret Garden',
 'Kill Me, Heal Me',
 'The Legend of the Blue Sea',
 'Crash Landing on You',
 'City Hunter',
 'I Hear Your Voice',
 'She Was Pretty',
 "I'm Not a Robot",
 'Cheese in the Trap',
 'Fight For My Way',
 'Hotel del Luna',
 "The Master's Sun",
 "It's Okay to Not Be Okay",
 'Suspicious Partner',
 "It's Okay, That's Love",
 'Oh My Ghostess',
 'Playful Kiss',
 'Dream High',
 'Cinderella and the Four Knights',
 'Oh My Venus',
 'Reply 1997',
 'My ID Is Gangnam Beauty',
 'Personal Taste',
 'Because This is My First Life',
 'Itaewon Class',
 'The K2',
 'Hwarang',
 'Who Are You: School 2015',
 'Heartstrings',
 'To The Beautiful You',
 'Her Private Life',
 'My Girlfriend Is a Gumiho',
 'Love in the Moonlight',
 'Reply 1988',
 'Doctor Stranger',
 'A Korean Odyssey',
 'Doctors',
 'Romance is a Bonus Book',
 'Flower Boy Next Door',
 'My Secret Romance',
 'Uncontrollably Fond',
 'Rooftop Prince',
 'The Bride of Habaek',
 'Extraordinary You',
 'The King: Eternal Monarch',
 'Fated to Love You',
 'Bring It On, Ghost',
 'Touch Your Heart',
 'Just Between Lovers',
 'Love Alarm',
 'Are You Human Too?',
 'Moon Embracing the Sun',
 'Age of Youth',
 'Sassy Go Go',
 'He Is Psychometric',
 "Queen In Hyun's Man",
 'Emergency Couple',
 'Memories of the Alhambra',
 'Introverted Boss',
 'The Innocent Man',
 'Marriage, Not Dating',
 'Faith',
 'Shopping King Louie',
 'Thirty But Seventeen',
 'The Beauty Inside',
 'True Beauty',
 "Angel's Last Mission: Love",
 'Another Miss Oh',
 'Prison Playbook',
 'Abyss',
 'Hospital Playlist',
 'Shut Up: Flower Boy Band',
 'Sungkyunkwan Scandal',
 'Blood',
 'Chicago Typewriter',
 'Flower Boy Ramen Shop',
 'Flower of Evil',
 'The Great Seducer',
 'Gu Family Book',
 'School 2017',
 'Eulachacha Waikiki',
 'Something in the Rain',
 'King2Hearts',
 'Mr. Sunshine',
 'Start-Up',
 'Lie to Me',
 'The Girl Who Sees Scents',
 'EXO Next Door',
 '49 Days',
 "You're All Surrounded",
 'Dr. Romantic',
 'Love Rain',
 'Good Doctor',
 'Black',
 'Tale of the Nine-Tailed',
 'Hi! School - Love On',
 'Dream High 2',
 'Reply 1994',
 'The Smile Has Left Your Eyes',
 'Jealousy Incarnate',
 'Moorim School',
 'My First First Love',
 'When the Camellia Blooms',
 'Protect the Boss',
 'Search: WWW',
 'The Tale of Nokdu',
 'Big',
 'Come and Hug Me',
 'Empress Ki',
 'Something About 1 Percent',
 'That Winter, The Wind Blows',
 "A Gentleman's Dignity",
 'Falling for Innocence',
 'Orange Marmalade',
 'Melting Me Softly',
 'The Producers',
 'Secret',
 '100 Days My Prince',
 'Tomorrow With You',
 'Hit the Top',
 'Clean With Passion For Now',
 'The Liar and His Lover',
 'Lawless Lawyer',
 '7 First Kisses',
 'Mary Stayed Out All Night',
 'The Secret Life of My Secretary',
 'Hyde, Jekyll, Me',
 'Radio Romance',
 'The Scholar Who Walks the Night',
 'Missing You',
 'The Greatest Love',
 'Noble, My Love',
 'My Princess',
 'The Bridal Mask',
 'Birth of a Beauty',
 'My Holo Love',
 'Beautiful Gong Shim',
 'Cunning Single Lady',
 'Arang and the Magistrate',
 'When the Weather Is Fine',
 'Go Back Couple',
 'Record of Youth',
 'High Society',
 'Age of Youth 2',
 'Where Your Eyes Linger',
 'My Strange Hero',
 'Remember: War of the Son',
 'Lucky Romance',
 'Bride of the Century',
 'Run On',
 'Encounter',
 'Monstar',
 "Witch's Romance",
 'Please Come Back, Mister',
 'Rookie Historian Goo Hae Ryung',
 'The World of the Married',
 'Dr. Romantic 2',
 'Miss Hammurabi',
 'High School King of Savvy',
 'One Spring Night',
 'Mask',
 'Mr. Queen',
 'Surplus Princess',
 'Man to Man',
 'Madame Antoine',
 'Cruel City',
 'Terius Behind Me',
 'A Beautiful Mind',
 'Backstreet Rookie',
 'Yong Pal',
 'Where Stars Land',
 'The Lover',
 'Long Time No See',
 'My Father is Strange',
 'My Lovely Girl',
 'About Time',
 'Queen of the Ring',
 '18 Again',
 'Hi Bye, Mama!',
 'Bel Ami',
'Arthdal Chronicles Part 1: The Children of Prophecy',
 "The Princess's Man",
 "Go Ho's Starry Night",
 'My First First Love 2',
 'Scent of a Woman',
 'Doctor John',
 'Temperature of Love',
 'Moment at Eighteen',
 'The Hymn of Death',
 'Angel Eyes',
 'Who Are You',
 'Love with Flaws',
 'Prosecutor Princess',
 'High-end Crush',
 'Six Flying Dragons',
 'Missing 9',
 'Do Do Sol Sol La La Sol',
 'King of Baking, Kim Tak Goo',
 'Meow, the Secret Boy',
 'Devilish Joy',
 'Wok of Love',
 'Panda and Hedgehog',
 'K-POP - The Ultimate Audition',
 'The Emperor: Owner of the Mask',
 'Hotel King',
 'D-Day',
 'Twenty Again',
 "Ho Goo's Love",
 'Mirror of the Witch',
 'Dream Knight',
 'Marriage Contract',
 'Strongest Deliveryman',
 'Rich Man',
 'One More Happy Ending',
 'The Time We Were Not in Love',
 'Oh! My Lady',
 'Find Me in Your Memory',
 'A Piece of Your Mind',
 'Revolutionary Love',
 'Prime Minister and I',
 'Warm and Cozy',
 'Can You Hear My Heart',
 "Let's Eat",
 'Be Melodramatic',
 'Color Rush',
 'Live Up to Your Name',
 'The Last Empress',
 'Cheongdamdong Alice',
 'My Only Love Song',
 'I Need Romance 3',
 'Mr. Heart',
 'Full House Take 2',
 'Me too, Flower!',
 'Ma Boy',
 'Lovestruck in the City',
 'Nine: Nine Times Time Travel',
 'My Absolute Boyfriend',
 'The Light in Your Eyes',
 'Queen for Seven Days',
 'Pasta',
 "Cinderella's Sister",
 'Marry Him If You Dare',
 'Live',
 'Chocolate',
 'The Boy Next Door',
 'A Poem a Day',
 "Witch's Love",
 'Familiar Wife',
 'The Crowned Clown',
 'My Country: The New Age',
 "Naeil's Cantabile",
 'Jugglers',
 'Eulachacha Waikiki 2',
 'Heart to Heart',
 'Drinking Solo',
 'Click Your Heart',
 'Rebel: Thief Who Stole the People',
 'You Are The Best!',
 'Dinner Mate',
 'Trot Lovers',
 'A-Teen',
 'My Secret Hotel',
 'I  Do, I Do',
 "Because It's The First Time",
 'Discovery of Romance',
 'Star of the Universe',
 'Modern Farmer',
 'Sweet Revenge',
 'Do You Like Brahms?',
 'One More Time',
 'Warrior Baek Dong Soo',
 'Wild Romance',
 'Catch the Ghost',
 'The Package',
 'Wednesday 3:30 PM',
 'Secret Love Affair',
 'Dating Agency: Cyrano',
 'The Third Charm',
 'Twenty Years Old',
 'Was It Love?',
 'The Undateables',
 'Arthdal Chronicles Part 3: The Prelude To All Legends',
 'Somehow 18',
 'More Than Friends',
 'Forest',
 'Pride and Prejudice',
 'Myung Wol the Spy',
 'The King of Dramas',
 'My Love Eun Dong',
 'Private Lives',
 'Plus Nine Boys',
 'Perfume',
 'Nail Shop Paris',
 'The King in Love',
 '7th Grade Civil Servant',
 'Dong Yi',
 'Wish You: Your Melody From My Heart',
 'To My Star',
 'What Happens to My Family?',
 'Operation Proposal',
 'Hyena',
 'Black Knight: The Man Who Guards Me',
 'I Need Romance',
 'A Love So Beautiful',
 'Padam Padam',
 'Triangle',
 'I Picked Up a Star on the Road',
 "When A Man's in Love",
 'Baby-faced Beauty',
 'Dramaworld',
 'Radiant Office',
 'Time Slip Dr. Jin',
 'Flower Crew: Joseon Marriage Agency',
 'Gunman In Joseon',
 'Your Honor',
 'Money Flower',
 "Let's Eat 2",
 'Stars Falling From the Sky',
 'I Need Romance 2',
 'Born Again',
 'When My Love Blooms',
 'Bad Guy',
 'My Unfortunate Boyfriend',
 'Live On',
 'Into the Ring',
 'Choco Bank',
 'Oh My Baby',
 'Inspiring Generation',
 'Mama Fairy and the Woodcutter',
 'Misty',
 'The Ghost Detective',
 'My Fellow Citizens!',
 'Can We Get Married?',
 'Chuno',
 'XX',
 'Your House Helper',
 "What's Up?",
 'My Beautiful Bride',
 'Jang Ok Jung',
 'My Golden Life',
 'When Time Stopped',
 'Ugly Alert',
 'Five Enough',
 'Coffee House',
 "Girls' Generation 1979",
 'Best Wedding',
 'On The Way To The Airport',
 'Feel Good To Die',
 'Lie After Lie',
 'Kiss Goblin',
 'Best Mistake',
 'Possessed',
 'Once Again',
 'Soul Mechanic',
 'Love Revolution',
 'Twenty-Twenty',
 'Haechi',
 'When I Was the Most Beautiful',
 "Please Don't Date Him",
 'Cheat On Me, If You Can',
 'Queen of Ambition',
 'Wild Chives and Soy Bean Soup: 12 Years Reunion',
 'The Incarnation of Money',
 'All About My Romance',
 'Love Affairs in the Afternoon',
 'Valid Love',
 'Queen: Love And War',
 'Sweet Munchies',
 'New Tales of Gisaeng',
 'Temptation',
'My Heart Twinkle Twinkle']

# %%
len(title)
# Out:
# 383

# %%
finalfinal = finalfinal[finalfinal.Title.isin(title)].reset_index().drop("index", axis = 1)

# %% [markdown]
# Found out that there are dramas that have the same name like "Once Again", "While You Were Sleeping" and "Mask". So we have to remove one because the other duplicate does not have at least 2 reviews.

# %%
finalfinal[finalfinal.Title == "Once Again"]
# Out:
#           Title  Ratings   Ranked Popularity         Name   Gender  \
# 458  Once Again      7.4   #33773     #99999     Park Jun     Male
# 459  Once Again      8.5     #221      #1107  Chun Ho Jin     Male
# 460  Once Again      8.5     #221      #1107  Cha Hwa Yun   Female
# 461  Once Again      7.4   #33773     #99999   Han Ji Hye   Female
#
#                                       Image
# 458  https://i.mydramalist.com/RgngR_5c.jpg
# 459    https://i.mydramalist.com/pkNw8c.jpg
# 460    https://i.mydramalist.com/43l46c.jpg
# 461  https://i.mydramalist.com/Qlrv4_5c.jpg

# %%
finalfinal[finalfinal.Title == "While You Were Sleeping"]
# Out:
#                        Title  Ratings   Ranked Popularity            Name  \
# 738  While You Were Sleeping      7.7   #30066      #4347   Lee Young Eun
# 739  While You Were Sleeping      8.7      #59        #12        Bae Suzy
# 740  While You Were Sleeping      8.7      #59        #12    Lee Jong Suk
# 741  While You Were Sleeping      7.7   #30066      #4347  Choi Won Young
#
#       Gender                                   Image
# 738   Female    https://i.mydramalist.com/qbB4dc.jpg
# 739   Female    https://i.mydramalist.com/pOqyQc.jpg
# 740     Male    https://i.mydramalist.com/XbzDnc.jpg
# 741     Male  https://i.mydramalist.com/QBrn6_5c.jpg

# %%
finalfinal[finalfinal.Title == "Mask"]
# Out:
#     Title  Ratings   Ranked Popularity            Name   Gender  \
# 352  Mask      8.1     #748       #251     Park Soo Ae   Female
# 353  Mask      6.8   #40256      #5377  Park Jeong Hwa   Female
# 354  Mask      6.8   #40256      #5377     Kim Jin Woo     Male
# 355  Mask      8.1     #748       #251     Joo Ji Hoon     Male
#
#                                       Image
# 352  https://i.mydramalist.com/vg4ye_5c.jpg
# 353    https://i.mydramalist.com/rbzmEc.jpg
# 354  https://i.mydramalist.com/w7p4g_5c.jpg
# 355    https://i.mydramalist.com/pOrorc.jpg

# %%
finalfinal = finalfinal.drop([353,354,458,461,738,741])

# %%
finalfinal[finalfinal.Title == "Once Again"]
# Out:
#           Title  Ratings Ranked Popularity         Name   Gender  \
# 459  Once Again      8.5   #221      #1107  Chun Ho Jin     Male
# 460  Once Again      8.5   #221      #1107  Cha Hwa Yun   Female
#
#                                     Image
# 459  https://i.mydramalist.com/pkNw8c.jpg
# 460  https://i.mydramalist.com/43l46c.jpg

# %%
finalfinal[finalfinal.Title == "Mask"]
# Out:
#     Title  Ratings Ranked Popularity         Name   Gender  \
# 352  Mask      8.1   #748       #251  Park Soo Ae   Female
# 355  Mask      8.1   #748       #251  Joo Ji Hoon     Male
#
#                                       Image
# 352  https://i.mydramalist.com/vg4ye_5c.jpg
# 355    https://i.mydramalist.com/pOrorc.jpg

# %%
finalfinal[finalfinal.Title == "While You Were Sleeping"]
# Out:
#                        Title  Ratings Ranked Popularity          Name  \
# 739  While You Were Sleeping      8.7    #59        #12      Bae Suzy
# 740  While You Were Sleeping      8.7    #59        #12  Lee Jong Suk
#
#       Gender                                 Image
# 739   Female  https://i.mydramalist.com/pOqyQc.jpg
# 740     Male  https://i.mydramalist.com/XbzDnc.jpg

# %%
finalfinal = finalfinal.reset_index().drop("index", axis = 1)

# %% [markdown]
# We realised that some of the two actors taken for each dramas are both male-male or female-female. We will take those out too because we are more concerned about the chemistry of female-male lead characters.

# %%
finalfinal
# Out:
#                      Title  Ratings  Ranked Popularity            Name  \
# 0       100 Days My Prince      8.3    #354       #160     Nam Ji Hyun
# 1       100 Days My Prince      8.3    #354       #160    Do Kyung Soo
# 2                 18 Again      8.8     #44       #287     Kim Ha Neul
# 3                 18 Again      8.8     #44       #287  Yoon Sang Hyun
# 4                  49 Days      8.3    #438       #123      Nam Gyu Ri
# ..                     ...      ...     ...        ...             ...
# 761  You're All Surrounded      8.2    #577       #124        Go Ah Ra
# 762             Your Honor      8.0    #921       #749   Yoon Shi Yoon
# 763             Your Honor      8.0    #921       #749   Lee Yoo Young
# 764      Your House Helper      7.9   #1418       #879     Ha Seok Jin
# 765      Your House Helper      7.9   #1418       #879            Bona
#
#       Gender                                   Image
# 0     Female    https://i.mydramalist.com/wlJ8Yc.jpg
# 1       Male    https://i.mydramalist.com/43e46c.jpg
# 2     Female  https://i.mydramalist.com/Qy7kW_5c.jpg
# 3       Male  https://i.mydramalist.com/dxN6W_5c.jpg
# 4     Female  https://i.mydramalist.com/BZbnl_5c.jpg
# ..       ...                                     ...
# 761   Female  https://i.mydramalist.com/ejKbK_5c.jpg
# 762     Male    https://i.mydramalist.com/43zLwc.jpg
# 763   Female  https://i.mydramalist.com/x5Wl0_5c.jpg
# 764     Male  https://i.mydramalist.com/1Aoeb_5c.jpg
# 765   Female  https://i.mydramalist.com/X1q4d_5c.jpg
#
# [766 rows x 7 columns]

# %%
f = finalfinal[finalfinal.Gender == " Female"]
f = f.drop_duplicates(subset = ['Title'], keep = False)
m = finalfinal[finalfinal.Gender == " Male"]
m = m.drop_duplicates(subset = ['Title'], keep = False)
finalfinal = pd.concat([m,f], axis = 0).sort_values("Title").reset_index().drop("index", axis = 1)

# %% [markdown]
# We decided we wanted to scrape the characters' names, so we had to scrape again.

# %%
arr = final.Title.values
list1 = arr.tolist()

# %%
drama = pd.read_csv("kdramaclean.csv")

# %%
drama
# Out:
#       Unnamed: 0                        Title  \
# 0              0                       Goblin
# 1              1    Strong Woman Do Bong Soon
# 2              2       Descendants of the Sun
# 3              3                            W
# 4              4  You Who Came from the Stars
# ...          ...                          ...
# 1185        1185        The Reason I Hate You
# 1186        1186            You I Didn't Know
# 1187        1187          Love Playlist Pilot
# 1188        1188               Life of Namjoo
# 1189        1189           Case Cell Division
#
#                                   Info  Ratings  \
# 0     Korean Drama - 2016, 16 episodes      8.9
# 1     Korean Drama - 2017, 16 episodes      8.7
# 2     Korean Drama - 2016, 16 episodes      8.7
# 3     Korean Drama - 2016, 16 episodes      8.5
# 4     Korean Drama - 2013, 21 episodes      8.6
# ...                                ...      ...
# 1185   Korean Drama - 2020, 3 episodes      6.9
# 1186   Korean Drama - 2020, 3 episodes      7.8
# 1187   Korean Drama - 2017, 2 episodes      7.5
# 1188   Korean Drama - 2020, 6 episodes      7.3
# 1189   Korean Drama - 2021, 3 episodes     10.0
#
#                                     URL
# 0                         /18452-goblin
# 1      /18894-strong-woman-do-bong-soon
# 2         /10904-descendants-of-the-sun
# 3                              /16589-w
# 4     /7398-you-who-came-from-the-stars
# ...                                 ...
# 1185              /683329-weekly-bamboo
# 1186            /683331-weekly-bamboo-2
# 1187        /683585-love-playlist-pilot
# 1188                  /683713-life-boys
# 1189         /688531-case-cell-division
#
# [1190 rows x 5 columns]

# %%
drama = drama[drama.Title.isin(list1)]

# %%
drama = drama.drop([820,767,1182])

# %%
drama = drama.reset_index().drop(["Unnamed: 0", "index"], axis = 1)

# %%
drama
# Out:
#                             Title                              Info  Ratings  \
# 0                          Goblin  Korean Drama - 2016, 16 episodes      8.9
# 1       Strong Woman Do Bong Soon  Korean Drama - 2017, 16 episodes      8.7
# 2          Descendants of the Sun  Korean Drama - 2016, 16 episodes      8.7
# 3                               W  Korean Drama - 2016, 16 episodes      8.5
# 4     You Who Came from the Stars  Korean Drama - 2013, 21 episodes      8.6
# ...                           ...                               ...      ...
# 1143                Love Teenager   Korean Drama - 2020, 8 episodes      6.9
# 1144      My Wonderful Roommate 2  Korean Drama - 2020, 10 episodes      7.0
# 1145          Love Playlist Pilot   Korean Drama - 2017, 2 episodes      7.5
# 1146               Life of Namjoo   Korean Drama - 2020, 6 episodes      7.3
# 1147           Case Cell Division   Korean Drama - 2021, 3 episodes     10.0
#
#                                     URL
# 0                         /18452-goblin
# 1      /18894-strong-woman-do-bong-soon
# 2         /10904-descendants-of-the-sun
# 3                              /16589-w
# 4     /7398-you-who-came-from-the-stars
# ...                                 ...
# 1143              /681637-love-teenager
# 1144    /683281-my-wonderful-roommate-2
# 1145        /683585-love-playlist-pilot
# 1146                  /683713-life-boys
# 1147         /688531-case-cell-division
#
# [1148 rows x 4 columns]

# %%
#drama.to_csv("drama.csv")

# %% [markdown]
# Cleaning the URL once again.

# %%
list1 = []

for i in range(0,344):
    list1.insert(i, drama.URL[i])

# %%
half = drama['URL'].values
links = ['https://www.mydramalist.com' + i for i in half]

# %%
reviews = pd.read_csv("reviews 2.csv")

# %%
reviews
# Out:
#                                Title     Character1     Character2  \
# 0                                  W    Oh Yeon Joo      Kang Chul
# 1    What's Wrong with Secretary Kim      Kim Mi So            NaN
# 2        You Who Came from the Stars    Do Min Joon  Cheon Song Yi
# 3                             Goblin            NaN     Ji Eun Tak
# 4    Weightlifting Fairy Kim Bok Joo            NaN            NaN
# ..                               ...            ...            ...
# 339         My Heart Twinkle Twinkle            NaN            NaN
# 340                       Temptation            NaN            NaN
# 341                   Sweet Munchies  Park Jin Sung            NaN
# 342                       Valid Love            NaN            NaN
# 343              Queen: Love And War            NaN      Lee Gyung
#
#                     Character3       Character4
# 0                          NaN              NaN
# 1                          NaN   Lee Young Joon
# 2                          NaN              NaN
# 3                     Kim Shin              NaN
# 4                  Kim Bok Joo  Jung Joon Hyung
# ..                         ...              ...
# 339               Lee Soon Jin   Cheon Woon Tak
# 340               Yoo Se Young    Cha Seok Hoon
# 341                        NaN       Kim Ah Jin
# 342               Jang Hee Tae        Kim Il Ri
# 343  Gang Eun Bo | Gang Eun Gi              NaN
#
# [344 rows x 5 columns]

# %% [markdown]
# Since the character names are all in different columns, we need to clean it.

# %%
a1 = reviews[(reviews.Character1.isna() == True) & (reviews.Character2.isna() == True)]

# %%
a1.Character1 = a1.Character3
a1.Character2 = a1.Character4
# Out:
# /Users/valencialie/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
b1 = reviews[(reviews.Character1.isna() == True) & (reviews.Character2.isna() == False)]

# %%
b1.Character1 = b1.Character3
# Out:
# /Users/valencialie/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
c1 = reviews[(reviews.Character1.isna() == False) & (reviews.Character2.isna() == True)]

# %%
c1.Character2 = c1.Character4
# Out:
# /Users/valencialie/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
d1 = reviews[(reviews.Character1.isna() == False) & (reviews.Character2.isna() == False)]

# %%
len(a1) +len(b1) + len(c1) + len(d1)
# Out:
# 344

# %%
fin = pd.concat([a1, b1,c1,d1]).drop(["Character3", "Character4"], axis = 1).sort_values("Title")

# %%
fin
# Out:
#                            Title                           Character1  \
# 119           100 Days My Prince  Crown Prince Lee Yool / Na Won Deuk
# 168                     18 Again                         Jung Da Jung
# 274      7th Grade Civil Servant            Han Gil Ro / Han Pil Hoon
# 166             A Beautiful Mind                         Lee Young Oh
# 113        A Gentleman's Dignity                           Kim Do Jin
# ..                           ...                                  ...
# 241            You Are The Best!                        Lee Soon Shin
# 2    You Who Came from the Stars                          Do Min Joon
# 96         You're All Surrounded             Eun Dae Gu / Kim Ji Yong
# 293                   Your Honor             Han Kang Ho / Han Soo Ho
# 314            Your House Helper                          Kim Ji Woon
#
#                         Character2
# 119        Hong Shim / Yoon Yi Seo
# 168  Hong Dae Young [37 years old]
# 274     Kim Seo Won / Kim Kyung Ja
# 166                   Gye Jin Sung
# 113                     Seo Yi Soo
# ..                             ...
# 241                   Shin Joon Ho
# 2                    Cheon Song Yi
# 96                      Eo Soo Sun
# 293                    Song So Eun
# 314                    Im Da Young
#
# [344 rows x 3 columns]

# %%
fin1 = fin.drop("Character1", 1)
fin2 = fin.drop("Character2", 1).sort_values("Title")

fin1 = fin1.rename(columns={"Character2": "Character1"})

# %%
fin1 = fin1.sort_values("Title")

# %%
finfin = pd.concat([fin2,fin1], 0)

# %%
finfin = finfin.sort_values("Title")

# %%
finfin = finfin.drop("Title", 1)

# %%
finfin = finfin.reset_index().drop("index", 1)

# %%
finfin
# Out:
#                               Character1
# 0    Crown Prince Lee Yool / Na Won Deuk
# 1                Hong Shim / Yoon Yi Seo
# 2          Hong Dae Young [37 years old]
# 3                           Jung Da Jung
# 4              Han Gil Ro / Han Pil Hoon
# ..                                   ...
# 683             Eun Dae Gu / Kim Ji Yong
# 684                          Song So Eun
# 685             Han Kang Ho / Han Soo Ho
# 686                          Kim Ji Woon
# 687                          Im Da Young
#
# [688 rows x 1 columns]

# %%
finalfinal
# Out:
#                        Title  Ratings  Ranked Popularity            Name  \
# 0         100 Days My Prince      8.3    #354       #160    Do Kyung Soo
# 1         100 Days My Prince      8.3    #354       #160     Nam Ji Hyun
# 2                   18 Again      8.8     #44       #287     Kim Ha Neul
# 3                   18 Again      8.8     #44       #287  Yoon Sang Hyun
# 4    7th Grade Civil Servant      6.9   #4405       #632         Joo Won
# ..                       ...      ...     ...        ...             ...
# 683    You're All Surrounded      8.2    #577       #124    Lee Seung Gi
# 684               Your Honor      8.0    #921       #749   Lee Yoo Young
# 685               Your Honor      8.0    #921       #749   Yoon Shi Yoon
# 686        Your House Helper      7.9   #1418       #879     Ha Seok Jin
# 687        Your House Helper      7.9   #1418       #879            Bona
#
#       Gender                                   Image
# 0       Male    https://i.mydramalist.com/43e46c.jpg
# 1     Female    https://i.mydramalist.com/wlJ8Yc.jpg
# 2     Female  https://i.mydramalist.com/Qy7kW_5c.jpg
# 3       Male  https://i.mydramalist.com/dxN6W_5c.jpg
# 4       Male  https://i.mydramalist.com/wrJg1_5c.jpg
# ..       ...                                     ...
# 683     Male    https://i.mydramalist.com/B3RRqc.jpg
# 684   Female  https://i.mydramalist.com/x5Wl0_5c.jpg
# 685     Male    https://i.mydramalist.com/43zLwc.jpg
# 686     Male  https://i.mydramalist.com/1Aoeb_5c.jpg
# 687   Female  https://i.mydramalist.com/X1q4d_5c.jpg
#
# [688 rows x 7 columns]

# %%
final = finalfinal.join(finfin)

# %%
#final.to_csv("finaldataset.csv")

# %%
a = pd.read_csv("finaldataset.csv")

# %%
uniquenames = a[a.Name.duplicated() == False].drop("Unnamed: 0", axis = 1)

# %%
duplicatednames = a[a.Name.duplicated() == True].drop("Unnamed: 0", axis = 1)

# %%
uniquenames
# Out:
#                                                Title  Ratings  Ranked  \
# 0                                 100 Days My Prince      8.3    #354
# 1                                 100 Days My Prince      8.3    #354
# 2                                           18 Again      8.8     #44
# 3                                           18 Again      8.8     #44
# 4                            7th Grade Civil Servant      6.9   #4405
# ..                                               ...      ...     ...
# 664                                      Who Are You      7.6   #2294
# 668  Wild Chives and Soy Bean Soup: 12 Years Reunion      7.2   #3990
# 673                                     Witch's Love      7.5   #2740
# 674                                  Witch's Romance      8.0   #1052
# 687                                Your House Helper      7.9   #1418
#
#     Popularity            Name   Gender  \
# 0         #160    Do Kyung Soo     Male
# 1         #160     Nam Ji Hyun   Female
# 2         #287     Kim Ha Neul   Female
# 3         #287  Yoon Sang Hyun     Male
# 4         #632         Joo Won     Male
# ..         ...             ...      ...
# 664       #310      So Yi Hyun   Female
# 668      #1322     Lee So Yeon   Female
# 673       #439        Hyun Woo     Male
# 674       #231    Uhm Jung Hwa   Female
# 687       #879            Bona   Female
#
#                                       Image  \
# 0      https://i.mydramalist.com/43e46c.jpg
# 1      https://i.mydramalist.com/wlJ8Yc.jpg
# 2    https://i.mydramalist.com/Qy7kW_5c.jpg
# 3    https://i.mydramalist.com/dxN6W_5c.jpg
# 4    https://i.mydramalist.com/wrJg1_5c.jpg
# ..                                      ...
# 664  https://i.mydramalist.com/qxvvB_5c.jpg
# 668    https://i.mydramalist.com/l0wW6c.jpg
# 673    https://i.mydramalist.com/Zod3Oc.jpg
# 674  https://i.mydramalist.com/BDv6b_5c.jpg
# 687  https://i.mydramalist.com/X1q4d_5c.jpg
#
#                               Character1
# 0    Crown Prince Lee Yool / Na Won Deuk
# 1                Hong Shim / Yoon Yi Seo
# 2          Hong Dae Young [37 years old]
# 3                           Jung Da Jung
# 4              Han Gil Ro / Han Pil Hoon
# ..                                   ...
# 664                Detective Cha Gun Woo
# 668                         Yoo Joon Soo
# 673                        Kang Cho Hong
# 674                         Yoon Dong Ha
# 687                          Im Da Young
#
# [319 rows x 8 columns]
