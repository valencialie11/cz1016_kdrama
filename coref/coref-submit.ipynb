# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# #### import the packages
# - we need spacy for nlp
# - we use a matcher to match different spellings of names
# - we borrow spacy's pre-trained model: en_core_web_lg
# - we'll add entity ruler to the pipeline because we need to label all the Korean names as PERSON (which the model sometimes fail to predict it as it is)
# - we import neuralcoref for pronoun replacement (coreference resolution)

# %%
import spacy
from spacy.matcher import Matcher
nlp = spacy.load('en_core_web_lg')
from spacy.pipeline import EntityRuler
ruler = EntityRuler(nlp)

import neuralcoref

# %%
dramas = pd.read_csv('reviews.csv', index_col = 0)
dramas
# Out:
#                      title                                             review
# 0                   Goblin  If you are hesitating to watch this at all, pl...
# 1                   Goblin  I feel compelled to write a review for Goblin ...
# 2                   Goblin  It must be said that Goblin is very much a som...
# 3                   Goblin  Every moment of it indeed shined! Goblin is a ...
# 4                   Goblin  Somewhere inside Goblin, buried under a mound ...
# ...                    ...                                                ...
# 21228  Queen: Love And War  I think I might have over-hyped this drama for...
# 21229  Queen: Love And War  I'll just gonna say it was very wonderful, it'...
# 21230  Queen: Love And War  This is one of my binge watched dramas after b...
# 21231  Queen: Love And War  The best word to sum up this kdrama is "strong...
# 21232  Queen: Love And War  First of all I love the acting! ML is so hands...
#
# [21233 rows x 2 columns]

# %% [markdown]
# #### define functions to remove/convert emojis
# - we use the package `emot` which contains dictionaries for emoticons/unicodes of emojis and corresponding descriptionos
# - the package has typos ('andry'-->'angry'). So we correct them after we import them

# %%
from emot.emo_unicode import UNICODE_EMO, EMOTICONS_EMO
for emo, des in EMOTICONS_EMO.items():
    if ' andry ' in des:
        EMOTICONS_EMO[emo] = EMOTICONS_EMO[emo].replace('andry', 'angry') # the package has typos
        
def remove_emo(text):
    for emot in UNICODE_EMO:
        text = text.replace(emot, ' ')
    for emot in EMOTICONS_EMO:
        text = text.replace(emot, ' ')
    return text

def convert_emo(text):
    for emot in UNICODE_EMO:
        description = "_".join(UNICODE_EMO[emot].replace(",","").replace(":","").split())
        text = text.replace(emot, ' '+description+' ')
    for emot in EMOTICONS_EMO:
        description = "_".join(EMOTICONS_EMO[emot].replace(",","").split())
        text = text.replace(emot, ' '+description+' ')
    return text

# %% [markdown]
# #### define functions to clean punctuations / remove non-ASCII characters
# - we replace repeated punctuations (eg. replace two or more '?' with '?' because we want to split by punctuations (eg. single '?') later. If we don't replace then later we'll have many strings of '?' when the reviewers use '??????' in the review
# - we don't want to split by comma because we want to keep the full sentence. So we'll replace '...' with ',' and decimals (eg: 7.8) to 7,8
#
#
# - we also define a function to remove non-ASCII characters

# %%
def clean_punct(text):
    text = re.sub(r'\?{2,}', "? ", text) # replace two or more '?' with '? '
    text = re.sub(r'!{2,}', "! ", text)  # replace two or more '!' with '! '
    text = re.sub(r'\.{2,}', ", ", text) # replace '...' with ', '
    
    text = re.sub(r'\s+-\s*', ' ', text) # replace - with ' '
    text = re.sub(r'&', ' and ', text)   # replace & with ' and '

    dec = re.findall(r'\d+\.\d*', text)
    for n in dec:
        m = n.replace('.', ',')
        text = text.replace(n, m)       # replace 7.8 with 7,8
    text = re.sub(r'\s+', ' ', text)
    return text

def clean_ascii(text):
    return str(''.join([t if ord(t) < 128 else ' ' for t in text]))

# %% [markdown]
# #### language detections:
# - remove emojis first because they'll affect language detections
# - if the review is in English, we'll then convert the emojis/emoticons

# %%
from langdetect import detect_langs

langlist = []
review_clean = []
for d in range(len(dramas)):
    no_emo = remove_emo(dramas.iloc[d,1])
    no_emo = clean_punct(no_emo)
    try:
        langL = detect_langs(no_emo)# for language detection, remove emojis instead of replacing them first, becuase the English description may affect the detection results
    except:
        langlist.append(d)
        continue
        
    if str(langL[0]).split(':')[0]!='en':
        langlist.append(d)
    else:
        with_emo = convert_emo(dramas.iloc[d,1])
        review = clean_ascii(with_emo)
        review = clean_punct(review)
        review_clean.append(review)
# we don't do clean_ascii first before detecting language because it may affect the language detections

# %%
print("number of non-English reviews:", len(langlist), '\n')
for lang in langlist:
    print(dramas.iloc[lang, 1], "\n")
# Out:
# number of non-English reviews: 126
#
# 5 episodios he durado. Todo en esta serie es tan absurdo que no te motiva a seguir viéndola. Lo mejor la música y los actores, pero no consiguen sostener la lamentable trama.
#
# Os pontos mais altos de Goblin são: a trilha sonora, q é uma das melhores, se não a melhor trilha sonora em Doramas q já escutei na vida, a arte  visual e a fotografia, que são belíssimas, os efeitos especiais, que são incríveis e não deixam em nada a desejar, a incrível atuação da Sunny, que de longe e a melhor personagem do Dorama, ah, o enredo tbm é bem interessante. Agora os pontos negativos e que me incomodaram bastante, alguns furos de roteiro idiotas, a morte mais nada a ver da protagonista, sério eu fiquei de bobeira como aquilo foi forçado e a atuação medíocre do Dong Wook ou "Grim Reaper", um personagem com bastante potencial, mas com um crescimento quase nulo é de é personalidade rasa, sério, não sei o q as meninas pagam tanto pau pra esse cara!
#
# Troche sie meczyeam. Watki poboczne byly czesto ciekawsze niz ten glowny. Duzo ladnych scen. Glówna bohaterka irytujaca i dziecinna. Postaci Goblina i Zniwiarza bardzo dobre.
#
# un drama super un mélange romance/fantastique super bien fait pourtant au début j'ai eu un peu peur avec l'historique sanglant mais part la suite pas déçu sauf la fin j'aurais aimer une autre meme si elle est bien.commentaire traduit aussi en anglais pour que tous le monde comprennent. No drama super-UN novel fantastic / great fantastic well done so early in the beginning i got little no fear with the bloody historical But part the following not disappointed Except the end I would love even if another one is fine.
#
# Ceritanya okey bgt walopun genrenya fantasy,, jg cm lihat sekedar khayalan yg ga mungkin. Ada lucu nya,  romance,, pokoknya terhibur. Apalagi ada trio ganteng nya.. Komplit bgt.. Mereka bener bener kocak bgt, berharap mereka bakalan main bareng lagi buat drama di masa dpn. Kalo bs genrenya fantasy juga. Soalnya aku suka bgt drama, apalagi genre fantasy, mystery, detective, kalo yg romance gitu agak kurang ya. Thank u? - Tp rada ga suka nya, peran main cewenya.. Entah knp saat jd anak sekolahan cantik, tp pas cerita dewasa berambut pendek, keliatan jelek. Kyk lbh tua dr s goblin nya. - Juga sayang bgt, cerita tentang Sunny n Wangyi aka Kim Woobin nya rada sedikit. Pas endingnya itu lohh,, yg bikin rada gimana gitu.. Uri Sungjaenya kemana? Yg mana? Kok ga ada.
#
# WATCH IT NO QUESTIONS .❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️??????????????????????????????????????????
#
# I can not hold on to this drama. It lacks something that makes me want to continue to watch it. I usually have trouble picking a drama, it's also why I expect they are finished watching them. But, I really worth. I'm on episode 11 and since I started, I watched 5 other dramas (seen trafficked few) and some films. I think I'll end up Give Up. Je n'arrive pas à accrocher à ce drama. Il lui manque quelque chose qui me pousse à vouloir continuer de le regarder. Habituellement j'ai du mal à décrocher d'un drama, c'est d'ailleurs pour cela que j'attend qu'ils soient finis pour les regarder. Mais là, je peine vraiment. J'en suis à l'épisode 11 et depuis que je l'ai commencé, j'ai regardé 5 autres dramas (vu d'une traite ceux là) et quelques films. Je crois que je vais finir par l’abandonner.
#
# Bylo bardzo dobrze, dopoki wszystko mialo miejsce w Urk. Koncówka byla meczaca. Cala akcja wokol trzesienia ziemi i mafiozami byla ciekawie napisana. Glowna bohaterka dziecinna, nie interesowal mnie jej romans, za to jej etyka pracy juz byla duzo lepsza. Romans poboczny byl duzo ciekawszy.
#
# Para mim definitivamente foi é será o melhor drama de 2016! Ótimo elenco, ótimo enredo, ótima ost. Produção fantástica! THE BEST <3
#
# Ce drama est vraiment "LE DRAMA DE L'ANNEE 2016" à ne pas manquer. Ok je ne fais pas de "Spoil" mais allez le voir, bon vous avez de la chance maintenant tous les épisodes sont sortis (vous allez vite comprendre en le regardant). Pleins de rebondissement, d'inattendu. Le sujet n'est pas ordinaire et les acteurs jouent vraiment très très bien, on ne sait jamais à l'avance ce qu'il va se passer dans l'histoire. Bon visionnage en gros ! Attention c'est un "Policier Thriller" ça bouge ... si vous n'aimez pas ce genre passez votre chemin.
#
# Fine un pò scontata però non è stato male. Storia interessante, personaggi pure, luogo bè è lo stesso di molti drama che ho visto; ma vorrei dire che l'idea utilizzata mi è sembrata un pò troppo "americana" che è risultato una pazzesca. Complimenti allo scenografo e al produttore, che ha saputo gestire un coordinamento diverso dal solito; ideare una serie/fumetto che si può anche visitare, non è per niente male; i due personaggi principali non mi hanno fatto impazzire ma sono stati bravi. Per l'antagonista devo ammettere che sono rimasta stupita quando ho scoperto chi era, a parte l'altro "cattivo" che era stato creato del fumettista, personaggio del drama. Non è stato un granchè, per il resto del cast, secondo me serviva per riempire 16 puntate... lo so che è un brutto giudizio per il cast ma io la penso in questo modo. Ora spero che nascano altri drama korean di questo stile anche per qualche altra storia.
#
# I love this drama so much that I I'll never forget it till my life ended. I wished it came out season 2 ........... Saranghae Giguuiztsusjyfugihydgfihoghycu jfkkdjdbdjdkdkkffhugof me fjfivuidjdbskdodvxhdsidgxjhcycududhdivdibididhidgudgidhidhidhihdihdibskbisboajosbkx imdmdkdkdjkdkdkdkdlodllfkfkfhfjfkkfkfjjfkfkfkkfjfkfkldkdkdkkdkdkkdkdkdkkdkdkdkkdkdkkdkdkdkdjjdkdkldkdldkkdldllflflfkkdkfkfllflflflflfkfklttueisgishodnidbidbipdhigsisisgusgudgdsh hdihdivdigdigdigdihdihdihdigdihdihdohdohdigsigsudgigdigidgdgdgdjjdgdhdhdrhjdjjfjdjxjfkkfjfjjdjjjdjdjdjjdjdjjdkdjdjjdkdkdkkdkdkkdkjjjdjdjjdjdjjdjdjdjjdjdjjdjdjkfkfkfjjfjfkkfkfjjfkfkfkkfkd
#
# eu ñ consigo assistir pq os episódios sumiram em tds os doramas :(
#
# AMEI! Simplesmente perfeito. Aquele tipo de Dorama que te chama atenção, e que você acha que vai de um jeito e muda aos poucos. Meu coração ficou na mão a cada segundo! Super recomendo, porque eles são maravilhosos juntos <3
#
# O enredo não é tão interessante ou chamativo, a atuação tbm não é lá grandes coisas e é bem padrão mesmo, não tem muito destaque para ninguém (personagens), as piadas não tem muito o que falar, afinal nenhuma me fez ri ou foi até mesmo interessante, nem mesmo a que geral sempre comenta "MESSI" os acontecimentos tbm são bem previsível, um cara boa pinta é um dos melhores atletas da escola, e óbvio q ele teria uma ex e o melhor de tudo ou não, louquinha, louquinha, é um dorama pra vc desliga a mente e de pouca ou quase nula profundidade, mas não tem nada de errado em gosta, visto a nota incrivelmente alta que ele possui e é um dos queridinhos da galera, no mais é um dorama água com açúcar!
#
# #1 ON MY FAVORITE DRAMA LIST! I'LL NEVER GET TIRED WATCHING THIS OVER AND OVER AGAIN!! SWEEEEG!
#
# allora iniziamo col dire che prima di iniziarmi il drama ho letto tante di quelle recensioni negative da farmi venire il mal di testa, devo ammettere che sono tutte bagianate poiché nella recensione ho letto molte volte che “è uno dei peggiori drama mai visti, è monotono, è più piatto di una tavola da surf eccc” da premettere che io l’ho iniziato subito dopo che sono usciti tutti gli ep in italiano quindi vedendolo tutto di botto “senza aspettare un ep alla sett” sicuramente ha avuto un altro effetto… devo ammettere che è stato un drama scolastico diverso dagli altri basato tutti sugli eredi più importanti con solo una ragazza povera… è stata interessante la parte che ha svolto Park Shin essendo che lei ancora “avendo interpretato tantissimi ruoli da protagonista “ ancora, secondo me non ha trovato lo sblocco che gli serve e che sembra che solo lee min ho abbia compreso, infatti solo negli ultimi ep abbiamo visto che la protagonista fosse più sciolta, a parte questo l’interpretazione di lee min ho mi ha lasciato un po’ perplessa poiché abituata a vederlo in versione tutt’altro che senior, devo dire che il ruolo che ha svolto in questo drama non l’ha valorizzato parecchio, kim woo bin invece è tutto un che dire, ha svolto un bel ruolo e si è immedesimato perfettamente nella parte, per me è lui il vero protagonista del drama avendo svolto un ruolo impeccabile e meglio di tutti gli altri in the heirs (gli eredi), Krystal Jung all’inizio odiosa in assoluto ma ce poi conquista i cuori di tutte noi dramiste con la sua parlantina velocissima e la sua gelosia sfrenata per Kang Min Hyuk ( il batterista dei CNBLUE) formano una bella coppia entrambe  e devo aggiungere che Min Hyuk è cresciuto parecchio dopo aver recitato nel ruolo di Heartstrings… IN SEGUITO TUTTI GLI ATTORI DI THE HEIRS hanno svolto un ottimo ruolo; il finale mi è piaciuto molto devo dire, aggiungerei che non mi è garbato molto il finale del nostro Choi Jin Hyuk (il fratello maggiore di lee min ho) poverino dopo tanti sacrifici ha ottenuto ciò che voleva ma che aimè ha dovuto rinunciare alla cosa più importante Cmq in questo drama sono uno più strafigo di un altro XD Il drama in per sé è stato gradito, all’inizio strafigo ed interessante ma poi verso la metà si è perso un po’ ma per fortuna si è ripreso negli ultimi episodi, ve lo consiglio e non badate a tutte le recensioni negative che girano su FACEBOOK soprattutto!!!!!!!!
#
# Me encanto, fue fresca y dramática a la vez, moderna y divertida, las actuaciones fueron estelares, tanto de los personajes principales como de los secundarios, de hecho principalmente de los secundarios. la trama se desarrollo sin capítulos aburridores y con pequeñas dosis de clímax entre capítulos que nos dejaron entusiasmados por ver el siguiente. Excelente drama!!!!!!!
#
# Cara...  Pinocchio é simplesmente maravilhoso. O elenco é simplesmente incrível! Cara... Shin Hye é linda e uma excelente atriz e junto com Jong Suk, os dois arrasaram... Shin Hye atuando como a In Ha foi incrível, aqueles soluços que ela dava a toda vez que mentia, além de ser engraçado, era fascinante. A personagem dela com certeza foi a melhor das melhores! E o Dal Po (Jong Suk)... cara, que personagem de da dó no inicio e no fim torcer pra que ele não vacilasse e fizesse as coisas corretamente (foi lindo)... Esses dois fizeram um espetáculo de perfeição! Claro que o reconhecimento não irá só pra eles dois, como também, para a Jin Kyung (Song Cha Ok). Ô atriz linda e phoda!! Aquelas últimas cenas dela, foram incríveis! Ela trabalhou muito bem! Soube fazer &amp;quot;Fato e Impacto&amp;quot; (se é que me entende?!) Yoo Bi (Yoo Rae), Young Kwang (Bum Jo) e Gyun Sang (Jae Myung), que excelente trabalho de cada um... Yoo Bi fazendo da sua personagem a mais cômica da série. Já Young Kwang fazendo a personagem dele um mimado que com o tempo teve que amadurecer para que as coisas fossem corrigidas, por fim, Gyun Sang, puts... a personagem dele foi o que mais me emocionou, carai... Claro que tem mto outros personagens bons, mas esses que listei acima foram os que mais causaram e fizeram da série phoda e perfeita demais e por isso merecem meu reconhecimento, tanto para as personagens que fizeram, como também pela bela atuação... Escolheram perfeitamente o elenco. E por isso, mais uma vez dizendo... Pinocchio deixará muitas saudades <33
#
# Gran dorama, de los pocos que he disfrutado hasta el momento. Tiene de todo no solo amor tambien intriga y humor. Me a encantado y la quimica entre los actores principales es maravilloso. Espero ver algo pronto de Park Shin Hye y Lee Jong Suk
#
# Las casualidades y conveniencias de guión, sumadas a un monton de factores externos, y los personajes totalmente unidimensionales (teniendo en cuenta que es una novela), arruinan el dorama que podria ser un 9 tranquilamente. Falto desarrollar MUCHO el personaje de Ki Jae Myung, y no hacerlo simplemente un complemento para el protagonista. Mas allá de eso no hay mucho mas que decir.
#
# Mon tout premier Drama.. et j'ai trop aimé. Autant dire qu'après celui-là j'en ai enchainé quelques-un. Ce drama est d'une richesse scriptural ... génial vraiment.
#
# 10/10 baby. Just watch it. Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer Healer
#
# &quot;Healer&quot; un drama con una temática muy diferente que te atrapa en seguida, los primeros capítulos muy buenos pero en lo personal en los últimos se me hizo algo lenta. aún así un buen drama recomendable para pasar el rato y para destacar personajes como la &quot;ahjuma&quot; o escenas tiernas entre los protagonistas, el final me gusto, me dio todo lo que necesitaba pero no me sorprendió demasiado. en conclusión un buen drama de duración media, digno de recomendarse.
#
# A primeira vista lendo somente a sinopse, é possivel achar que a história é somente mais um clichê dos doramas, porém é muito mais que isso. A relação que o casal principal vai construindo é feita de maneira gradual, não deixando brechas para pensarmos que aquele amor é tóxico ou motivado por outra coisa que não seja o verdadeiro sentimento dos envolvidos. A história é surpreendente e te prende do início ao fim, sendo esse admirável. A atuação de todo o elenco é impecável, eles entregam tudo o que você espera do personagem. Além disso, ainda te trás alívio cômico sempre com a ajuda dos coadjuvantes e até dos personagens principais. Esse dorama é simplesmente perfeito (na minha opinião), e de forma técnica ele também é muito bom.  OBS= se você gosta de uma temática mais adulta e de um dorama com um pouco mais do que somente alguns beijos, esse é pra você.
#
# yaaas yas yaaaaaaaas yas yaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yasyaaas yas yaaaaaaaas yas
#
# [PORTUGUESE] Moon Lovers não é um drama qualquer, e talvez seja por isso que tenha chamado tanta atenção do público ocidental. Para mim, o que mais me atraiu no drama foi o casal principal, principalmente no que se refere à química entre os atores Lee Joon Gi e Lee Ji Eun (IU). Não existe uma palavra no meu vocabulário que possa resumir a atuação do Joon Gi como Wang So nesse drama, pois "maravilhoso" e "incrível" são adjetivos muito vagos no que se refere às expressões faciais desse homem. Ele conseguiu me ganhar já na primeira cena dele no cavalo, chegando em Songak durante o eclipse (aquela imagem é maravilhosa), e quanto mais conhecia o personagem e percebia o que estava por trás dele, mais me apaixonava. Alguns dizem que ele levou o drama nas costas, mas eu não acho isso. Ele como personagem principal tinha que se destacar mesmo, e isso ele fez com louvor.
#
# Gente tem episodio 21? Pq ai aparece mas quando clica não vai? eu amei tanto o dorama amei amei
#
# Este dorama foi para mim uma agradável surpresa. Normalmente eu demoro de 2 a 3 episódios para me apegar aos personagens e torcer por eles, em Secret Garden como coisas como um pouco mais lentas e até pensei em parar de assistir, o Kim Joo Won estava realmente muito chato humilhando Gil Ra Im, eu pensei que nunca daria certo aquilo, brigando o tempo todo mesmo já tendo passado tantos episódios. Ainda bem que não desisti, como coisas realmente mudam depois. Não vamos falar muito para não dar spoiler Mas o que ele fez por ela no final foi de tocar o coração. Eu semper acho interessante essa coisa de "trocar de corpo" e isso foi o que me atraiu para assistir. A primeira troca deles rendeu momentos bem divertidos, mas depois é ficado mais sério. A personagem mais desagradável do drama foi a mãe do Kim Joo Won, que mulherzinha mais chata hein, o melhor personagem (excluído os dois protagonistas, claro) foi Oska, ele pode até não ser um bom namorado mas com certeza e um ótimo amigo, seus momentos com um Ra Im eram especiais, mesmo quando ela estava em "outro corpo". Por mais que eu tenho achado no começo que o casal protagonista não tinha nada a ver um com outro, já era de esperar que esta relação de amor e ódio iria acabar em amor. Tenho que admitir: eles são muito fofos juntos <3
#
# Simplesmente incrível, atores maravilhosos, verdadeiro drama, comedia e romance.
#
# J'adore. Déjà vu 2 fois et sans doute je le regarderais encore...
#
# Et oui City Hunter entre évidemment dans mes "Drama coup d'coeur" J'ai beaucoup aimé l'intrigue, l'histoire, le jeu des personnages, les acteurs jouent vraiment bien, que dire de plus. Une belle fin aussi (même si toujours un peu baclée à mon gout, ce que je trouve un peu dommage, d'ou le 9,5 au lieux de 10) pourquoi les auteurs ne prennent-ils pas le temps de nous faire de vrai belles fins qui ressemblent à quelque chose !!! pas juste les 5 dernières minutes du drama quand celui-ci fait entre 16 et 20 épisodes... enfin, Bref, reste que ce drama vaut le détour évidemment. A voir et éventuellement revoir.
#
# She Was Pretty bisa saja kelanjutan cerita Kill Me Heal Me versi Hwang Jung Eum dengan Park Seo Joon, hihi. Nggak ding. Ini sama sekali bukan kelanjutan Kill Me Heal Me, namun banyak candaan di media sosial mengenai dua drama tersebut. Lucu juga sih kalau misalkan beneran, kan. Story Kim Hye Jin, tumbuh menjadi seorang gadis berambut keriting dan jerawatan. Ji Seong Joon, tumbuh menjadi pemuda tampan dan pekerja keras. Perubahan keduanya benar-benar menakjubkan. Bagaimana tidak? Sewaku kecil Hye Jin sangatlah cantik dan seseorang yang baik kepada siapa saja. Dan itu pulalah yang membuat Seong Joon kecil jatuh hati pada Hye Jin. Hingga suatu hari, Seong Joon harus berpisah dengan Hye Jin. Mereka berjanji akan saling bertemu di kemudian hari. Tapi ketika waktunya sudah tiba, mengapa Hye Jin tidak mau bertemu dengan cinta pertamanya? Dan ketika Ha Ri menyukai Seong Joon, apa yang harus Hye Jin lakukan? Wah, She Was Pretty menganut paham 'cinta masa kecil' nih. Kalau menganut paham tersebut sih, akhirnya pasti udah ketebak. Tapi yang aku suka dari kebanyakan drama Korea, mereka selalu menampilkan latar belakang pekerjaan si aktor-aktrisnya dengan detail. Di She Was Pretty ini mengusung pekerjaan di balik sebah majalah fashion. Dan aku suka banget kalau ceritanya lagi ada di kantor majalah. Seru banget. Acting/Cast Sebelumnya aku udah nonton aktingnya Hwang Jung Eum dan Park Seo Joon sebagai adik-kakak di Kill Me Heal Me. Di sini kemistri mereka dapet banget. Menurutku karakter Kim Hye Jin nggak beda jauh sih sama karakter Oh Ri Jin, heboh nya samaaa, haha. Aku suka Park Seo Joon di sini. Mungkin karena dia peran utama jadi karismanya dapet banget. Tapi aku lebih suka Hye Jin - Shin Hyeok masa. Ketawa mulu tiap ada mereka berdua. Aku juga suka sama karakernya Pemred Kim. Saat dia memberikan ambutan di ulang tahun The Most, kata-katanya menyentuh sekali. Jadi baper bacanya (ya karena aku baca subtitlenya) Music Untuk soundtrack ada ih yang nyantol di telinga, tapi tetep yah, aku mles download lagunya. Cuman dengerin pa diputar di radio aja, xixi. Rewatch Value Karena ecara keseluruhan cerita ini tipe yang mudah ditebak bagaimana akhirnya, jadi untuk di tonton ulang sepertinya nggak deh. Paling pas adegan yang menurutku seru aja, kayak adegannya Hye Jin-Shin Hyeok, haha.
#
# https://mystuffmynonsenses.wordpress.com/2016/03/02/cheese-in-the-trap/ Nel mio lungo elenco dei drama visti o che sto vedendo spicca Cheese in the trap, tratto dall’omonimo webtoon non concluso di Soonkki disponibile su Naver in coreano e su Webtoons in inglese (sono indietro con le stagioni). Sono tanti i fattori per cui inizio a guardare un drama e decido di spendere almeno sedici ore della mia vita. Inizialmente fa da calamita la scelta del cast. Scorrendo alcuni post fra vari forum e blog, ho letto la lunga diatriba (internazionale) su chi potevano essere adatti a ricoprire i personaggi tanto amati dai lettori del webtoon. La discussione era incentrata per lo più sul personaggio femminile principale, Hong Seol, quale attrice poteva meglio rappresentare un personaggio così divertente, forte, non bellissima ma nemmeno brutta, rovinare l’immaginario del lettore del webtoon. La scelta è caduta poi sull’attrice emergente e camaleontica, Kim Go Eun. Famosa per lo più in ambito cinematografico (Eungyo, Monster, Coinlocker Girl, Memories of the Sword… un curriculum invidiabile costruito in pochi anni), CITT è il suo debutto nel piccolo schermo. Per me è stata una fantastica scoperta e che continuerò a seguire, disponibilità in inglese dei suoi progetti permettendo, per lo più film appunto. Da persona profonda e riflessiva quale sono io, sono stata invece attirata dall’attore principale, Park Hae Jin, che ha una trentina di anni e ricopre il ruolo dell’universitario. Per me è credibile, questi attori coreani non invecchiano mai. Scherzi a parte, non cambierei nulla della scelta del casting, ogni attore ha fatto il suo dovere, mi sono divertita a vederli e mi hanno convinta. Bravissimi i principali. Ma anche i secondari meritano. I secondari “odiosi” poi riescano a rubare la scena agli attori principali in alcuni momenti. Ricorderò sempre Sang Chul, Young Gun, Min Soo. Sono detestabili ma ispirano anche pietà in scene apparentemente innocue. Mi piacerebbe dire che il merito non sia solo degli attori ma anche della regia di Lee Yoon Jung, già regista di alcuni drama che ho adorato (Coffee Prince, Heart to Heart). Dirige il cast in maniera stupenda. Gli attori non sembrano recitare. Nelle sue mani i personaggi sembrano vivere. Per questo drama, la trama è pressoché basilare e già vista: una ragazza e un ragazzo si incontrano e si innamorano. Semplice. Ciò che lo rende diverso dagli altri sono la rappresentazione dei suoi personaggi sia principali che secondari. Il fascino di CITT è proprio nei personaggi complessi (e complessati) in cui possiamo (a volte) riconoscerci…. oddio a parte alcuni personaggi come Young Gon lo stalker e Min Soo intendo dire, lo stesso personaggio principale non rientra nei canoni “dramosi”. La scelta dell’OST che accompagna l’intero drama si discosta dalla solita kpop commerciale ma è davvero azzeccata (detto da una persona che non capisce il coreano, mi fa capire quanto la musica sia davvero un linguaggio universale che va al di là delle barriere linguistiche quando si tratta di trasmettere emozioni). CITT rientra nei drama che posso ritenere belli nonostante i suoi difetti e le polemiche di cui è stato investito (e che continuano nonostante la messa in onda dell’ultima puntata). Prima ancora della messa in onda, la polemica verteva sulla scelta dell’attrice, che non fosse somigliante abbastanza alla Hong Seol del webtoon. Polemica poi zittita dalla recitazione della bravissima Kim Go Eun e dai numeri dell’indice di ascolto del drama, dal 3 al 6%, che per una tv via cavo come la Tvn è un buon risultato, tanto che il cast si è meritato già una vacanza premio. Le successive polemiche riguardano poi la seconda metà del drama, ovvero la scelta della regista o degli autori o dei produttori (o di tutti loro) di diminuire le scene di Yoo Jung (Park Hae Jin), il personaggio principale a favore del second lead, Baek In Ho (Seo Kang Joon). È una scelta strana che potrebbe coincidere in parte alla terza stagione di CI ...
#
# I never watch horror or scary movies so I passed on this one a few times ..should have watched it sooner! Great storyline,great acting, and im not usually one to watch things for a second time I would watch this. ...
#
# Saya suka dengan plotnya. Tapi lama kelamaan makin aneh dan tidak seram yang seperti saya bayangkan. Anda yang tidak suka dengan film horror karena ada jump scare tidak perlu khawatir untuk itu. Karena menurut saya episode yang seram hanya sepatu merah wanita. Selebihnya tidak seram. Anda bisa menontonnya sendiri tanpa takut ketakutan. Tokoh wanita disini sangat bagus aktingnya dan tokoh prianya pun juga. Saya cuma sedikit kecewa dengan plot yang lama kelamaan membosankan dan terlalu dibuat buat.
#
# ahahahahahhaha lei troppo pazzaaaaa, lui da urloooooooo (ha 36anni ma dove cavolo li ha messiiiiiiiiiiiiiii); questo drama è basato dal fatto che lei vede le persone già morte e che si presentano a lei chiedendo un solo favore prima di scomparire per sempre, questa si avvicina al nostro protagonista non perché è interessata, anzi lei non si accorgerà di lui fin quando non ci sarà una svolta nel drama, ma per via dello spirito di una giovane ragazza, ex del nostro presidente, che cerca in tutti i modi di far trapelare di come sia andato veramente l’incidente di quando lei perse la vita parecchi anni fa… bel drama anche molto comico soprattutto quando la protagonista beve, lui (no comment) con il suo SPARISCI DALLA MIA VISTA ahahahhahahah
#
# It's Okay , That's Love ???? - The Review - ok . teka . hinga muna ako , hano ? *sigh* soooo . kalagitnaan pa lang ng storya , nakutuban ko na yung twist at lalo ako naintriga . at oo , ANG SICK NUNG TWIST . sobrang sick lang . sobrang under rated neto kasi hindi ko talaga sya nakikita sa kahit anong list ng 'BEST' KDrama pero isa ito sa pinaka solid ang storya . sick yung twist pero hindi malayong mangyari sa totoong buhay . Alam ko ng magaling umarte si Do Kyung Soo . Kaya ko nga 'to pinanood dahil sa kanya . Alam ko na ring magaling umarte ang pambansang ajusshi na si Sung Dong Il - sa dami ng napanood kong KDrama na cast sya , alam ko na kalibre nya . Kahit si Gong Hyo Jin , alam ko na rin na award winning . ANG KINAGULAT KO , si LEE KWNAG SOO . first time ko kasi sya mapanood sa Drama . oo , si Lee Kwang Soo - yung real life bestfriend ni Song Joong Ki na sobrang sira ulo sa Running man . sya nga . hanep pala umarte si Gago . ibang level lang . A MUST WATCH . kung naghahanap ka ng KDramang worth it pagpuyatan , isama mo 'to sa listahan . babala lang , hindi sya light . MABIGAT YUNG STORYA . at marami kang ipa-process na info along the way - marami kang matututunan . again , di ako maka get over sa twist . may isa dito na hindi naka-credit as MAIN CAST . SUPPORTING lang . pero sya nagdala ng storya . sya yung turning point . pakshet lang . eto yung tipo ng storya na iisipin mo ng mga ilang araw pagtapos panoorin . iba . #ItsOkayThatsLove #DO12 #EXO #EXOLove #WeAreOne #Saranghaja
#
# Glowny watek wciagajacy. Radzenie sobie z choroba psychicza i jej nie stygmatyzowane. Dobra gra aktorska i swietna muzyka.
#
# PERFEITOOOOOOOOOOOOO <3 Eu realmente amei muito esse dorama, está entre os meus preferidos para sempre <3
#
# Drama del genere commedia-musicale che ripercorre un po’ lo schema della serie “Saranno famosi”, ottimi interpreti i giovanissimi attori che dimostrano notevoli capacità anche nella danza e nel canto. Buona la sceneggiatura che racconta la storia di questi ragazzi che si muovono nell’ambito scolastico come in un micro-cosmo che contiene tutti i pregi e difetti della vita reale e fra gioie e dolori, fra conquiste e sconfitte, senza mai smettere di sperare, crescono e migliorano. I complimenti vanno anche alla scelta delle canzoni, delle basi musicali e delle coreografie che supportano al meglio e sottolineano i momenti cruciali dell’intera vicenda in modo appropriato e piacevole. Mettendo a paragone saranno famosi con dream high, quest’ultimo lo batte di gran lunga, è stato annunciato come primo drama prodotto in italia sul canale Super del digitale terrestre ahhaha aimè con i doppiaggi in italiano ma con le voci originali quando cantano Il mio preferito? Song Sam Dong è un cantante e compositore notevole; un diamante grezzo nell’aspetto e nei modi da campagnolo, con un carattere dolce e sensibile, sempre pronto ad aiutare gli altri. Per conquistare Hye Mi, di cui si innamora perdutamente da subito, è disposto a trasformarsi e a diventare un artista di spicco, pur di dimostrarle di essere degno di starle accanto. Consigliato assolutamente con le voci originali ovviamente per noi dramiste
#
# Sorpresa delle sorprese, a presentarsi come possibile coinquilino sarà proprio Jeon Jin Ho, disposto a fingersi gay, condizione indispensabile per essere accettato nella convivenza con la padrona di casa, pur di scoprire i segreti dell’esclusiva dimora di lei e sfruttarli per ottenere l’appalto di un importante lavoro che potrebbe salvare la sua ditta dal lastrico.La forzata intimità, fra i novelli coinquilini, a quali sviluppi porterà? L’antipatia diventerà simpatia? L’ostilità cambierà in solidarietà? La finzione si trasformerà in realtà?? bellissimo drama , commedia romantica e soprattutto lee mi ho nei panni di un finto omosessuale
#
# নতুন স্কুলে বদলি হওয়ার প্রথম দিনই দূর্বল এক স্টুডেন্ট এর উপর অন্য আরেক স্টুডেন্ট এর অত্যাচার মেনে নিতে না পেরে তাকে আঘাত করে বসে কঠোর নীতিবান ছেলে Park Sae Ro Yi. সেই আঘাত এর প্রতিশোধ নিতে হাজির হয় সেই ছেলের বাবা Jang Dae Hee, যে কিনা কোরিয়ার সবচেয়ে বড় ফুড কর্পোরেশন Jangga এর মালিক। চেয়ারম্যান Jang Dae Hee, সে-রোয়ি কে হাঁটু গেড়ে বসে ক্ষমা চাইতে বলে তার কাছে, না হলে তাকে স্কুল থেকে বহিষ্কার করা হবে। নীতির সাথে কখনো আপোষ না করা ছেলেটা কোনো ভাবেই রাজি হয় না বিনা কারণে ক্ষমা চাইতে। যার দরুন চাকরি হারাতে হয় তার বাবাকে এবং স্কুল থেকে বহিষ্কার হয় সে। কোনোরকম আশাহত না হয়ে বাবা ছেলে সিদ্ধান্ত নেয় ছোট্ট একটি রেস্টুরেন্ট খোলার। সবকিছু ওলোট পালোট হয়ে যায় যখন সে-রোয়ির বাবা হুট করে একটা এক্সিডেন্ট এ মারা যায়। এবং জানা যায় এরজন্য সেই চেয়ারম্যান Jang dae Hee এর ছেলে দায়ী।রাগে, দুঃখে, হতাশায় সেই ছেলে কে মারতে গেলে পুলিশ তাকে Attempt To murder এর কেসে জড়িয়ে ফেলে এবং ৩ বছরের জন্য শাস্তি হয় তার। এপিজে আব্দুল কালাম এর একটা কথা আছে "স্বপ্ন সেটা নয় যেটা তুমি ঘুমিয়ে দেখো,স্বপ্ন সেটাই যেটা তোমাকে ঘুমাতে দেয় না।" এই ড্রামার জন্য,বিশেষ করে সে-রোয়ির কাছে স্বপ্ন তাই ছিলো যা তাকে ঘুমাতে দেয় নি। মানুষ চাইলে কি না পারে! দরকার শুধু ইচ্ছাশক্তির। ইচ্ছা আর স্বপ্ন থাকলে কোনো কিছুই যে অসম্ভব না তার জ্বলন্ত প্রমাণ Park Sae Ro Yi এর চরিত্র। যতই বাঁধা আসুক সামনে, সব কিছু উপেক্ষা করে এগিয়ে যেতে এটাই এই ড্রামার মূল বক্তব্য। চরিত্র বিশ্লেষণ: Park Sae Ro Yi: বাঁটিছাট চুলের অসম্ভব নীতিবান ছেলেটা এমনিতে খুব চুপচাপ ইন্ট্রোভার্ট হলেও স্বপ্ন দেখায় বিশ্বাসী সে।দূরদৃষ্টি, বিচক্ষণতা, পরোপকারীতা তার চরিত্রের অন্যতম ভালো গুণ। আমার কাছে সম্ভবত পার্ক সে জুনের সবচেয়ে ভালো একটা ড্রামা এখন পর্যন্ত। তেমন কোনো গ্ল্যামারাস লুকে না এসেও কিভাবে শুধু এক্সপ্রেশন আর অভিনয় দিয়ে তাক লাগিয়ে দেয়া যায় তার সবচেয়ে বড় উদাহরণ হয়ত এইড্রামা টা! Jo Yi Seo: এই চরিত্র টা একদম ই অন্য রকম। কম বয়সী, তুখোড় বুদ্ধিমতী, সোশ্যাল মিডিয়া স্টার আর একি সাথে রুড, স্যাভেজ। প্রথম দেখায় বয়সে এত বড় একজন কে পছন্দ করে ফেলা আর তারপর তার সাথেই থাকার সিদ্ধান্ত নেয়া আপাতদৃষ্টিতে হাসির বিষয় হলেও সে কিন্তু সফল হয়ে দেখিয়েছে। এই ড্রামায় আমার সবচেয়ে পছন্দের একটা ডায়লগ হচ্ছে Yi seo যখন বলে- I Have To Be Someone Who He Needs. মানে সত্যিই তো! আমরা কেনো সবসময়ই ভাবি যে আমার জন্য সে-ই সব কিছু করবে। সে-ই আমার স্বপ্ন পূরণ করবে। অথচ এমন স্বার্থপরের মতো চিন্তা না করে এমন টা হয় না যে আমি সেরকম একজন হবো যখন তার প্রয়োজনে সে আমাকে পাবে, দুজনে মিলে দুজনের স্বপ্ন পূরণ করবো, তার স্বপ্ন আমারও স্বপ্ন হবে। আমার কাছে মনে হয়, যখন একটা সম্পর্কে এই মনোভাব থাকে সেই সম্পর্ক পরিণতি পেতে বাধ্য! এই ড্রামার বেশির ভাগ OST সুন্দর। Gaho এর Start Over টা শুনলেই মনে হতো- হ্যাঁ হয়তো আসলেই সব নতুন করে আবার শুরু করা যায়। পুরোনো সব ভুলে নতুন ভাবে একটা দিন সাজানো যায়।
#
# Finalmente sono giunta al termine di questa serie coreana. La serie è stata realizzata molto bene, mi piace l'azione in un film ma molto di più in una serie, perchè si può sviluppare molto di più la storia. Parlando del personaggio K2 è stato a mio parere fantastico, il suo ruolo lo rende credibile e lo fa veramente bene, e così che il protagonista se scelto bene ti può appassionare a tal punto di emozionarti e così capita anche per il cattivo, che qui naturalmente c'è ne sono troppi. Corrotti, burattini e guerre con traffici illeciti, e aggiungiamo omicidi a sangue fresco. Questi tipi di Drama koerani mi piacciono molto e non tutti i produttori riescono a colpirmi; tante volte preferisco un film d'azione a quello d'amore mi annoiano dopo un pò qui infatti ce ne sono talmente poche che potrebbero tenerle per staccare da una sparatoria e combattimenti a mani nude. Come avete bene capito dal mio voto gli ho dato quasi il massimo
#
# Um dos dramas mais consistentes e profundos que já assisti. Óbvio, tenho algumas críticas, mas a atuação juntamente com a história e desenrolar dos fatos me fez ficar viciada do início ao fim nesta obra.As cenas de luta são um tanto irrealistas, mas em compensação, o drama de Anna é possível de se sentir apenas com a mísera informação que você recebe ao longo dos episódios. Yoona é uma atriz excelente, e juntamente com o Ji Chang Wook, que também é um ator magnífico, não poderia esperar menos. Embora o romance seja o de menos nessa história, a química entre os dois é de tirar o fôlego. Um beijo muito bem feito, esse do final, nossa.
#
# bellissimo drama, molto romantico con la presenza di JUNG YONG-HWA il cantante e capo gruppo dei CN BLUE ^3^ bellissimo da morireeeee e lei una bravissima attrice PARK SHIN ... entambi gli attori formano una coppia bellissima e super dolce
#
# bellissimo drama  mi sono piaciuti tutti devo dire... come protagonista maschile abbiamo la bellissima presenza di Choi Minho niente poco di meno che un membro del gruppo degli shinee, l'attrice jae hee è molto carina dolce e carismatica, il suo modo di vestire con quei pantaloni maschili mi faceva morir da ridere  per non parlare del calciatore e del suo modo allegro di vestire ... mi sono piaciuti tutti  sono stata contenta perchè è sempre qualcosa di diverso il mio attore da sbavo del drama è il dottore della scuola Ki Tae-young :Q____
#
# questo drama parla del sovrannaturale, ovvero di una volpe a 6code che cerca a tutti i costi di diventare umana cercando l'affetto e l'amore di un ragazzo..... lei si innamora del nostro protagonista anche se lui all'inizio non si trova a suo agio cerca in tutti i modi di mandarla via dalla sua vita ma, fatalità, lei gli salva la vita donandogli la sua perla, con essa gli permetterà di vivere.... lei è straordinariamente dolce e bella ed è innamoratissima  è un bel drama ve lo consiglio
#
# Pense num drama que eu amei desde o primeiro episódio... Sofri junto com o Hoon e me apeguei ao drama de uma maneira que já estou sentindo falta dele. Jae Hee foi uma personagem que amei e odiei ao mesmo tempo. Amei a coragem dela para enfrentar tudo pelo Hoon, odiei a forma como ela fez o Hoon chorar... rsrs Dra. Oh ou Quack tinha suas metas em primeiro plano, foi bom ver como a chegada do Hoon e amizade dos dois, foi mudando ela aos poucos. Eu gostei do Jae Joon, ele tinha seus próprios planos em mente e uma vingança que esperava cumprir, mas ninguém pode dizer que ele ñ amava realmente a Quack. [SPOILER] Por que consolar a mulher que ele ama que chora por outro não é pra qualquer um, certo? [] Pra falar a verdade, é difícil apontar um personagem que eu ñ tenha gostado, desde as cenas hilárias entre Chi Gyu e a Chang Yi... [SPOILER] Eu realmente torci por este casal... rsrs Quantos garrafões de água ele não levou na cabeça... Se bem que esse "pervetido" mereceu, né?[] Também tinha as cenas divertidas entre o Hoon e o Dr. Moon, esses dois faziam uma dupla e tanto. E mesmo os antagonistas, ah, esses eu tive verdadeiro ódio e desprezo: o vingativo, Jin Soo, o manipulador primeiro ministro Jang Seok Joo e aquele diretor do hospital, Oh Joon Gyu. Vou dizer, os antagonistas me fez odiá-los com muita facilidade... rsrs Torci para a morte de todos eles. rsrs E temos o final, bem, muito do final eu imaginei que poderia acontecer, e meus últimos pensamentos imaginando tudo foi justamente com [SPOILER] a cena "deja vu" da ponte. Pensei que seria inteligente fazer uma retomada da coisa.. E fiquei feliz em vez que a cena realmente aconteceu... Mas ñ gostei da maneira como ela acabou sendo realizada. Porque na minha opinião, a cena que deveria ter um Q a mais, ficou meio perdida, até um pouco sem vida... os fatos que levaram a ela acontecer, pareciam desconexos... E acabei não gostando do ponto final. [] Tiveram várias outras cenas que eu considero que faltou algo a mais [SPOILER] (como quando a Quack descobre que o Hoon está vivo... OI? Só uns tapinhas e pronto? Acho que faltou mais emoção na cena!)[] Entretanto, o drama foi tenso, fofo, bem conduzido, pecou em alguns momentos, mas não deixou de ser ótimo por isso... Sinceramente, vou sentir falta de "morrer" na expectativa dos próximos episódios... rsrs
#
# Simplesmente espetacular! .
#
# I loved the story line but there were 1 or 2 things I'd change about the story line. I admit i cried a good few times. I didn't like Seo Jun, he seemed a bit of an asshole the more you watch. I was a bit upset for Hae Rin since she had no idea about their relationship. The ending was beautiful and heart warming. I overall loved the show but i could fine some things that could have made it better. i don't have anything else to say about it so... ...
#
# Bellissimo drama, molta commedia  fino a lacrimare, bellissima la storia piochè diversa dalle altre, INASPETTATA, avrei di certo preferito che continuasse, i due protagonisti sono troppo belli, formano una bella coppia Micky Yoochun ,bellissimo lui con la sua voce che mi penetra il cuore  , e Han Ji Min lei super bella con lo sguardo più dolce di tutta Joseon. questo drama è davvero eccezionale: la trama è davvero ben congeniata e gli attori sono davvero molto molto bravi! Ci sono parecchi colpi di scena e la storia fra loro due è Un drama davvero molto bello che consiglio vivamente, altro consiglio? preparatevi una scorta di kleenex  E' un drama da guardare assolutamente
#
# Pertemuan yang tidak terbayangkan memulai kisah drama ini. Para aktris dan aktor berhasil membuat semua emosi keluar. Anda tidak akan bisa menahan tangis saat menonton ini. Emosi marah, rindu, tangis, dan kekecewaan diperlihatkan. Banyak adegan yang tidak terduga. Jangan harap ini akan menjadi sebuah cerita cinta yang berjalan mulus. Banyak yang bisa dipetik di dalam drama ini. Tapi, sabar. Jangan ditonton dengan melompat. Anda harus benar benar meresapi apa yang aktor dan aktris sampaikan. Sebuah drama yang mengharukan.
#
# Provavelmente esse dorama é em que eu mais me envolvi com os personagens, não tem essa de "vilão" ou "mocinho", eles são complexos e realistas. A trama se desenrola de forma lenta, mas necessário pra compreender os personagens e a forma em que lidavam com a dor e as situações em que os cercavam. Perdi as contas das vezes em que gravei uma frase dita por ser tão inspiradora e bonita, e também perdi as contas de quanto chorei, foram lágrimas de felicidade, tristeza e aceitação. Aprendi que quando algo tiver que acontecer, ela vai independente da situação, você nunca vai estar preparado, pois a vida é assim. Então em vez de dizer palavras que ferem para as pessoas que te amam, abrace-as e as ame com toda sua força, pois nunca sabemos o amanhã. E mesmo depois de tantas coisas que os abalaram, juntaram os cacos, mesmo quando não parecia possível e tentaram seguir em frente. Me doía ver eles guardavam tanto dor pra si, vi que é importante desabafar suas dores e medos pra as pessoas que amam e assim torna-los menores ao os compartilhar.Esse foram os pensamentos que eu tive após terminar esse dorama. Não foi apenas um dorama triste, ele teve também episódios engraçados e felizes,  uma hora eu ria em outra eu chorava. Adiei muito terminar de o assistir, mas valeu super a pena. E o casal principal se tornou um dos meus favoritos, tão fofos e lindos apoiando uma ao outro, nunca vou me esquecer desse casal. Eles conseguem dar um final que todos os personagens mereciam. Enfim vou terminar por aqui essas avaliação, pois sinto que vou reviver todos os sentimentos que tive durante e escrever umas 10 páginas kkkk. Vou terminar com uma citação da falas de um dos meus personagens favoritos: " Assim como o infortúnio vem inesperadamente. Milagres vem do nada, logo quando estamos quase desistindo de ter esperança"
#
# RAGAZZE Questo drama me lo sono letteralmente divorato! E' stupendo,commovente e certe scene mi hanno fatta ridere, ho adorato l'eunuco col suo improbabile sorriso a 8mila denti XD ! Kim Soo Hyun...vabbè è stato amore a prima vista! E' stato bravissimo e in tutte le scene, quando piangeva mi faceva cosi commuovere che MI SI STRAZiAVA IL CUORE Ho adorato anche le versioni giovanili però...soprattutto del protagonista. Ha talento il ragazzo, anche la giovane luna  piccoli attori di talento crescono (alla faccia di 13anni) XD ma possiamo parlare un secondo della colonna sonora spettacolare? a me è piaciuto moltissimo, ascolto le canzoni del drama tutte le volte che faccio la doccia e metto lo stero a palla che ovviamente ho contagiato mia sorella con queste canzoni che le canta anche lei che ancora non ha visto il drama ho votato 10 poichè lo considero il migliore drama storico in assoluto  drama così rimangono impressi nel cuore
#
# Interesujace, prawdziwe. Mlode dziewczyny o roznych temperamentach pod jednym dachem. Nowe poczatki i widma przeszlosci, ktore chca odebrac dotychczasowy spokoj.
#
# Huwaaa, drama sekolah lagi. Karena aku masih berstatus ebagai siwa, jadi cerita ini ada beberapa yang relatable sama kehidupan sekolahku. Story Gila! Sungguh. Yah, okelah mungkin di Indonesia ada juga yang kayak begitu, tapi aku yang cuman ngelihat dari nonton Cheer Up ini ngerasa perbuatan mamanya Kwon Soo Ah itu mengerikan. Sumpah. Cuman karena ingin menaikkan spesifikasi Soo Ah, Nyonya Choi melakukan sesuatu hingga mengorbankan beberapa murid lainnya. Selain itu, menurutku dengan Nyonya Choi yang melakukan hal tersebut, itu menandakan kurang percayanya ia dengan putrinya sendiri. Hal itulah yang menjadikan Soo Ah melakukan hal tercela pula. Tapi dibalik menyeramkannya hal itu, persahabatan mereka membuatku terenyuh. Indah sekali. Di awal-awal cerita bahkan aku sampai menangis segala. Huh, so sweet! Acting/Cast Ini pertama kalinya aku lihat aktingnya Jung Eun Ji dan beberapa artis lainnya. Kemistri yang satu dengan yang ainnya sangat terasa. Pertengkaran dan rasa persahabatan mereka benar-benar membuatku memikirkan sekali lagi, apa aku sudah cukup melakukan hal baik kepada sahabatku? Ah, Yeon Doo ini tipe sahaba idaman, dan Kim Yeol tipe pacar idaman. Tak lupa Guru Yang adalah guru yang benar-benar memberikan pelajaran hidup, bukan hanya pelajaran formal di kelas. Music Lagu-lagu temanya benar-benar rekomen banget buat menaikkan semangat kalian. Arti liriknya juga menyentuh sekali, apalagi tentang persahabatan. Rewatch Value Aku nggak tahu sih kalau sekarang, tapi mungkin kalau lagi jenuh dengan pendidikan yang aku tempuh bisa coba menonton ulang drama ini. Karena aku akui, kalau aku lagi jenuh dengan belajar, kata-kata kutipan di drama ini benar-benar jempol! Ngasih semangat banget.
#
# I was so happy cuz this Drama it very interesting . الدراما كذا رائعة لم اتوقعها بهذا الجمال اتمنى منكم الاستمرار شكرا لكل طاقم التصوير وللمثل المبدع ???? ايضا لم يجب علي ان اكتب اكثر ٥٠٠ كلمة هذا كثير وصعب وشكرا لكم مرا اخرى اه اشعر بالتعب  متى استطيع ان انتهي من هذه الكتابة حسنا انا استعمتعت كثير بهذه الدراما
#
# non posso iniziare questa recensione senza dire questo: "Ci troviamo di fronte ad una piccola perla del panorama dramoso" Un drama che dalle premesse sembrava la solita storia vista e rivista ma che ha saputo soprendere e intrattenere con una trama davvero solida e interessante, personaggi dolcissimi e dalla chimica fenomenale che hanno praticamente incantato lo spettatore. In questo caso la sottoscritta.
#
# Salah satu drama favorit saya. Adegan operasi atau pembedahan yang ditampilkan membuat saya tegang dan khawatir. Menurut saya prosesnya terlihat asli dan menambahkan poin plus untuk drama ini. Alur cerita yang bisa dibilang tarik ulur dan terjebak dalam masa lalu membuat cerita ini semakin menarik. Ditambah dengan Jihyo yang memerankan pemeran utama. Emosi yang dikeluarkan juga terlihat baik. Saya tidak menyesal mengeluarkan dan menghabisi waktu saya untuk menonton 21 episode. Saya pantas untuk menghabiskan waktu anda.
#
# Premetto che ho visto questo drama tutto di un fiato (chiusa in camera 20 ore con pausa cibo e sonno   ^_^) . Ogni puntata ti invogliava a continuare senza interruzioni, ottima interpretazioni di tutti i protagonisti dove ho riscontrato molta intesa tra loro! Bravo davvero Song Joong Ki, l'ho ammirato in precedenza in Descent of the Sun (guardo i drama a ritroso! lol), un attore davvero poliedrico! La storia mi è piaciuta meno, troppo esasperata e a tratti certe scene erano un po' contraddittorie ma capisco che i drama sono anche questo (eccedere fino a stressare lo spettatore) ma qui si notano molto i cambiamenti attitudinali dei protagonisti e mi ha infastidito. 10 agli attori, 8 alla storia
#
# Cuando inicia parte con el SJK que conocí en DOTS pero es el inicio y de nada más, no esperaba que interpretara un personaje tontamente distinto (prefiero no leer mucho sobre los dramas antes), quede impactada con su gran actuación. Las otras actuaciones estuvieron muy bien, creo que es destable la de Jo Hwi Joon (Hijo de Han Jae Hee) a quien le creí todas sus actuaciones (distinto al hijo de Las dos Madres). Los besos fueron muy reales y eso lo agradezco mucho, ya que como occidental estoy acostumbrada a los besos apasionados! Por momento la story-line me supero porqué no avanzaba y adelantaba unos minutos. Spoiler! . . . . . . . . . . . . . . No quede conforme con el final de los "malo".
#
# bellissimo drama,  devo dire che ci sono parecchi colpi di scena ve lo consiglio... la cosa che non mi è andata è che lui a causa della sua ex (che secondo me si è messa troppo nella parte della tro...) è diventato una specie di gigolò con quel viso da innocente... invece la protagonista mi fa una tenerezza pazzesca  tutte a lei gli succedono è incredibile cmq è da vedere perchè è un melodramma molto bello e romantico soprattutto
#
# Great story and actors. Awesome!!Awesome!!Awesome!! Awesome!!Awesome!!Awesome!! Awesome!!Awesome!!Awesome!! Awesome!!Awesome!!Awesome!! Awesome!!Awesome!!Awesome!! Awesome!!Awesome!!Awesome!! Awesome!!Awesome!!Awesome!! Awesome!!Awesome!!Awesome!! Awesome!!Awesome!!Awesome!! Awesome!!Awesome!!Awesome!! Awesome!!Awesome!!Awesome!!
#
# Sebenarnya drama ini punya pesan yang bagus ya untuk para cewek-cewek dan semua semua orang, cuma karena ini termasuk drama musiman dan banyak banget kan yang overproud jadi aku pun agak males nontonnya. Ternyata nggak cuman aku yang ngerasain kaya gitu tapi mutualan drama aku juga banyak banget yang bilang kayak gitu, terus pas aku ngirimin menfess juga banyak yang replay punya perasaan kayak gitu. Trus ada masalah dimana penonton indo serang PYN padahal itu cuma drama Serta ada scene yang pas mereka satu sekolahan deh kayaknya camping, itu kan Suho dan jukyung naik kapal kecil gitu dan ceritanya jukyung jatuh sama Suho. Tapi pas aku lihat BTSnya mereka nggak jatuh, karena kan juga syuting lagi winter jadi enggak mungkin banget jatuh ke air yang dingin banget. Jadi pihak editing juga punya pengaruh besar. Oh ya disini aku nggak terlalu tertarik sama kisah percintaan main rolenya, tapi aku malahan lebih tertarik sama kisah cintanya Ju Yeong sama Hee Kyung. Karena justru mereka jauh lebih lucu. OSTnya enak bgt wey apalagi yang diciptain SAya, Yuju, car the garden selalu nyantol di kepala VALID NO DEBAT! Playlist on my insta bio! @cinndyra
#
# ...
#
# teka , di ko alam pano ko sisimulan ???? una , medyo boring yung simula . napaataas kilay ko , tas nasasabing kong parang ang OA ng lahat . mula sa pagacting , gang sa paglatag ng kwento - and all . pero unti unti , nagiging cute saya - na narerealize ko na lang na nakangiti na pala ako buong episode pag nagfreeze na kasi tapos na ❤ pinaalala ko sa sarili kong hindi ako dapat magexpect ng mabigat na kwento , ng production o ng ano pa man . dahil , mini series lang 'to na ginawa para sa fans ng Got7 . walang pinagiba sa #EXONextDoor - sa totoo lang , walang content yung END , as in wala talaga . walang laman yung kwento . walang twist . walang kahit ano . pero nakakaaliw at nakakatuwa kasi EXO-L ako . kaya tingen ko , ganon din yung mga Ahgase dito ???? pero sabi ko nga cute ???? sa una habang nilalatag nila , medyo OA . pero kalaunan , nakakatuwa naman . nakakacurious kung ano ba talaga ang magyayari o ano . nakakakilig in a way . medyo nalito pa ako kung sino ba ang second lead sa lead talaga . tas ayun - WALANG SECOND LEAD SYNDROME DITO - KASI MAMAHALIN AT PIPILIIN MO TALAGA YUNG MAIN ????❤    12E/15-20 mins each , kaya kayang kayang tapusin ng isang harapan . Jackson Bias ako sa Got7 at hindi ganon kalaki role ni Bae dito pero twing screentime nya , sulit . Sya ang pinakamakulit sa lahat , pinaka kenkoy ???? mas lalo lang ako nainlove sa kanya . Pero based on expirience sa ganito mo malalaman na hindi lang pala yung Bias mo ang member ng grupo . SOBRANG CUTE LANG NI JB ???????? , as in . My Bias Wrecker na ata ako sa G7 ???? pero acting wise , hm - alam ko may iiimprove pa sila . (sorry na , EXO-L e , standards ko sa acting si DO e ????) Samahan mo pa ng pamilyar na mukha . Yung female lead yung bespren ni Ae Ra sa #FightForMyWay kaya alam mo na kalibre nya sa pagaarte . ilang beses ko nasabi sa review na ito yung cute . so ayun , overall impression ko , CUTE . kung tatanungin ako kung gugustuhin ko ulitin ito , hindi na siguro . kung itatanong nyo kung irerecommend ko ba ito , hm . hindi rin . pang chill lang sya . HINDI A MUST WATCH , pero pwede na ❤
#
# a me ha lasciato l'amaro in bocca troppo noioso si salva solo il protagonista per il resto, soprattutto la protagonista femmina, secondo me doveva ritirarsi
#
# 46rfytryfuvyvutffgukiguctucfuuhfgtxudhgdtdthfhtxhfghdhddhghgxhxgxthtxtx ytfutdyydudytutydudytyd tdtdytudtduduudydh gyxjtxuyutdyuytxxytiydt yctjiftuififiytftxydtyrtxu ytiutfiutftiftfifti uttuftiftdy kyutit7truuttudtudydituiftduid u dit udutdtduiutditditudidyittyidtiydtydtdiy i tf utufuituftufiutififtdyf ddiuiutdtdtfudtutdyyud tudtuidutidifutdudttd tu tdtdutdutdtidtd uft i udtiutdiutdiutdutdtdu tujftfjufytfuututuutftff ftyuftfytyuffyuttyvf tf tfuytft ftf tftfu. futufu ttguf tuffutdyutydytdtydtdut56re54trsuyrust5eteu. tudtudytdtdtudtuydtduy
#
# O que posso dizer sobre este incrível dorama? O enredo gira em torno de uma gravidez e como isso pode afeta a vida de uma mulher, ainda mais quando ela é solteira, visto que isso na sociedade coreano e um absurdo, pois o pai ainda é uma criança sem pretensão futura alguma, então ela esconde esse fato dele, ainda mais por te se tratando de um rolo de uma noite. Os pontos de vista sobre paternidade são uns dos destaques da drama. O amadurecimento do Tae (pai da criança)  e o relacionamento que com o tempo crescer entre eles é algo sensacional, o romance, apesar de mais maduro, tem vários momentos fofos e engraçados, a comédia e os momentos sad desde Dorama são sensacionais, serve pra vc refletir sobre a vida. E um dorama q trata sobre o amadurecimento e aceitação, recomendo bastante!
#
# Como les digo que hace mucho rato un drama no me hacia llorar tanto, al inicio quede como con bug mental por que no sabia de que si iba a tratar y me encanto el no saberlo, creo que me entro mucho el sentimiento por el hecho que soy fan del kpop entonces cuando pasaban algunas cosas, pense que eso realmente les podia pasar a los idols , y mas que esta protagonizado por uno de mis bias de EXO, Suho y me dolía pensar en que no los podría proteger,  este drama lo deben ver todos es que es hermoso, el ost fue arte, la historia te deja una moraleja bella, en cuanto a el elenco me gusto mucho nunca habia visto actuar ninguno de los dos protagonistas apesar de que los conocia, sin duda lo volveria ver
#
# Sono super di parte con questo drama, e forse il voto non rispecchia pienamente alla qualità del prodotto, e sono più che consapevole di alcuni difetti della serie, ma quel voto rispecchia in pieno la montagna russa di emozioni che ho provato durante tutto il decorso delle puntate, ma soprattutto è la quantificazione della felicità che ho provato dopo aver concluso la visione dell'ultima puntata. Mi son completamente Innamorata di Kim Min Jae, sarà che in altri drama non è mai stato il main ma qui mi ha tolto il respiro, bello, gentile ma soprattutto umano, una delle rappresentazioni più belle che abbia mai visto. Park Eun Bin non ho avuto modo di vederla in altro ma qui mi è piaciuta, spero presto di vederla in altro per capire la profondità delle emozioni che sa portare sullo schermo. Ho amato il suo personaggio, una ragazza timida, riservata ma all'occorrenza ha saputo saper mettere un punto ferma nella sua vita decidendo, rifiutando ma soprattutto crescendo. Ho iniziato questo drama senza troppe aspettative, KMJ era protagonista e tanto mi è bastato per metterlo nella watchlist ma è stato amore a prima visione, mi sono innamorata della musica, non ingombrante ma complementare alla narrazione della storia, mi sono innamorata delle complesse relazioni tra i protagonisti e i supporter, mi sono innamorata di una ship che mi ha fatta emozione, esultare, piangere e che mi ha stampato un sorriso in faccia nonostante i vari contraccolpi subiti. Un drama non perfetto, certe volte si è perso in dinamiche non troppo favorevoli che ne hanno implicato la fluidità della narrazione (si è concentrato troppo sulla storia dei protagonisti secondari), un interesse troppo marcato per questioni tediose che hanno decisamente abbassato la qualità della storia (un interesse troppo approfondito riguardo questioni burocratiche e non del mondo accademico musicale), risultando in un rallentamento della storia. Ma per chi ama le storie slow, ma dove slow non è un eufemismo, dove tutto diventa un crescendo di emozioni, fino al culmine finale, ebbene questo è un Drama coi fiocchi. Ho sorriso, ho pianto, e sicuramente questa è una di quelle storie che ricorderò con piacere e che con piacere rivedrò. Tra le ost ricordo: happy di Baekhyun; kiss me di Taeyeon;
#
# You must have seen lots of reviews complaining about this drama. I would have to say that I also have the same thought. The only reason I watched this till the end is Shin Ye Eun. I'm her fan. So if you aren’t one of the actors fan just skip this one. Don’t waste your 18 hrs.  I beg ❤️ (Just to make it reach 500 characters ssssssssssssssssssssssssssssssssSssssssssssssssssssssssssssssss ssssssssssssssssssssssssssssssssSssssssssssssssssssssssssssssss  ssssssssssssssssssssssssssssssssSssssssssssssssssssssssssssssss ssssssssssssssssssssssssssssssssSssssssssssssssssssssssssssssss ssssssssssssssssssssssssssssssssSssssssssssssssssssssssssssssss ssssssssssssssssssssssssssssssssSssssssssssssssssssssssssssssss ssssssssssssssssssssssssssssssssSssssssssssssssssssssssssssssss ssssssssssssssssssssssssssssssssSssssssssssssssssssssssssssssss )
#
# Come nel manga originale, il medico chirurgo Jin finisce nel passato; qui però c’è un cambio di paesaggio: veniamo portati nella Corea del 1860, nel periodo della dinastia Joseon. Dotato delle conoscenze moderne in campo medico, il protagonista si dedica a curare i suoi nuovi pazienti. Potrà il suo bisturi, salvando delle vite, modificare il corso della storia? Jin è interpretato dall’attore Song Seung-heon (Autumn in my Heart, Summer Scent, East of Eden, My Princess) il ruolo dell’antagonista è ricoperto dal cantante-attore Kim Jaejoong (Protect the Boss), che si calerà nei panni di Kim Kyung-tak, il discendente di una nobile famiglia di guerrieri maestri di spada, quest’ultimo è innamorato di una sua amica d’infanzia. Nel cast troviamo anche Lee Beom-soo (Singles, Giant), Park Min-yeong (Glory Jane, Sungkyunkwan Scandal, City Hunter) e Lee So-yeon (Untold Scandal, Dong Yi, My Love By My Side). In molti hanno screditato questo drama, visto e considerato che è diverso dagli altri; Io invece penso che sia una storia originale e interessante. Un medico di oggi che finisce nel passato e porta le sue conoscenze mediche moderne in un mondo antico sa un po' di Thermae Romae e può avere dei risvolti interessanti. Come romanticismo non aspettatevi nulla di stratosferisco -.- ahahahhahaha
#
# Cerita ni jnis deep gilaa. Main feeling. Ji chul tak perlu cakap pn. Gerak geri dia. Pandangan dia. Mmg dah feel cinta dia bkn cinta biasa. Kalau si polis tu normal cinta mcm kbykkan org.  jnis biasa2 takkan faham drama ni. Melainkan korg betul2 fokus. Feel btl2 apa yg nk disampaikan. Jangan pilih2 hero mcm tgk style budak2. Aku cop dia nii. Aku suka dia ni. Pastu ending tak dpt hero yg nak mula la ckp drama tak best. Bagi aku born again mmg best. Deep sgt2. Stiap kata2. Pandangan. Gerak geri smua paduu! ?????? yg jenis tak faham tu korg layan cerita biasa2 dah la. Jgn layan yg berat2 ni. Dh tak faham salahkan drama pulak tak best apa ceritaaa ??
#
# allora… il protagonista di bad guy è troppo belloooooo, altissimo, bellissimo, muscoloso (e con i baffettiiiii) omoooo….. “ricomponiamoci” qui il protagonista è abbastanza famoso, ha fatto molti drama e molti film, devo ancora vederli tutti, come attore è formidabile, recita davvero bene nessuno messo a paragone con lui… la protagonista è la principessa perduta del drama the moon e in quel drama, lei era perfetta, nulla da togliere o da discriminare, i due si incontrano a causa di lei che vuole accalappiare a tutti i costi il figlio ancora nubile del presidente dove lavora lei, a questo punto facendo delle ricerche (sbagliate) va a finire dal protagonista che esso fa finta di essere il ragazzo che lei sta cercando… scoprendo dopo che si era sbagliata la loro vita amorosa finisce lì e entrambi diventano amici e lui per farsi perdonare di questa presa in giro l’aiuta a conquistare il vero figlio del presidente… il drama è ambientato metà in corea e metà in giappone… ho adorato questo drama perché per la prima volta in un drama ci sono moltiiii dialoghi in giapponese, personalmente li ho trovati entrambi troppo sexy con un’altra lingua anche perché la sanno parlare molto bene e se non sbaglio i due ragazzi sono entrambi per metà di origine giapponese
#
# ?????? ???? ?? ????? ??? ?????? ???? ?? ?????? ?????? ??? ??????? ?? ???? ????? ????????
#
# Generalno ne komentarišem niti filmove niti serije koje sam odgledala, ali ovog puta ću napraviti izuzetak jer moram da podelim utisak koji je na mene ova drama ostavila, posebno zato što znam da na našim prostorima svi delimo manje ili više isti karakter,  znam da ćete je zavoleti i da će u vama probuditi mnogo osećanja. Baš iz tog razloga i pišem ponaški, kako bi naši Balkanci videli i odlučili se da odgledaju ovu divnu seriju. Možda će vas na prvi pogled odvratiti 24 jednočasovne epizode, možda zato što je drama iz 2013. godine ili nešto drugo. Ali molim vas, nemojte odustajati i istrajte u gledanju do poslednje epizode. Kako je drama zasnovana na istinitim istorijskim događajima i likovima, možda ćete poput mene biti u iskušenju da kada stignete napola serije, na Vikipediji iščitate šta će se desiti sa svima njima - ALI, jedno veliko ali - nikako nemojte da mislite da znate sve samo zato što ste pročitali jedan članak. Toliko je stvari objašnjeno i toliko je nijansi dodato razrešenju svakog događaja. Gluma je toliko fantastična da ćete biti uvređeni i emotivno povređeni u par navrata kroz seriju, kao da neko vama lično radi sve to. Nećete imati jednog omiljenog lika, imaćete samo jednog omraženog lika i barem troje-četvoro likova koje ćete OBOŽAVATI. Molim vas odgledajte ovu dramu i budite spremni da će u vama probuditi i uzburkati sva moguća osećanja. 10/10 ~~~~~ [ ENG below ] ~~~~~ Perhaps at the first glance you won't be interested in this drama because it has 24  x one-hour episodes, maybe because it’s a 2013 drama or for some other reason. But please don't drop this drama before even giving it a try; persevere in watching until the last episode, you won't regret it. As the drama is based on real historical events and characters, you may be tempted to read on Wikipedia what will happen to all of them (like I was) - BUT, one big but - by no means think you know everything about those characters and their destinies just because you have read an article. So many things have been explained and so many nuances have been added to the resolution of each event. The acting is so fantastic that you will be offended and emotionally hurt on a couple of occasions throughout the series, as if someone is doing all those things to you personally. You won’t have one favorite character, you’ll only have one character you don't like and at least three or four characters you’ll absolutely LOVE. Please watch this drama and be ready to awaken and agitate all possible feelings in you. 10/10
#
# Sangat suka film ini. Terutama karakter Jin Soo, Bravo aktingnya!!! dan Seo Eun Young. Mereka "feel"nya dapet banget. Bisa dibilang tokoh antagonisnya dalam film ini tidak terlalu menonjol. Biasanya hampir ditiap film ada tokoh antagonis yang kejam dan jahat, dalam hal ini digambarkan setiap tokoh hampir punya keseimbangan peran. Kemudian fokus dari film tidak ditonjolkan hanya pada Jin Soo dan Eun Young, sebaliknya tokoh-tokoh lain yang terlibat cukup berperan serta. Akting dari masing-masing pemainnya kereeeenn!! momen-momennya dibuat rapih dan banyak yang berkesan :). Intinya aku suka banget sama film ini. Terutama sama peran Jin Soo dan Eun Young.
#
# sarò molto diretta di questo drama anche perché ho imiegato 4 giorni per vederlo, di solito non arrivo mai a così tanti giorni ^.^, cmq stavo per citarvi alcune descrizioni del drama, ovvero il mio commento, nei primi episodi racconta la storia del protagonista di come tutto iniziò, quindi in questo momento vedremo il giovane Park ji-bin, che lo abbiamo visto già in molti drama ma che svolgeva la parte del fratelli minore “di solito della protagonista” ma che qui, invece svolge il ruolo del protagonista, da adolescente; devo dire che il nostro giovanotto nella recitazione di questo drama si è completamente superato, forse perché nei panni del protagonista si è gasato un po’  cmq bravo, bravo, complimenti Park ji-bin (della serie “piccoli attori crescono”) Dopo alcuni episodi passano gli anni in fretta e si arriva nel 2008, quindi all’incirca saranno passati tra i 9e i 10 anni, il nostro protagonista cresce e si trasforma nel nostro incantevole Kang Ji-Hwan dove svolge un ruolo totalmente nuovo di come lo vediamo di solito, non posso dire altro  come protagonista femminile abbiamo la dolcissima e paffutella Hwang Jung-Eum che fa un nuovo drama quando ne finisce un altro come fa lo sa solo lei, cmq fantastica attrice e fantastici entrambi poiché è una coppia molto strana e divertente quando sono insieme, dal primo momento che si vedono iniziano ad azzuffarsi e ad insultarsi a vicenda fino all’ultimo minuto dell’ep 24 ahahahhahah se ci penso le risateeeeee Cmq lo consiglio solo se vi piacciono i generi dei procurato e avvocati anche triller, devo dire che c’è molta suspense.. è un drama devo dire molto pesante, causata dalla storia ce è moltooooooo contorta  di solito nei drama c’è solo una persona malvagia, oppure nei casi più rari sono 2, ma qui si sono superatiiii già sono arrivata al punto di non riuscire a contarli quindi immaginate un po’ il mal di testa che mi hanno fatto venire questi delinquenti

# %% [markdown]
# - drop those non-English reviews

# %%
dramas = dramas.drop(langlist).reset_index(drop=True)
dramas = dramas.drop(columns='review')
dramas['review'] = review_clean
dramas
# now reviews should only contain English
# Out:
#                      title                                             review
# 0                   Goblin  If you are hesitating to watch this at all, pl...
# 1                   Goblin  I feel compelled to write a review for Goblin ...
# 2                   Goblin  It must be said that Goblin is very much a som...
# 3                   Goblin  Every moment of it indeed shined! Goblin is a ...
# 4                   Goblin  Somewhere inside Goblin, buried under a mound ...
# ...                    ...                                                ...
# 21102  Queen: Love And War  I think I might have over-hyped this drama for...
# 21103  Queen: Love And War  I'll just gonna say it was very wonderful, it'...
# 21104  Queen: Love And War  This is one of my binge watched dramas after b...
# 21105  Queen: Love And War  The best word to sum up this kdrama is "strong...
# 21106  Queen: Love And War  First of all I love the acting! ML is so hands...
#
# [21107 rows x 2 columns]

# %%
# read in the role informations
roles = pd.read_csv('roles.csv', index_col = 0)
roles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2138 entries, 0 to 2137
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       2138 non-null   object
#  1   CharName    2136 non-null   object
#  2   Role        2138 non-null   object
#  3   MainCouple  2138 non-null   object
#  4   ActorName   2138 non-null   object
#  5   Gender      2138 non-null   object
#  6   Image       2138 non-null   object
# dtypes: object(7)
# memory usage: 133.6+ KB

# %%
# There are NaN for CharName, we fill it with empty string
roles = roles.fillna('')

roleTitle = set(roles['Title'])
dramaTitle = set(dramas['title'])
dramaTitle - roleTitle
# Out:
# {'The Great Seducer'}

# %% [markdown]
# - `The Great Seducer` doesn't have role information, so we drop it as well to be consistent (because we can't change actor/actress name to single word format and we won't be able to match them with any tuple pair in the dictionary later)

# %%
dramas = dramas[dramas['title']!= 'The Great Seducer'].reset_index(drop=True)
dramas
# Out:
#                      title                                             review
# 0                   Goblin  If you are hesitating to watch this at all, pl...
# 1                   Goblin  I feel compelled to write a review for Goblin ...
# 2                   Goblin  It must be said that Goblin is very much a som...
# 3                   Goblin  Every moment of it indeed shined! Goblin is a ...
# 4                   Goblin  Somewhere inside Goblin, buried under a mound ...
# ...                    ...                                                ...
# 21012  Queen: Love And War  I think I might have over-hyped this drama for...
# 21013  Queen: Love And War  I'll just gonna say it was very wonderful, it'...
# 21014  Queen: Love And War  This is one of my binge watched dramas after b...
# 21015  Queen: Love And War  The best word to sum up this kdrama is "strong...
# 21016  Queen: Love And War  First of all I love the acting! ML is so hands...
#
# [21017 rows x 2 columns]

# %% [markdown]
# #### Create conversion dictionary for neuralcoref:
# - first, the 'CharacterName' field is not well-structured. <br>
# eg: `"Safari" Moon Deok Bae`: it is one string but two names, `Safari` or `Moon Deok Bae` <br>
# eg: `Park Ha / Boo Yong` or `Jun Seol | Ryu Soo Hyun` : some are seperated by '/', some are seperated by '|' <br>
# eg: `"Man Goo" Choi Jin Nyeo {Room 610}` <br>
# eg: `Han Mi Mo [former "Angels" member] `<br>
# so this function will split the string into individual names
# - after having all the possible character names and actor/actress name, if gender is `male`, we will add `['boy','male','man']` to the key and `['girl','female','woman']` otherwise
# - this function will return a dictionary for conversion, and also a cast list containing all the names (character names and real names for entity ruler later)

# %%
def make_casts(roles, title):
    cast_dict = {}
    df = roles[roles['Title']==title]
    actors = list(df['ActorName'])
    casts = []
    for actor in actors:
        row = df[df['ActorName']==actor]
        index = row.index[0]
        gender = row['Gender'].values[0]
        char = row['CharName'].values[0]
        charNew = []

        if len(row['CharName']) != 0 and 'Himself' not in char and 'Herself' not in char:
        # sometimes the actor is acting as 'Himself/Herself' so if that's in character name, don't include
        
            if '|' in char:
                names = char.split("|")
            elif '/' in char:
                names = char.split("/")
            else:
                names = [char]
            for nam in names:
                nam = nam.strip()
                nam = nam.split('[')[0].strip() 
                # if there is [ ] in the string, we don't include those inside the squre brackets becuase it is 
                # usually an explanation (not name) and it's usually long eg: Han Mi Mo [former "Angels" member]
                
                clean = [n.strip() for n in nam.split('"') if n]
                for c in clean:
                    a = c.split('{')
                    for b in a:
                        b = b.replace('}', ' ')
                        charNew.append(b.strip()) 
                        # charNew is a list containing seperated names for one character name string

        casts += [actor] + charNew
        charNew = [''.join(ch.split()) for ch in charNew] # change to single word format (eg: 'Gong Yoo'->'GongYoo')
        actor = ''.join(actor.split()) # change to single word format
        
        roles.at[index, 'CharName'] = ','.join(charNew) 
        # after we seperate different character names, we modify on roles df so when we need to use it in 
        # the next notebook, we don't need to do this again and can split by comma
        
        roles.at[index, 'ActorName'] = actor # modify on roles df
        for key in charNew + [actor]:
            if 'Room' not in key: # eg: Room 610 is a name refer to the couple, 
                                  # but in this case we don't include it in dict because we cannot assign gender
                if gender == 'Female':
                    cast_dict[key] = ['girl','female','woman']
                else:
                    cast_dict[key] = ['boy','male','man']

    return cast_dict, casts

# %% [markdown]
# #### Replace all different spellings to all same format:
# - we do this for all character names and real names <br>
# eg: 'Gong Yoo' -> 'GongYoo' (real name: Gong Yoo) <br>
# eg: 'go-eun' -> 'KimGoEun' (real name: Kim Go Eun)

# %%
def replace_cast(doc):
    name_matcher = Matcher(nlp.vocab)
    for cast in casts:
        cast_pattern = []
        name = cast.split()
        if len(name)==1:
            char1 = name[0].lower()
            pt1 = [{'LOWER': char1}]
            name_matcher.add(cast, None, pt1)
        elif len(name)==2:
            char1 = name[0].lower()
            char2 = name[1].lower()
            pt1 = [{'LOWER': char1+char2}]
            pt2 = [{'LOWER': char1[0]+char2[0]}]
            pt3 = [{'LOWER': char1}, {'TEXT': '-', 'OP': '?'}, {'LOWER': char2}] 
            name_matcher.add(cast, None, pt1)
            name_matcher.add(cast, None, pt2)
            name_matcher.add(cast, None, pt3)
        elif len(name)==3:
            char1 = name[0].lower()
            char2 = name[1].lower()
            char3 = name[2].lower()
            pt1 = [{'LOWER': char1, 'OP': '?'}, {'LOWER': char2+char3}] 
            pt2 = [{'LOWER': char1[0]+char2[0]+char3[0]}]
            pt3 = [{'LOWER': char1, 'OP': '?'}, {'TEXT': '-', 'OP': '?'}, {'LOWER': char2}, {'TEXT': '-', 'OP': '?'}, {'LOWER': char3}]
            pt4 = [{'LOWER': char1+char2+char3}] 
            name_matcher.add(cast, None, pt1)
            name_matcher.add(cast, None, pt2)
            name_matcher.add(cast, None, pt3)
            name_matcher.add(cast, None, pt4)
        elif len(name)==4:
            char1 = name[0].lower()
            char2 = name[1].lower()
            char3 = name[2].lower()
            char4 = name[3].lower()
            pt1 = [{'LOWER': char1, 'OP': '?'},{'LOWER': char2, 'OP': '?'}, {'LOWER': char3+char4}] 
            pt2 = [{'LOWER': char2[0]+char3[0]+char4[0]}]
            pt3 = [{'LOWER': char1, 'OP': '?'},{'LOWER': char2, 'OP': '?'}, {'TEXT': '-', 'OP': '?'}, {'LOWER': char3}, {'TEXT': '-', 'OP': '?'}, {'LOWER': char4}]
            pt4 = [{'LOWER': char2+char3+char4}] 
            pt5 = [{'LOWER': char1+char2+char3+char4}] 
            name_matcher.add(cast, None, pt1)
            name_matcher.add(cast, None, pt2)
            name_matcher.add(cast, None, pt3)
            name_matcher.add(cast, None, pt4)
            name_matcher.add(cast, None, pt5)
    count = 0
    name_matches = name_matcher(doc)
    while count < len(name_matches):
        match_id, start, end = name_matches[count]
        castName = nlp.vocab.strings[match_id]
        rep = ''.join(castName.split())
        newDoc = doc[:start].text+' '+rep+' '+doc[end:].text
        newDoc = re.sub(r'\s+', ' ', newDoc)
        doc = nlp.make_doc(newDoc.strip()) # this will speed up things because make_doc will only run the tokenizer
        name_matches = name_matcher(doc)
        count += 1
    return doc

# we replace the first match, then we match again, this time because we change to eg 'KimGoEun',
# so it'll be matched again, so +1 each time

# %% [markdown]
# #### Pronoun replacement:
# - we add 3 components to the pipeline: <br>
# `replace_cast` (match and change different spellings) <br>
# `entity_ruler` (when we change the format of the name, eg: Gong Yoo -> GongYoo, the model may predict it wrongly (we tried and it is predicted as ORG, but this is an actor so it should be PERSON), we need to change everyone in the cast list as PERSON, because neuralcoref is using named entity recognizer (NER) results from spacy model) <br>
# `neuralcoref` (for pronoun replacement) <br>
#
#
# - these three components are changed whenever the drama changes (when we have a new drama, we'll remove them and add again. We don't want this to buildup, because:
# 1. there are some special names that only appear in this drama as a person's name but not in others <br>
# eg: Sunny in `Goblin`. sunny is not a name when it appears in other drama, we don't want to mismatch/misclassify it in other drama
# 2. Korean names are similar (eg: Joo Ji Won / Han Ji Won / Kim Ji Won) <br>
# Sometimes people will use Ji Won to refer to the person. This is context-specific (i.e it should only refer to the person acting in the drama not someone else). If this builds up, `Ji Won` may be matched to some other person who doesn't act in this drama, which is not correct

# %%
reviews = list(dramas['review'])
titles = list(dramas['title'].unique())
i = 0
for title in titles:
    l = 0
    title_df = dramas[dramas['title']==title]
    length = len(title_df)
    cast_dict, casts = make_casts(roles, title)
    nlp.add_pipe(replace_cast, first=True)
    for cast in casts:
        pattern = ''.join(cast.split())
        ruler.add_patterns([{"label": "PERSON", "pattern": pattern}])
    nlp.add_pipe(ruler, before="ner")
    neuralcoref.add_to_pipe(nlp,conv_dict=cast_dict)
    while l < length:
        doc = nlp(reviews[i])
        reviews[i] = doc._.coref_resolved
        i+=1
        l+=1
    nlp.remove_pipe('replace_cast')
    nlp.remove_pipe('entity_ruler')
    nlp.remove_pipe('neuralcoref')

# %%
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %%
resolve = pd.DataFrame({'title': dramas.title, 'review': reviews})

# %% [markdown]
# - export the new csv for the next notebook

# %%
resolve.to_csv('review_resolve_emoji.csv')
roles.to_csv('roles_mod.csv')
